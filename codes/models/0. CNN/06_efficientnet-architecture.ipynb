# %% [markdown]
# # Dependencies
#    - torchvision models:
#       - class
#          - brings in the model class directly
#          - Allows more control and customization since you are dealing directly with the class. You can override methods, customize initialization, etc.
#       - function
#          - This import brings in a function that returns an instance of the model
#          - Easier and quicker to use, especially for standard models
#    - [pytorch.org/vision/stable/models.html](https://pytorch.org/vision/stable/models.html)

# %%
import math

import torch
from torch import nn
from torch.functional import F
from torchinfo import summary
from torchvision.models import (EfficientNet, efficientnet_b0, efficientnet_b1, efficientnet_b2, efficientnet_b3, efficientnet_b4, efficientnet_b5, efficientnet_b6, efficientnet_b7)

# %% [markdown]
# # EfficientNet
#    - EfficientNet, developed in 2019 by researchers at [Google AI](https://research.google/)
#    - It is based on the [EfficientNet: Rethinking Model Scaling for Convolutional Neural Networks](https://arxiv.org/pdf/1905.11946) paper
#    - It was trained on the [ImageNet](https://www.image-net.org/) dataset (first resized to 256x256 then center cropped to 224x224) [[ImageNet viewer](https://navigu.net/#imagenet)]
#    - Known for its balance of accuracy and efficiency, achieving state-of-the-art performance while being significantly more computationally efficient than previous models
#    - The EfficientNet family includes several variants, such as `EfficientNet-B0` through `EfficientNet-B7`, where the number indicates the scaling factor, with B0 being the base model
#    - Achieved high performance in various benchmarks and demonstrated significant efficiency improvements due to the compound scaling method
#
# <figure style="text-align: center;">
#     <img src="../../../resources/images/SVGs/efficientnet-architecture.svg" alt="efficientnet-architecture.svg" style="width: 100%;">
#     <figcaption>EfficientNet Architecture</figcaption>
# </figure>

# %% [markdown]
# ## Custom EfficientNet
#    - `Softmax` is missing due to internal implementation of `LogSoftmax` in the `CrossEntropyLoss` function.

# %%
# Swish activation function
class Swish(nn.Module):
    def forward(self, x):
        return x * torch.sigmoid(x)

# SE Block
class SEBlock(nn.Module):
    def __init__(self, in_channels, reduction=4):
        super(SEBlock, self).__init__()
        reduced_channels = in_channels // reduction
        self.fc1 = nn.Conv2d(in_channels, reduced_channels, 1)
        self.fc2 = nn.Conv2d(reduced_channels, in_channels, 1)

    def forward(self, x):
        out = F.adaptive_avg_pool2d(x, 1)
        out = F.relu(self.fc1(out))
        out = torch.sigmoid(self.fc2(out))
        return x * out

# MBConv Block
class MBConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, expand_ratio, kernel_size, stride, reduction=4, drop_connect_rate=0.2):
        super(MBConvBlock, self).__init__()
        self.drop_connect_rate = drop_connect_rate
        self.has_se = reduction > 0
        self.stride = stride
        mid_channels = in_channels * expand_ratio

        # Expand phase
        if expand_ratio != 1:
            self.expand = nn.Conv2d(in_channels, mid_channels, 1, bias=False)
            self.bn0 = nn.BatchNorm2d(mid_channels)
            self.act0 = Swish()

        # Depthwise convolution phase
        self.depthwise = nn.Conv2d(mid_channels, mid_channels, kernel_size, stride, (kernel_size-1)//2, groups=mid_channels, bias=False)
        self.bn1 = nn.BatchNorm2d(mid_channels)
        self.act1 = Swish()

        # Squeeze and Excitation phase
        if self.has_se:
            self.se = SEBlock(mid_channels, reduction)

        # Output phase
        self.project = nn.Conv2d(mid_channels, out_channels, 1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

    def drop_connect(self, x):
        if not self.training:
            return x
        keep_prob = 1 - self.drop_connect_rate
        random_tensor = keep_prob + torch.rand((x.shape[0], 1, 1, 1), dtype=x.dtype, device=x.device)
        binary_tensor = torch.floor(random_tensor)
        return x / keep_prob * binary_tensor

    def forward(self, x):
        identity = x

        if hasattr(self, 'expand'):
            x = self.expand(x)
            x = self.bn0(x)
            x = self.act0(x)

        x = self.depthwise(x)
        x = self.bn1(x)
        x = self.act1(x)

        if self.has_se:
            x = self.se(x)

        x = self.project(x)
        x = self.bn2(x)

        if self.stride == 1 and x.shape == identity.shape:
            if self.drop_connect_rate:
                x = self.drop_connect(x)
            x += identity
        return x

# %%
class CustomEfficientNet(nn.Module):
    def __init__(self, width_coefficient, depth_coefficient, dropout_rate=0.2, num_classes=1000):
        super(CustomEfficientNet, self).__init__()
        self.dropout_rate = dropout_rate

        def round_filters(filters, divisor=8):
            filters *= width_coefficient
            new_filters = max(divisor, int(filters + divisor / 2) // divisor * divisor)
            if new_filters < 0.9 * filters:
                new_filters += divisor
            return int(new_filters)

        def round_repeats(repeats):
            return int(torch.ceil(torch.tensor(depth_coefficient * repeats)).item())

        # Stem
        out_channels = round_filters(32)
        self.stem = nn.Sequential(
            nn.Conv2d(3, out_channels, 3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            Swish()
        )

        # Blocks
        self.blocks = nn.ModuleList([])
        self.blocks.append(MBConvBlock(in_channels=out_channels, out_channels=round_filters(16), expand_ratio=1, kernel_size=3, stride=1))
        
        in_channels = round_filters(16)
        block_args = [
            # (out_channels, num_repeats, kernel_size, stride, expand_ratio)
            (24, 2, 3, 2, 6),
            (40, 2, 5, 2, 6),
            (80, 3, 3, 2, 6),
            (112, 3, 5, 1, 6),
            (192, 4, 5, 2, 6),
            (320, 1, 3, 1, 6)
        ]
        for (out_channels, num_repeats, kernel_size, stride, expand_ratio) in block_args:
            out_channels = round_filters(out_channels)
            repeats = round_repeats(num_repeats)
            for i in range(repeats):
                if i == 0:
                    self.blocks.append(MBConvBlock(in_channels=in_channels, out_channels=out_channels, expand_ratio=expand_ratio, kernel_size=kernel_size, stride=stride))
                else:
                    self.blocks.append(MBConvBlock(in_channels=in_channels, out_channels=out_channels, expand_ratio=expand_ratio, kernel_size=kernel_size, stride=1))
                in_channels = out_channels

        # Head
        out_channels = round_filters(1280)
        self.head = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            Swish(),
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Dropout(dropout_rate),
            nn.Linear(out_channels, num_classes)
        )

    def forward(self, x):
        x = self.stem(x)
        for block in self.blocks:
            x = block(x)
        x = self.head(x)
        return x

# %% [markdown]
# ### EfficientNet-B0

# %%
efficientnet_b0_1 = CustomEfficientNet(width_coefficient=1.0, depth_coefficient=1.0, dropout_rate=0.2, num_classes=1000)
efficientnet_b0_1
# Out:
# CustomEfficientNet(
#   (stem): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): ModuleList(
#     (0): MBConvBlock(
#       (depthwise): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (expand): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): MBConvBlock(
#       (expand): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): MBConvBlock(
#       (expand): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6-7): 2 x MBConvBlock(
#       (expand): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#       (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8): MBConvBlock(
#       (expand): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#       (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (9-10): 2 x MBConvBlock(
#       (expand): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#       (bn1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (11): MBConvBlock(
#       (expand): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#       (bn1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (12-14): 3 x MBConvBlock(
#       (expand): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#       (bn1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1152, 288, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(288, 1152, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (15): MBConvBlock(
#       (expand): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#       (bn1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1152, 288, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(288, 1152, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b0_1, (1, 3, 224, 224), device='cpu')
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomEfficientNet                       [1, 1000]                 --
# ├─Sequential: 1-1                        [1, 32, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 32, 112, 112]         864
# │    └─BatchNorm2d: 2-2                  [1, 32, 112, 112]         64
# │    └─Swish: 2-3                        [1, 32, 112, 112]         --
# ├─ModuleList: 1-2                        --                        --
# │    └─MBConvBlock: 2-4                  [1, 16, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 32, 112, 112]         288
# │    │    └─BatchNorm2d: 3-2             [1, 32, 112, 112]         64
# │    │    └─Swish: 3-3                   [1, 32, 112, 112]         --
# │    │    └─SEBlock: 3-4                 [1, 32, 112, 112]         552
# │    │    └─Conv2d: 3-5                  [1, 16, 112, 112]         512
# │    │    └─BatchNorm2d: 3-6             [1, 16, 112, 112]         32
# │    └─MBConvBlock: 2-5                  [1, 24, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 96, 112, 112]         1,536
# │    │    └─BatchNorm2d: 3-8             [1, 96, 112, 112]         192
# │    │    └─Swish: 3-9                   [1, 96, 112, 112]         --
# │    │    └─Conv2d: 3-10                 [1, 96, 56, 56]           864
# │    │    └─BatchNorm2d: 3-11            [1, 96, 56, 56]           192
# │    │    └─Swish: 3-12                  [1, 96, 56, 56]           --
# │    │    └─SEBlock: 3-13                [1, 96, 56, 56]           4,728
# │    │    └─Conv2d: 3-14                 [1, 24, 56, 56]           2,304
# │    │    └─BatchNorm2d: 3-15            [1, 24, 56, 56]           48
# │    └─MBConvBlock: 2-6                  [1, 24, 56, 56]           --
# │    │    └─Conv2d: 3-16                 [1, 144, 56, 56]          3,456
# │    │    └─BatchNorm2d: 3-17            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-18                  [1, 144, 56, 56]          --
# │    │    └─Conv2d: 3-19                 [1, 144, 56, 56]          1,296
# │    │    └─BatchNorm2d: 3-20            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-21                  [1, 144, 56, 56]          --
# │    │    └─SEBlock: 3-22                [1, 144, 56, 56]          10,548
# │    │    └─Conv2d: 3-23                 [1, 24, 56, 56]           3,456
# │    │    └─BatchNorm2d: 3-24            [1, 24, 56, 56]           48
# │    └─MBConvBlock: 2-7                  [1, 40, 28, 28]           --
# │    │    └─Conv2d: 3-25                 [1, 144, 56, 56]          3,456
# │    │    └─BatchNorm2d: 3-26            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-27                  [1, 144, 56, 56]          --
# │    │    └─Conv2d: 3-28                 [1, 144, 28, 28]          3,600
# │    │    └─BatchNorm2d: 3-29            [1, 144, 28, 28]          288
# │    │    └─Swish: 3-30                  [1, 144, 28, 28]          --
# │    │    └─SEBlock: 3-31                [1, 144, 28, 28]          10,548
# │    │    └─Conv2d: 3-32                 [1, 40, 28, 28]           5,760
# │    │    └─BatchNorm2d: 3-33            [1, 40, 28, 28]           80
# │    └─MBConvBlock: 2-8                  [1, 40, 28, 28]           --
# │    │    └─Conv2d: 3-34                 [1, 240, 28, 28]          9,600
# │    │    └─BatchNorm2d: 3-35            [1, 240, 28, 28]          480
# │    │    └─Swish: 3-36                  [1, 240, 28, 28]          --
# │    │    └─Conv2d: 3-37                 [1, 240, 28, 28]          6,000
# │    │    └─BatchNorm2d: 3-38            [1, 240, 28, 28]          480
# │    │    └─Swish: 3-39                  [1, 240, 28, 28]          --
# │    │    └─SEBlock: 3-40                [1, 240, 28, 28]          29,100
# │    │    └─Conv2d: 3-41                 [1, 40, 28, 28]           9,600
# │    │    └─BatchNorm2d: 3-42            [1, 40, 28, 28]           80
# │    └─MBConvBlock: 2-9                  [1, 80, 14, 14]           --
# │    │    └─Conv2d: 3-43                 [1, 240, 28, 28]          9,600
# │    │    └─BatchNorm2d: 3-44            [1, 240, 28, 28]          480
# │    │    └─Swish: 3-45                  [1, 240, 28, 28]          --
# │    │    └─Conv2d: 3-46                 [1, 240, 14, 14]          2,160
# │    │    └─BatchNorm2d: 3-47            [1, 240, 14, 14]          480
# │    │    └─Swish: 3-48                  [1, 240, 14, 14]          --
# │    │    └─SEBlock: 3-49                [1, 240, 14, 14]          29,100
# │    │    └─Conv2d: 3-50                 [1, 80, 14, 14]           19,200
# │    │    └─BatchNorm2d: 3-51            [1, 80, 14, 14]           160
# │    └─MBConvBlock: 2-10                 [1, 80, 14, 14]           --
# │    │    └─Conv2d: 3-52                 [1, 480, 14, 14]          38,400
# │    │    └─BatchNorm2d: 3-53            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-54                  [1, 480, 14, 14]          --
# │    │    └─Conv2d: 3-55                 [1, 480, 14, 14]          4,320
# │    │    └─BatchNorm2d: 3-56            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-57                  [1, 480, 14, 14]          --
# │    │    └─SEBlock: 3-58                [1, 480, 14, 14]          115,800
# │    │    └─Conv2d: 3-59                 [1, 80, 14, 14]           38,400
# │    │    └─BatchNorm2d: 3-60            [1, 80, 14, 14]           160
# │    └─MBConvBlock: 2-11                 [1, 80, 14, 14]           --
# │    │    └─Conv2d: 3-61                 [1, 480, 14, 14]          38,400
# │    │    └─BatchNorm2d: 3-62            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-63                  [1, 480, 14, 14]          --
# │    │    └─Conv2d: 3-64                 [1, 480, 14, 14]          4,320
# │    │    └─BatchNorm2d: 3-65            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-66                  [1, 480, 14, 14]          --
# │    │    └─SEBlock: 3-67                [1, 480, 14, 14]          115,800
# │    │    └─Conv2d: 3-68                 [1, 80, 14, 14]           38,400
# │    │    └─BatchNorm2d: 3-69            [1, 80, 14, 14]           160
# │    └─MBConvBlock: 2-12                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-70                 [1, 480, 14, 14]          38,400
# │    │    └─BatchNorm2d: 3-71            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-72                  [1, 480, 14, 14]          --
# │    │    └─Conv2d: 3-73                 [1, 480, 14, 14]          12,000
# │    │    └─BatchNorm2d: 3-74            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-75                  [1, 480, 14, 14]          --
# │    │    └─SEBlock: 3-76                [1, 480, 14, 14]          115,800
# │    │    └─Conv2d: 3-77                 [1, 112, 14, 14]          53,760
# │    │    └─BatchNorm2d: 3-78            [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-13                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-79                 [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-80            [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-81                  [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-82                 [1, 672, 14, 14]          16,800
# │    │    └─BatchNorm2d: 3-83            [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-84                  [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-85                [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-86                 [1, 112, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-87            [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-14                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-88                 [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-89            [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-90                  [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-91                 [1, 672, 14, 14]          16,800
# │    │    └─BatchNorm2d: 3-92            [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-93                  [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-94                [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-95                 [1, 112, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-96            [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-15                 [1, 192, 7, 7]            --
# │    │    └─Conv2d: 3-97                 [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-98            [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-99                  [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-100                [1, 672, 7, 7]            16,800
# │    │    └─BatchNorm2d: 3-101           [1, 672, 7, 7]            1,344
# │    │    └─Swish: 3-102                 [1, 672, 7, 7]            --
# │    │    └─SEBlock: 3-103               [1, 672, 7, 7]            226,632
# │    │    └─Conv2d: 3-104                [1, 192, 7, 7]            129,024
# │    │    └─BatchNorm2d: 3-105           [1, 192, 7, 7]            384
# │    └─MBConvBlock: 2-16                 [1, 192, 7, 7]            --
# │    │    └─Conv2d: 3-106                [1, 1152, 7, 7]           221,184
# │    │    └─BatchNorm2d: 3-107           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-108                 [1, 1152, 7, 7]           --
# │    │    └─Conv2d: 3-109                [1, 1152, 7, 7]           28,800
# │    │    └─BatchNorm2d: 3-110           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-111                 [1, 1152, 7, 7]           --
# │    │    └─SEBlock: 3-112               [1, 1152, 7, 7]           664,992
# │    │    └─Conv2d: 3-113                [1, 192, 7, 7]            221,184
# │    │    └─BatchNorm2d: 3-114           [1, 192, 7, 7]            384
# │    └─MBConvBlock: 2-17                 [1, 192, 7, 7]            --
# │    │    └─Conv2d: 3-115                [1, 1152, 7, 7]           221,184
# │    │    └─BatchNorm2d: 3-116           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-117                 [1, 1152, 7, 7]           --
# │    │    └─Conv2d: 3-118                [1, 1152, 7, 7]           28,800
# │    │    └─BatchNorm2d: 3-119           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-120                 [1, 1152, 7, 7]           --
# │    │    └─SEBlock: 3-121               [1, 1152, 7, 7]           664,992
# │    │    └─Conv2d: 3-122                [1, 192, 7, 7]            221,184
# │    │    └─BatchNorm2d: 3-123           [1, 192, 7, 7]            384
# │    └─MBConvBlock: 2-18                 [1, 192, 7, 7]            --
# │    │    └─Conv2d: 3-124                [1, 1152, 7, 7]           221,184
# │    │    └─BatchNorm2d: 3-125           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-126                 [1, 1152, 7, 7]           --
# │    │    └─Conv2d: 3-127                [1, 1152, 7, 7]           28,800
# │    │    └─BatchNorm2d: 3-128           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-129                 [1, 1152, 7, 7]           --
# │    │    └─SEBlock: 3-130               [1, 1152, 7, 7]           664,992
# │    │    └─Conv2d: 3-131                [1, 192, 7, 7]            221,184
# │    │    └─BatchNorm2d: 3-132           [1, 192, 7, 7]            384
# │    └─MBConvBlock: 2-19                 [1, 320, 7, 7]            --
# │    │    └─Conv2d: 3-133                [1, 1152, 7, 7]           221,184
# │    │    └─BatchNorm2d: 3-134           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-135                 [1, 1152, 7, 7]           --
# │    │    └─Conv2d: 3-136                [1, 1152, 7, 7]           10,368
# │    │    └─BatchNorm2d: 3-137           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-138                 [1, 1152, 7, 7]           --
# │    │    └─SEBlock: 3-139               [1, 1152, 7, 7]           664,992
# │    │    └─Conv2d: 3-140                [1, 320, 7, 7]            368,640
# │    │    └─BatchNorm2d: 3-141           [1, 320, 7, 7]            640
# ├─Sequential: 1-3                        [1, 1000]                 --
# │    └─Conv2d: 2-20                      [1, 1280, 7, 7]           409,600
# │    └─BatchNorm2d: 2-21                 [1, 1280, 7, 7]           2,560
# │    └─Swish: 2-22                       [1, 1280, 7, 7]           --
# │    └─AdaptiveAvgPool2d: 2-23           [1, 1280, 1, 1]           --
# │    └─Flatten: 2-24                     [1, 1280]                 --
# │    └─Dropout: 2-25                     [1, 1280]                 --
# │    └─Linear: 2-26                      [1, 1000]                 1,281,000
# ==========================================================================================
# Total params: 8,423,848
# Trainable params: 8,423,848
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 389.00
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 107.90
# Params size (MB): 33.70
# Estimated Total Size (MB): 142.20
# ==========================================================================================

# %% [markdown]
# ### EfficientNet-B1

# %%
efficientnet_b1_1 = CustomEfficientNet(width_coefficient=1.0, depth_coefficient=1.1, dropout_rate=0.2, num_classes=1000)
efficientnet_b1_1
# Out:
# CustomEfficientNet(
#   (stem): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): ModuleList(
#     (0): MBConvBlock(
#       (depthwise): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (expand): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2-3): 2 x MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5-6): 2 x MBConvBlock(
#       (expand): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): MBConvBlock(
#       (expand): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8-10): 3 x MBConvBlock(
#       (expand): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#       (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (11): MBConvBlock(
#       (expand): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#       (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (12-14): 3 x MBConvBlock(
#       (expand): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#       (bn1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (15): MBConvBlock(
#       (expand): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#       (bn1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (16-19): 4 x MBConvBlock(
#       (expand): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#       (bn1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1152, 288, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(288, 1152, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (20): MBConvBlock(
#       (expand): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#       (bn1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1152, 288, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(288, 1152, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (21): MBConvBlock(
#       (expand): Conv2d(320, 1920, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1920, 1920, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1920, bias=False)
#       (bn1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1920, 480, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(480, 1920, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1920, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
ientnet_b1_1 = CustomEfficientNet(width_coefficient=1.0, depth_coefficient=1.1, dropout_rate=0.2, num_classes=1000)
efficientnet_b1_1
# Out:
# CustomEfficientNet(
#   (stem): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): ModuleList(
#     (0): MBConvBlock(
#       (depthwise): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (expand): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2-3): 2 x MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5-6): 2 x MBConvBlock(
#       (expand): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): MBConvBlock(
#       (expand): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8-10): 3 x MBConvBlock(
#       (expand): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#       (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (11): MBConvBlock(
#       (expand): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#       (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (12-14): 3 x MBConvBlock(
#       (expand): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#       (bn1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (15): MBConvBlock(
#       (expand): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#       (bn1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (16-19): 4 x MBConvBlock(
#       (expand): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#       (bn1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1152, 288, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(288, 1152, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (20): MBConvBlock(
#       (expand): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#       (bn1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1152, 288, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(288, 1152, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (21): MBConvBlock(
#       (expand): Conv2d(320, 1920, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1920, 1920, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1920, bias=False)
#       (bn1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1920, 480, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(480, 1920, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1920, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b1_1, (1, 3, 224, 224), device='cpu')
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomEfficientNet                       [1, 1000]                 --
# ├─Sequential: 1-1                        [1, 32, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 32, 112, 112]         864
# │    └─BatchNorm2d: 2-2                  [1, 32, 112, 112]         64
# │    └─Swish: 2-3                        [1, 32, 112, 112]         --
# ├─ModuleList: 1-2                        --                        --
# │    └─MBConvBlock: 2-4                  [1, 16, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 32, 112, 112]         288
# │    │    └─BatchNorm2d: 3-2             [1, 32, 112, 112]         64
# │    │    └─Swish: 3-3                   [1, 32, 112, 112]         --
# │    │    └─SEBlock: 3-4                 [1, 32, 112, 112]         552
# │    │    └─Conv2d: 3-5                  [1, 16, 112, 112]         512
# │    │    └─BatchNorm2d: 3-6             [1, 16, 112, 112]         32
# │    └─MBConvBlock: 2-5                  [1, 24, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 96, 112, 112]         1,536
# │    │    └─BatchNorm2d: 3-8             [1, 96, 112, 112]         192
# │    │    └─Swish: 3-9                   [1, 96, 112, 112]         --
# │    │    └─Conv2d: 3-10                 [1, 96, 56, 56]           864
# │    │    └─BatchNorm2d: 3-11            [1, 96, 56, 56]           192
# │    │    └─Swish: 3-12                  [1, 96, 56, 56]           --
# │    │    └─SEBlock: 3-13                [1, 96, 56, 56]           4,728
# │    │    └─Conv2d: 3-14                 [1, 24, 56, 56]           2,304
# │    │    └─BatchNorm2d: 3-15            [1, 24, 56, 56]           48
# │    └─MBConvBlock: 2-6                  [1, 24, 56, 56]           --
# │    │    └─Conv2d: 3-16                 [1, 144, 56, 56]          3,456
# │    │    └─BatchNorm2d: 3-17            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-18                  [1, 144, 56, 56]          --
# │    │    └─Conv2d: 3-19                 [1, 144, 56, 56]          1,296
# │    │    └─BatchNorm2d: 3-20            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-21                  [1, 144, 56, 56]          --
# │    │    └─SEBlock: 3-22                [1, 144, 56, 56]          10,548
# │    │    └─Conv2d: 3-23                 [1, 24, 56, 56]           3,456
# │    │    └─BatchNorm2d: 3-24            [1, 24, 56, 56]           48
# │    └─MBConvBlock: 2-7                  [1, 24, 56, 56]           --
# │    │    └─Conv2d: 3-25                 [1, 144, 56, 56]          3,456
# │    │    └─BatchNorm2d: 3-26            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-27                  [1, 144, 56, 56]          --
# │    │    └─Conv2d: 3-28                 [1, 144, 56, 56]          1,296
# │    │    └─BatchNorm2d: 3-29            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-30                  [1, 144, 56, 56]          --
# │    │    └─SEBlock: 3-31                [1, 144, 56, 56]          10,548
# │    │    └─Conv2d: 3-32                 [1, 24, 56, 56]           3,456
# │    │    └─BatchNorm2d: 3-33            [1, 24, 56, 56]           48
# │    └─MBConvBlock: 2-8                  [1, 40, 28, 28]           --
# │    │    └─Conv2d: 3-34                 [1, 144, 56, 56]          3,456
# │    │    └─BatchNorm2d: 3-35            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-36                  [1, 144, 56, 56]          --
# │    │    └─Conv2d: 3-37                 [1, 144, 28, 28]          3,600
# │    │    └─BatchNorm2d: 3-38            [1, 144, 28, 28]          288
# │    │    └─Swish: 3-39                  [1, 144, 28, 28]          --
# │    │    └─SEBlock: 3-40                [1, 144, 28, 28]          10,548
# │    │    └─Conv2d: 3-41                 [1, 40, 28, 28]           5,760
# │    │    └─BatchNorm2d: 3-42            [1, 40, 28, 28]           80
# │    └─MBConvBlock: 2-9                  [1, 40, 28, 28]           --
# │    │    └─Conv2d: 3-43                 [1, 240, 28, 28]          9,600
# │    │    └─BatchNorm2d: 3-44            [1, 240, 28, 28]          480
# │    │    └─Swish: 3-45                  [1, 240, 28, 28]          --
# │    │    └─Conv2d: 3-46                 [1, 240, 28, 28]          6,000
# │    │    └─BatchNorm2d: 3-47            [1, 240, 28, 28]          480
# │    │    └─Swish: 3-48                  [1, 240, 28, 28]          --
# │    │    └─SEBlock: 3-49                [1, 240, 28, 28]          29,100
# │    │    └─Conv2d: 3-50                 [1, 40, 28, 28]           9,600
# │    │    └─BatchNorm2d: 3-51            [1, 40, 28, 28]           80
# │    └─MBConvBlock: 2-10                 [1, 40, 28, 28]           --
# │    │    └─Conv2d: 3-52                 [1, 240, 28, 28]          9,600
# │    │    └─BatchNorm2d: 3-53            [1, 240, 28, 28]          480
# │    │    └─Swish: 3-54                  [1, 240, 28, 28]          --
# │    │    └─Conv2d: 3-55                 [1, 240, 28, 28]          6,000
# │    │    └─BatchNorm2d: 3-56            [1, 240, 28, 28]          480
# │    │    └─Swish: 3-57                  [1, 240, 28, 28]          --
# │    │    └─SEBlock: 3-58                [1, 240, 28, 28]          29,100
# │    │    └─Conv2d: 3-59                 [1, 40, 28, 28]           9,600
# │    │    └─BatchNorm2d: 3-60            [1, 40, 28, 28]           80
# │    └─MBConvBlock: 2-11                 [1, 80, 14, 14]           --
# │    │    └─Conv2d: 3-61                 [1, 240, 28, 28]          9,600
# │    │    └─BatchNorm2d: 3-62            [1, 240, 28, 28]          480
# │    │    └─Swish: 3-63                  [1, 240, 28, 28]          --
# │    │    └─Conv2d: 3-64                 [1, 240, 14, 14]          2,160
# │    │    └─BatchNorm2d: 3-65            [1, 240, 14, 14]          480
# │    │    └─Swish: 3-66                  [1, 240, 14, 14]          --
# │    │    └─SEBlock: 3-67                [1, 240, 14, 14]          29,100
# │    │    └─Conv2d: 3-68                 [1, 80, 14, 14]           19,200
# │    │    └─BatchNorm2d: 3-69            [1, 80, 14, 14]           160
# │    └─MBConvBlock: 2-12                 [1, 80, 14, 14]           --
# │    │    └─Conv2d: 3-70                 [1, 480, 14, 14]          38,400
# │    │    └─BatchNorm2d: 3-71            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-72                  [1, 480, 14, 14]          --
# │    │    └─Conv2d: 3-73                 [1, 480, 14, 14]          4,320
# │    │    └─BatchNorm2d: 3-74            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-75                  [1, 480, 14, 14]          --
# │    │    └─SEBlock: 3-76                [1, 480, 14, 14]          115,800
# │    │    └─Conv2d: 3-77                 [1, 80, 14, 14]           38,400
# │    │    └─BatchNorm2d: 3-78            [1, 80, 14, 14]           160
# │    └─MBConvBlock: 2-13                 [1, 80, 14, 14]           --
# │    │    └─Conv2d: 3-79                 [1, 480, 14, 14]          38,400
# │    │    └─BatchNorm2d: 3-80            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-81                  [1, 480, 14, 14]          --
# │    │    └─Conv2d: 3-82                 [1, 480, 14, 14]          4,320
# │    │    └─BatchNorm2d: 3-83            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-84                  [1, 480, 14, 14]          --
# │    │    └─SEBlock: 3-85                [1, 480, 14, 14]          115,800
# │    │    └─Conv2d: 3-86                 [1, 80, 14, 14]           38,400
# │    │    └─BatchNorm2d: 3-87            [1, 80, 14, 14]           160
# │    └─MBConvBlock: 2-14                 [1, 80, 14, 14]           --
# │    │    └─Conv2d: 3-88                 [1, 480, 14, 14]          38,400
# │    │    └─BatchNorm2d: 3-89            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-90                  [1, 480, 14, 14]          --
# │    │    └─Conv2d: 3-91                 [1, 480, 14, 14]          4,320
# │    │    └─BatchNorm2d: 3-92            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-93                  [1, 480, 14, 14]          --
# │    │    └─SEBlock: 3-94                [1, 480, 14, 14]          115,800
# │    │    └─Conv2d: 3-95                 [1, 80, 14, 14]           38,400
# │    │    └─BatchNorm2d: 3-96            [1, 80, 14, 14]           160
# │    └─MBConvBlock: 2-15                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-97                 [1, 480, 14, 14]          38,400
# │    │    └─BatchNorm2d: 3-98            [1, 480, 14, 14]          960
# │    │    └─Swish: 3-99                  [1, 480, 14, 14]          --
# │    │    └─Conv2d: 3-100                [1, 480, 14, 14]          12,000
# │    │    └─BatchNorm2d: 3-101           [1, 480, 14, 14]          960
# │    │    └─Swish: 3-102                 [1, 480, 14, 14]          --
# │    │    └─SEBlock: 3-103               [1, 480, 14, 14]          115,800
# │    │    └─Conv2d: 3-104                [1, 112, 14, 14]          53,760
# │    │    └─BatchNorm2d: 3-105           [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-16                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-106                [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-107           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-108                 [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-109                [1, 672, 14, 14]          16,800
# │    │    └─BatchNorm2d: 3-110           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-111                 [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-112               [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-113                [1, 112, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-114           [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-17                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-115                [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-116           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-117                 [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-118                [1, 672, 14, 14]          16,800
# │    │    └─BatchNorm2d: 3-119           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-120                 [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-121               [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-122                [1, 112, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-123           [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-18                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-124                [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-125           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-126                 [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-127                [1, 672, 14, 14]          16,800
# │    │    └─BatchNorm2d: 3-128           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-129                 [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-130               [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-131                [1, 112, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-132           [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-19                 [1, 192, 7, 7]            --
# │    │    └─Conv2d: 3-133                [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-134           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-135                 [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-136                [1, 672, 7, 7]            16,800
# │    │    └─BatchNorm2d: 3-137           [1, 672, 7, 7]            1,344
# │    │    └─Swish: 3-138                 [1, 672, 7, 7]            --
# │    │    └─SEBlock: 3-139               [1, 672, 7, 7]            226,632
# │    │    └─Conv2d: 3-140                [1, 192, 7, 7]            129,024
# │    │    └─BatchNorm2d: 3-141           [1, 192, 7, 7]            384
# │    └─MBConvBlock: 2-20                 [1, 192, 7, 7]            --
# │    │    └─Conv2d: 3-142                [1, 1152, 7, 7]           221,184
# │    │    └─BatchNorm2d: 3-143           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-144                 [1, 1152, 7, 7]           --
# │    │    └─Conv2d: 3-145                [1, 1152, 7, 7]           28,800
# │    │    └─BatchNorm2d: 3-146           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-147                 [1, 1152, 7, 7]           --
# │    │    └─SEBlock: 3-148               [1, 1152, 7, 7]           664,992
# │    │    └─Conv2d: 3-149                [1, 192, 7, 7]            221,184
# │    │    └─BatchNorm2d: 3-150           [1, 192, 7, 7]            384
# │    └─MBConvBlock: 2-21                 [1, 192, 7, 7]            --
# │    │    └─Conv2d: 3-151                [1, 1152, 7, 7]           221,184
# │    │    └─BatchNorm2d: 3-152           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-153                 [1, 1152, 7, 7]           --
# │    │    └─Conv2d: 3-154                [1, 1152, 7, 7]           28,800
# │    │    └─BatchNorm2d: 3-155           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-156                 [1, 1152, 7, 7]           --
# │    │    └─SEBlock: 3-157               [1, 1152, 7, 7]           664,992
# │    │    └─Conv2d: 3-158                [1, 192, 7, 7]            221,184
# │    │    └─BatchNorm2d: 3-159           [1, 192, 7, 7]            384
# │    └─MBConvBlock: 2-22                 [1, 192, 7, 7]            --
# │    │    └─Conv2d: 3-160                [1, 1152, 7, 7]           221,184
# │    │    └─BatchNorm2d: 3-161           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-162                 [1, 1152, 7, 7]           --
# │    │    └─Conv2d: 3-163                [1, 1152, 7, 7]           28,800
# │    │    └─BatchNorm2d: 3-164           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-165                 [1, 1152, 7, 7]           --
# │    │    └─SEBlock: 3-166               [1, 1152, 7, 7]           664,992
# │    │    └─Conv2d: 3-167                [1, 192, 7, 7]            221,184
# │    │    └─BatchNorm2d: 3-168           [1, 192, 7, 7]            384
# │    └─MBConvBlock: 2-23                 [1, 192, 7, 7]            --
# │    │    └─Conv2d: 3-169                [1, 1152, 7, 7]           221,184
# │    │    └─BatchNorm2d: 3-170           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-171                 [1, 1152, 7, 7]           --
# │    │    └─Conv2d: 3-172                [1, 1152, 7, 7]           28,800
# │    │    └─BatchNorm2d: 3-173           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-174                 [1, 1152, 7, 7]           --
# │    │    └─SEBlock: 3-175               [1, 1152, 7, 7]           664,992
# │    │    └─Conv2d: 3-176                [1, 192, 7, 7]            221,184
# │    │    └─BatchNorm2d: 3-177           [1, 192, 7, 7]            384
# │    └─MBConvBlock: 2-24                 [1, 320, 7, 7]            --
# │    │    └─Conv2d: 3-178                [1, 1152, 7, 7]           221,184
# │    │    └─BatchNorm2d: 3-179           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-180                 [1, 1152, 7, 7]           --
# │    │    └─Conv2d: 3-181                [1, 1152, 7, 7]           10,368
# │    │    └─BatchNorm2d: 3-182           [1, 1152, 7, 7]           2,304
# │    │    └─Swish: 3-183                 [1, 1152, 7, 7]           --
# │    │    └─SEBlock: 3-184               [1, 1152, 7, 7]           664,992
# │    │    └─Conv2d: 3-185                [1, 320, 7, 7]            368,640
# │    │    └─BatchNorm2d: 3-186           [1, 320, 7, 7]            640
# │    └─MBConvBlock: 2-25                 [1, 320, 7, 7]            --
# │    │    └─Conv2d: 3-187                [1, 1920, 7, 7]           614,400
# │    │    └─BatchNorm2d: 3-188           [1, 1920, 7, 7]           3,840
# │    │    └─Swish: 3-189                 [1, 1920, 7, 7]           --
# │    │    └─Conv2d: 3-190                [1, 1920, 7, 7]           17,280
# │    │    └─BatchNorm2d: 3-191           [1, 1920, 7, 7]           3,840
# │    │    └─Swish: 3-192                 [1, 1920, 7, 7]           --
# │    │    └─SEBlock: 3-193               [1, 1920, 7, 7]           1,845,600
# │    │    └─Conv2d: 3-194                [1, 320, 7, 7]            614,400
# │    │    └─BatchNorm2d: 3-195           [1, 320, 7, 7]            640
# ├─Sequential: 1-3                        [1, 1000]                 --
# │    └─Conv2d: 2-26                      [1, 1280, 7, 7]           409,600
# │    └─BatchNorm2d: 2-27                 [1, 1280, 7, 7]           2,560
# │    └─Swish: 2-28                       [1, 1280, 7, 7]           --
# │    └─AdaptiveAvgPool2d: 2-29           [1, 1280, 1, 1]           --
# │    └─Flatten: 2-30                     [1, 1280]                 --
# │    └─Dropout: 2-31                     [1, 1280]                 --
# │    └─Linear: 2-32                      [1, 1000]                 1,281,000
# ==========================================================================================
# Total params: 13,335,592
# Trainable params: 13,335,592
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 570.25
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 143.17
# Params size (MB): 53.34
# Estimated Total Size (MB): 197.11
# ==========================================================================================

# %% [markdown]
# ### EfficientNet-B2

# %%
efficientnet_b2_1 = CustomEfficientNet(width_coefficient=1.1, depth_coefficient=1.2, dropout_rate=0.3, num_classes=1000)
efficientnet_b2_1
# Out:
# CustomEfficientNet(
#   (stem): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): ModuleList(
#     (0): MBConvBlock(
#       (depthwise): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (expand): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2-3): 2 x MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5-6): 2 x MBConvBlock(
#       (expand): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#       (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): MBConvBlock(
#       (expand): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#       (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(288, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8-10): 3 x MBConvBlock(
#       (expand): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#       (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(528, 132, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(132, 528, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (11): MBConvBlock(
#       (expand): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(528, 528, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=528, bias=False)
#       (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(528, 132, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(132, 528, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(528, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (12-14): 3 x MBConvBlock(
#       (expand): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#       (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(720, 180, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(180, 720, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (15): MBConvBlock(
#       (expand): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(720, 720, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=720, bias=False)
#       (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(720, 180, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(180, 720, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(720, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (16-19): 4 x MBConvBlock(
#       (expand): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#       (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1248, 312, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(312, 1248, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (20): MBConvBlock(
#       (expand): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1248, 1248, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1248, bias=False)
#       (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1248, 312, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(312, 1248, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1248, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (21): MBConvBlock(
#       (expand): Conv2d(352, 2112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(2112, 2112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2112, bias=False)
#       (bn1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(2112, 528, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(528, 2112, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(2112, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=1408, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b2_1, (1, 3, 224, 224), device='cpu')
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomEfficientNet                       [1, 1000]                 --
# ├─Sequential: 1-1                        [1, 32, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 32, 112, 112]         864
# │    └─BatchNorm2d: 2-2                  [1, 32, 112, 112]         64
# │    └─Swish: 2-3                        [1, 32, 112, 112]         --
# ├─ModuleList: 1-2                        --                        --
# │    └─MBConvBlock: 2-4                  [1, 16, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 32, 112, 112]         288
# │    │    └─BatchNorm2d: 3-2             [1, 32, 112, 112]         64
# │    │    └─Swish: 3-3                   [1, 32, 112, 112]         --
# │    │    └─SEBlock: 3-4                 [1, 32, 112, 112]         552
# │    │    └─Conv2d: 3-5                  [1, 16, 112, 112]         512
# │    │    └─BatchNorm2d: 3-6             [1, 16, 112, 112]         32
# │    └─MBConvBlock: 2-5                  [1, 24, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 96, 112, 112]         1,536
# │    │    └─BatchNorm2d: 3-8             [1, 96, 112, 112]         192
# │    │    └─Swish: 3-9                   [1, 96, 112, 112]         --
# │    │    └─Conv2d: 3-10                 [1, 96, 56, 56]           864
# │    │    └─BatchNorm2d: 3-11            [1, 96, 56, 56]           192
# │    │    └─Swish: 3-12                  [1, 96, 56, 56]           --
# │    │    └─SEBlock: 3-13                [1, 96, 56, 56]           4,728
# │    │    └─Conv2d: 3-14                 [1, 24, 56, 56]           2,304
# │    │    └─BatchNorm2d: 3-15            [1, 24, 56, 56]           48
# │    └─MBConvBlock: 2-6                  [1, 24, 56, 56]           --
# │    │    └─Conv2d: 3-16                 [1, 144, 56, 56]          3,456
# │    │    └─BatchNorm2d: 3-17            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-18                  [1, 144, 56, 56]          --
# │    │    └─Conv2d: 3-19                 [1, 144, 56, 56]          1,296
# │    │    └─BatchNorm2d: 3-20            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-21                  [1, 144, 56, 56]          --
# │    │    └─SEBlock: 3-22                [1, 144, 56, 56]          10,548
# │    │    └─Conv2d: 3-23                 [1, 24, 56, 56]           3,456
# │    │    └─BatchNorm2d: 3-24            [1, 24, 56, 56]           48
# │    └─MBConvBlock: 2-7                  [1, 24, 56, 56]           --
# │    │    └─Conv2d: 3-25                 [1, 144, 56, 56]          3,456
# │    │    └─BatchNorm2d: 3-26            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-27                  [1, 144, 56, 56]          --
# │    │    └─Conv2d: 3-28                 [1, 144, 56, 56]          1,296
# │    │    └─BatchNorm2d: 3-29            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-30                  [1, 144, 56, 56]          --
# │    │    └─SEBlock: 3-31                [1, 144, 56, 56]          10,548
# │    │    └─Conv2d: 3-32                 [1, 24, 56, 56]           3,456
# │    │    └─BatchNorm2d: 3-33            [1, 24, 56, 56]           48
# │    └─MBConvBlock: 2-8                  [1, 48, 28, 28]           --
# │    │    └─Conv2d: 3-34                 [1, 144, 56, 56]          3,456
# │    │    └─BatchNorm2d: 3-35            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-36                  [1, 144, 56, 56]          --
# │    │    └─Conv2d: 3-37                 [1, 144, 28, 28]          3,600
# │    │    └─BatchNorm2d: 3-38            [1, 144, 28, 28]          288
# │    │    └─Swish: 3-39                  [1, 144, 28, 28]          --
# │    │    └─SEBlock: 3-40                [1, 144, 28, 28]          10,548
# │    │    └─Conv2d: 3-41                 [1, 48, 28, 28]           6,912
# │    │    └─BatchNorm2d: 3-42            [1, 48, 28, 28]           96
# │    └─MBConvBlock: 2-9                  [1, 48, 28, 28]           --
# │    │    └─Conv2d: 3-43                 [1, 288, 28, 28]          13,824
# │    │    └─BatchNorm2d: 3-44            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-45                  [1, 288, 28, 28]          --
# │    │    └─Conv2d: 3-46                 [1, 288, 28, 28]          7,200
# │    │    └─BatchNorm2d: 3-47            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-48                  [1, 288, 28, 28]          --
# │    │    └─SEBlock: 3-49                [1, 288, 28, 28]          41,832
# │    │    └─Conv2d: 3-50                 [1, 48, 28, 28]           13,824
# │    │    └─BatchNorm2d: 3-51            [1, 48, 28, 28]           96
# │    └─MBConvBlock: 2-10                 [1, 48, 28, 28]           --
# │    │    └─Conv2d: 3-52                 [1, 288, 28, 28]          13,824
# │    │    └─BatchNorm2d: 3-53            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-54                  [1, 288, 28, 28]          --
# │    │    └─Conv2d: 3-55                 [1, 288, 28, 28]          7,200
# │    │    └─BatchNorm2d: 3-56            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-57                  [1, 288, 28, 28]          --
# │    │    └─SEBlock: 3-58                [1, 288, 28, 28]          41,832
# │    │    └─Conv2d: 3-59                 [1, 48, 28, 28]           13,824
# │    │    └─BatchNorm2d: 3-60            [1, 48, 28, 28]           96
# │    └─MBConvBlock: 2-11                 [1, 88, 14, 14]           --
# │    │    └─Conv2d: 3-61                 [1, 288, 28, 28]          13,824
# │    │    └─BatchNorm2d: 3-62            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-63                  [1, 288, 28, 28]          --
# │    │    └─Conv2d: 3-64                 [1, 288, 14, 14]          2,592
# │    │    └─BatchNorm2d: 3-65            [1, 288, 14, 14]          576
# │    │    └─Swish: 3-66                  [1, 288, 14, 14]          --
# │    │    └─SEBlock: 3-67                [1, 288, 14, 14]          41,832
# │    │    └─Conv2d: 3-68                 [1, 88, 14, 14]           25,344
# │    │    └─BatchNorm2d: 3-69            [1, 88, 14, 14]           176
# │    └─MBConvBlock: 2-12                 [1, 88, 14, 14]           --
# │    │    └─Conv2d: 3-70                 [1, 528, 14, 14]          46,464
# │    │    └─BatchNorm2d: 3-71            [1, 528, 14, 14]          1,056
# │    │    └─Swish: 3-72                  [1, 528, 14, 14]          --
# │    │    └─Conv2d: 3-73                 [1, 528, 14, 14]          4,752
# │    │    └─BatchNorm2d: 3-74            [1, 528, 14, 14]          1,056
# │    │    └─Swish: 3-75                  [1, 528, 14, 14]          --
# │    │    └─SEBlock: 3-76                [1, 528, 14, 14]          140,052
# │    │    └─Conv2d: 3-77                 [1, 88, 14, 14]           46,464
# │    │    └─BatchNorm2d: 3-78            [1, 88, 14, 14]           176
# │    └─MBConvBlock: 2-13                 [1, 88, 14, 14]           --
# │    │    └─Conv2d: 3-79                 [1, 528, 14, 14]          46,464
# │    │    └─BatchNorm2d: 3-80            [1, 528, 14, 14]          1,056
# │    │    └─Swish: 3-81                  [1, 528, 14, 14]          --
# │    │    └─Conv2d: 3-82                 [1, 528, 14, 14]          4,752
# │    │    └─BatchNorm2d: 3-83            [1, 528, 14, 14]          1,056
# │    │    └─Swish: 3-84                  [1, 528, 14, 14]          --
# │    │    └─SEBlock: 3-85                [1, 528, 14, 14]          140,052
# │    │    └─Conv2d: 3-86                 [1, 88, 14, 14]           46,464
# │    │    └─BatchNorm2d: 3-87            [1, 88, 14, 14]           176
# │    └─MBConvBlock: 2-14                 [1, 88, 14, 14]           --
# │    │    └─Conv2d: 3-88                 [1, 528, 14, 14]          46,464
# │    │    └─BatchNorm2d: 3-89            [1, 528, 14, 14]          1,056
# │    │    └─Swish: 3-90                  [1, 528, 14, 14]          --
# │    │    └─Conv2d: 3-91                 [1, 528, 14, 14]          4,752
# │    │    └─BatchNorm2d: 3-92            [1, 528, 14, 14]          1,056
# │    │    └─Swish: 3-93                  [1, 528, 14, 14]          --
# │    │    └─SEBlock: 3-94                [1, 528, 14, 14]          140,052
# │    │    └─Conv2d: 3-95                 [1, 88, 14, 14]           46,464
# │    │    └─BatchNorm2d: 3-96            [1, 88, 14, 14]           176
# │    └─MBConvBlock: 2-15                 [1, 120, 14, 14]          --
# │    │    └─Conv2d: 3-97                 [1, 528, 14, 14]          46,464
# │    │    └─BatchNorm2d: 3-98            [1, 528, 14, 14]          1,056
# │    │    └─Swish: 3-99                  [1, 528, 14, 14]          --
# │    │    └─Conv2d: 3-100                [1, 528, 14, 14]          13,200
# │    │    └─BatchNorm2d: 3-101           [1, 528, 14, 14]          1,056
# │    │    └─Swish: 3-102                 [1, 528, 14, 14]          --
# │    │    └─SEBlock: 3-103               [1, 528, 14, 14]          140,052
# │    │    └─Conv2d: 3-104                [1, 120, 14, 14]          63,360
# │    │    └─BatchNorm2d: 3-105           [1, 120, 14, 14]          240
# │    └─MBConvBlock: 2-16                 [1, 120, 14, 14]          --
# │    │    └─Conv2d: 3-106                [1, 720, 14, 14]          86,400
# │    │    └─BatchNorm2d: 3-107           [1, 720, 14, 14]          1,440
# │    │    └─Swish: 3-108                 [1, 720, 14, 14]          --
# │    │    └─Conv2d: 3-109                [1, 720, 14, 14]          18,000
# │    │    └─BatchNorm2d: 3-110           [1, 720, 14, 14]          1,440
# │    │    └─Swish: 3-111                 [1, 720, 14, 14]          --
# │    │    └─SEBlock: 3-112               [1, 720, 14, 14]          260,100
# │    │    └─Conv2d: 3-113                [1, 120, 14, 14]          86,400
# │    │    └─BatchNorm2d: 3-114           [1, 120, 14, 14]          240
# │    └─MBConvBlock: 2-17                 [1, 120, 14, 14]          --
# │    │    └─Conv2d: 3-115                [1, 720, 14, 14]          86,400
# │    │    └─BatchNorm2d: 3-116           [1, 720, 14, 14]          1,440
# │    │    └─Swish: 3-117                 [1, 720, 14, 14]          --
# │    │    └─Conv2d: 3-118                [1, 720, 14, 14]          18,000
# │    │    └─BatchNorm2d: 3-119           [1, 720, 14, 14]          1,440
# │    │    └─Swish: 3-120                 [1, 720, 14, 14]          --
# │    │    └─SEBlock: 3-121               [1, 720, 14, 14]          260,100
# │    │    └─Conv2d: 3-122                [1, 120, 14, 14]          86,400
# │    │    └─BatchNorm2d: 3-123           [1, 120, 14, 14]          240
# │    └─MBConvBlock: 2-18                 [1, 120, 14, 14]          --
# │    │    └─Conv2d: 3-124                [1, 720, 14, 14]          86,400
# │    │    └─BatchNorm2d: 3-125           [1, 720, 14, 14]          1,440
# │    │    └─Swish: 3-126                 [1, 720, 14, 14]          --
# │    │    └─Conv2d: 3-127                [1, 720, 14, 14]          18,000
# │    │    └─BatchNorm2d: 3-128           [1, 720, 14, 14]          1,440
# │    │    └─Swish: 3-129                 [1, 720, 14, 14]          --
# │    │    └─SEBlock: 3-130               [1, 720, 14, 14]          260,100
# │    │    └─Conv2d: 3-131                [1, 120, 14, 14]          86,400
# │    │    └─BatchNorm2d: 3-132           [1, 120, 14, 14]          240
# │    └─MBConvBlock: 2-19                 [1, 208, 7, 7]            --
# │    │    └─Conv2d: 3-133                [1, 720, 14, 14]          86,400
# │    │    └─BatchNorm2d: 3-134           [1, 720, 14, 14]          1,440
# │    │    └─Swish: 3-135                 [1, 720, 14, 14]          --
# │    │    └─Conv2d: 3-136                [1, 720, 7, 7]            18,000
# │    │    └─BatchNorm2d: 3-137           [1, 720, 7, 7]            1,440
# │    │    └─Swish: 3-138                 [1, 720, 7, 7]            --
# │    │    └─SEBlock: 3-139               [1, 720, 7, 7]            260,100
# │    │    └─Conv2d: 3-140                [1, 208, 7, 7]            149,760
# │    │    └─BatchNorm2d: 3-141           [1, 208, 7, 7]            416
# │    └─MBConvBlock: 2-20                 [1, 208, 7, 7]            --
# │    │    └─Conv2d: 3-142                [1, 1248, 7, 7]           259,584
# │    │    └─BatchNorm2d: 3-143           [1, 1248, 7, 7]           2,496
# │    │    └─Swish: 3-144                 [1, 1248, 7, 7]           --
# │    │    └─Conv2d: 3-145                [1, 1248, 7, 7]           31,200
# │    │    └─BatchNorm2d: 3-146           [1, 1248, 7, 7]           2,496
# │    │    └─Swish: 3-147                 [1, 1248, 7, 7]           --
# │    │    └─SEBlock: 3-148               [1, 1248, 7, 7]           780,312
# │    │    └─Conv2d: 3-149                [1, 208, 7, 7]            259,584
# │    │    └─BatchNorm2d: 3-150           [1, 208, 7, 7]            416
# │    └─MBConvBlock: 2-21                 [1, 208, 7, 7]            --
# │    │    └─Conv2d: 3-151                [1, 1248, 7, 7]           259,584
# │    │    └─BatchNorm2d: 3-152           [1, 1248, 7, 7]           2,496
# │    │    └─Swish: 3-153                 [1, 1248, 7, 7]           --
# │    │    └─Conv2d: 3-154                [1, 1248, 7, 7]           31,200
# │    │    └─BatchNorm2d: 3-155           [1, 1248, 7, 7]           2,496
# │    │    └─Swish: 3-156                 [1, 1248, 7, 7]           --
# │    │    └─SEBlock: 3-157               [1, 1248, 7, 7]           780,312
# │    │    └─Conv2d: 3-158                [1, 208, 7, 7]            259,584
# │    │    └─BatchNorm2d: 3-159           [1, 208, 7, 7]            416
# │    └─MBConvBlock: 2-22                 [1, 208, 7, 7]            --
# │    │    └─Conv2d: 3-160                [1, 1248, 7, 7]           259,584
# │    │    └─BatchNorm2d: 3-161           [1, 1248, 7, 7]           2,496
# │    │    └─Swish: 3-162                 [1, 1248, 7, 7]           --
# │    │    └─Conv2d: 3-163                [1, 1248, 7, 7]           31,200
# │    │    └─BatchNorm2d: 3-164           [1, 1248, 7, 7]           2,496
# │    │    └─Swish: 3-165                 [1, 1248, 7, 7]           --
# │    │    └─SEBlock: 3-166               [1, 1248, 7, 7]           780,312
# │    │    └─Conv2d: 3-167                [1, 208, 7, 7]            259,584
# │    │    └─BatchNorm2d: 3-168           [1, 208, 7, 7]            416
# │    └─MBConvBlock: 2-23                 [1, 208, 7, 7]            --
# │    │    └─Conv2d: 3-169                [1, 1248, 7, 7]           259,584
# │    │    └─BatchNorm2d: 3-170           [1, 1248, 7, 7]           2,496
# │    │    └─Swish: 3-171                 [1, 1248, 7, 7]           --
# │    │    └─Conv2d: 3-172                [1, 1248, 7, 7]           31,200
# │    │    └─BatchNorm2d: 3-173           [1, 1248, 7, 7]           2,496
# │    │    └─Swish: 3-174                 [1, 1248, 7, 7]           --
# │    │    └─SEBlock: 3-175               [1, 1248, 7, 7]           780,312
# │    │    └─Conv2d: 3-176                [1, 208, 7, 7]            259,584
# │    │    └─BatchNorm2d: 3-177           [1, 208, 7, 7]            416
# │    └─MBConvBlock: 2-24                 [1, 352, 7, 7]            --
# │    │    └─Conv2d: 3-178                [1, 1248, 7, 7]           259,584
# │    │    └─BatchNorm2d: 3-179           [1, 1248, 7, 7]           2,496
# │    │    └─Swish: 3-180                 [1, 1248, 7, 7]           --
# │    │    └─Conv2d: 3-181                [1, 1248, 7, 7]           11,232
# │    │    └─BatchNorm2d: 3-182           [1, 1248, 7, 7]           2,496
# │    │    └─Swish: 3-183                 [1, 1248, 7, 7]           --
# │    │    └─SEBlock: 3-184               [1, 1248, 7, 7]           780,312
# │    │    └─Conv2d: 3-185                [1, 352, 7, 7]            439,296
# │    │    └─BatchNorm2d: 3-186           [1, 352, 7, 7]            704
# │    └─MBConvBlock: 2-25                 [1, 352, 7, 7]            --
# │    │    └─Conv2d: 3-187                [1, 2112, 7, 7]           743,424
# │    │    └─BatchNorm2d: 3-188           [1, 2112, 7, 7]           4,224
# │    │    └─Swish: 3-189                 [1, 2112, 7, 7]           --
# │    │    └─Conv2d: 3-190                [1, 2112, 7, 7]           19,008
# │    │    └─BatchNorm2d: 3-191           [1, 2112, 7, 7]           4,224
# │    │    └─Swish: 3-192                 [1, 2112, 7, 7]           --
# │    │    └─SEBlock: 3-193               [1, 2112, 7, 7]           2,232,912
# │    │    └─Conv2d: 3-194                [1, 352, 7, 7]            743,424
# │    │    └─BatchNorm2d: 3-195           [1, 352, 7, 7]            704
# ├─Sequential: 1-3                        [1, 1000]                 --
# │    └─Conv2d: 2-26                      [1, 1408, 7, 7]           495,616
# │    └─BatchNorm2d: 2-27                 [1, 1408, 7, 7]           2,816
# │    └─Swish: 2-28                       [1, 1408, 7, 7]           --
# │    └─AdaptiveAvgPool2d: 2-29           [1, 1408, 1, 1]           --
# │    └─Flatten: 2-30                     [1, 1408]                 --
# │    └─Dropout: 2-31                     [1, 1408]                 --
# │    └─Linear: 2-32                      [1, 1000]                 1,409,000
# ==========================================================================================
# Total params: 15,677,892
# Trainable params: 15,677,892
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 660.60
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 150.41
# Params size (MB): 62.71
# Estimated Total Size (MB): 213.72
# ==========================================================================================

# %% [markdown]
# ### EfficientNet-B3

# %%
efficientnet_b3_1 = CustomEfficientNet(width_coefficient=1.2, depth_coefficient=1.4, dropout_rate=0.3, num_classes=1000)
efficientnet_b3_1
# Out:
# CustomEfficientNet(
#   (stem): Sequential(
#     (0): Conv2d(3, 40, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): ModuleList(
#     (0): MBConvBlock(
#       (depthwise): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#       (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(40, 10, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(10, 40, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(40, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2-3): 2 x MBConvBlock(
#       (expand): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#       (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): MBConvBlock(
#       (expand): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(192, 192, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=192, bias=False)
#       (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5-6): 2 x MBConvBlock(
#       (expand): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#       (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): MBConvBlock(
#       (expand): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#       (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8-11): 4 x MBConvBlock(
#       (expand): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#       (bn1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (12): MBConvBlock(
#       (expand): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#       (bn1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(576, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (13-16): 4 x MBConvBlock(
#       (expand): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#       (bn1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(816, 204, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(204, 816, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (17): MBConvBlock(
#       (expand): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(816, 816, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=816, bias=False)
#       (bn1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(816, 204, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(204, 816, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(816, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (18-22): 5 x MBConvBlock(
#       (expand): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#       (bn1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1392, 348, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(348, 1392, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (23): MBConvBlock(
#       (expand): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1392, 1392, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1392, bias=False)
#       (bn1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1392, 348, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(348, 1392, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1392, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (24): MBConvBlock(
#       (expand): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#       (bn1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(2304, 576, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(576, 2304, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=1536, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b3_1, (1, 3, 224, 224), device='cpu')
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomEfficientNet                       [1, 1000]                 --
# ├─Sequential: 1-1                        [1, 40, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 40, 112, 112]         1,080
# │    └─BatchNorm2d: 2-2                  [1, 40, 112, 112]         80
# │    └─Swish: 2-3                        [1, 40, 112, 112]         --
# ├─ModuleList: 1-2                        --                        --
# │    └─MBConvBlock: 2-4                  [1, 24, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 40, 112, 112]         360
# │    │    └─BatchNorm2d: 3-2             [1, 40, 112, 112]         80
# │    │    └─Swish: 3-3                   [1, 40, 112, 112]         --
# │    │    └─SEBlock: 3-4                 [1, 40, 112, 112]         850
# │    │    └─Conv2d: 3-5                  [1, 24, 112, 112]         960
# │    │    └─BatchNorm2d: 3-6             [1, 24, 112, 112]         48
# │    └─MBConvBlock: 2-5                  [1, 32, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 144, 112, 112]        3,456
# │    │    └─BatchNorm2d: 3-8             [1, 144, 112, 112]        288
# │    │    └─Swish: 3-9                   [1, 144, 112, 112]        --
# │    │    └─Conv2d: 3-10                 [1, 144, 56, 56]          1,296
# │    │    └─BatchNorm2d: 3-11            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-12                  [1, 144, 56, 56]          --
# │    │    └─SEBlock: 3-13                [1, 144, 56, 56]          10,548
# │    │    └─Conv2d: 3-14                 [1, 32, 56, 56]           4,608
# │    │    └─BatchNorm2d: 3-15            [1, 32, 56, 56]           64
# │    └─MBConvBlock: 2-6                  [1, 32, 56, 56]           --
# │    │    └─Conv2d: 3-16                 [1, 192, 56, 56]          6,144
# │    │    └─BatchNorm2d: 3-17            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-18                  [1, 192, 56, 56]          --
# │    │    └─Conv2d: 3-19                 [1, 192, 56, 56]          1,728
# │    │    └─BatchNorm2d: 3-20            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-21                  [1, 192, 56, 56]          --
# │    │    └─SEBlock: 3-22                [1, 192, 56, 56]          18,672
# │    │    └─Conv2d: 3-23                 [1, 32, 56, 56]           6,144
# │    │    └─BatchNorm2d: 3-24            [1, 32, 56, 56]           64
# │    └─MBConvBlock: 2-7                  [1, 32, 56, 56]           --
# │    │    └─Conv2d: 3-25                 [1, 192, 56, 56]          6,144
# │    │    └─BatchNorm2d: 3-26            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-27                  [1, 192, 56, 56]          --
# │    │    └─Conv2d: 3-28                 [1, 192, 56, 56]          1,728
# │    │    └─BatchNorm2d: 3-29            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-30                  [1, 192, 56, 56]          --
# │    │    └─SEBlock: 3-31                [1, 192, 56, 56]          18,672
# │    │    └─Conv2d: 3-32                 [1, 32, 56, 56]           6,144
# │    │    └─BatchNorm2d: 3-33            [1, 32, 56, 56]           64
# │    └─MBConvBlock: 2-8                  [1, 48, 28, 28]           --
# │    │    └─Conv2d: 3-34                 [1, 192, 56, 56]          6,144
# │    │    └─BatchNorm2d: 3-35            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-36                  [1, 192, 56, 56]          --
# │    │    └─Conv2d: 3-37                 [1, 192, 28, 28]          4,800
# │    │    └─BatchNorm2d: 3-38            [1, 192, 28, 28]          384
# │    │    └─Swish: 3-39                  [1, 192, 28, 28]          --
# │    │    └─SEBlock: 3-40                [1, 192, 28, 28]          18,672
# │    │    └─Conv2d: 3-41                 [1, 48, 28, 28]           9,216
# │    │    └─BatchNorm2d: 3-42            [1, 48, 28, 28]           96
# │    └─MBConvBlock: 2-9                  [1, 48, 28, 28]           --
# │    │    └─Conv2d: 3-43                 [1, 288, 28, 28]          13,824
# │    │    └─BatchNorm2d: 3-44            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-45                  [1, 288, 28, 28]          --
# │    │    └─Conv2d: 3-46                 [1, 288, 28, 28]          7,200
# │    │    └─BatchNorm2d: 3-47            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-48                  [1, 288, 28, 28]          --
# │    │    └─SEBlock: 3-49                [1, 288, 28, 28]          41,832
# │    │    └─Conv2d: 3-50                 [1, 48, 28, 28]           13,824
# │    │    └─BatchNorm2d: 3-51            [1, 48, 28, 28]           96
# │    └─MBConvBlock: 2-10                 [1, 48, 28, 28]           --
# │    │    └─Conv2d: 3-52                 [1, 288, 28, 28]          13,824
# │    │    └─BatchNorm2d: 3-53            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-54                  [1, 288, 28, 28]          --
# │    │    └─Conv2d: 3-55                 [1, 288, 28, 28]          7,200
# │    │    └─BatchNorm2d: 3-56            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-57                  [1, 288, 28, 28]          --
# │    │    └─SEBlock: 3-58                [1, 288, 28, 28]          41,832
# │    │    └─Conv2d: 3-59                 [1, 48, 28, 28]           13,824
# │    │    └─BatchNorm2d: 3-60            [1, 48, 28, 28]           96
# │    └─MBConvBlock: 2-11                 [1, 96, 14, 14]           --
# │    │    └─Conv2d: 3-61                 [1, 288, 28, 28]          13,824
# │    │    └─BatchNorm2d: 3-62            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-63                  [1, 288, 28, 28]          --
# │    │    └─Conv2d: 3-64                 [1, 288, 14, 14]          2,592
# │    │    └─BatchNorm2d: 3-65            [1, 288, 14, 14]          576
# │    │    └─Swish: 3-66                  [1, 288, 14, 14]          --
# │    │    └─SEBlock: 3-67                [1, 288, 14, 14]          41,832
# │    │    └─Conv2d: 3-68                 [1, 96, 14, 14]           27,648
# │    │    └─BatchNorm2d: 3-69            [1, 96, 14, 14]           192
# │    └─MBConvBlock: 2-12                 [1, 96, 14, 14]           --
# │    │    └─Conv2d: 3-70                 [1, 576, 14, 14]          55,296
# │    │    └─BatchNorm2d: 3-71            [1, 576, 14, 14]          1,152
# │    │    └─Swish: 3-72                  [1, 576, 14, 14]          --
# │    │    └─Conv2d: 3-73                 [1, 576, 14, 14]          5,184
# │    │    └─BatchNorm2d: 3-74            [1, 576, 14, 14]          1,152
# │    │    └─Swish: 3-75                  [1, 576, 14, 14]          --
# │    │    └─SEBlock: 3-76                [1, 576, 14, 14]          166,608
# │    │    └─Conv2d: 3-77                 [1, 96, 14, 14]           55,296
# │    │    └─BatchNorm2d: 3-78            [1, 96, 14, 14]           192
# │    └─MBConvBlock: 2-13                 [1, 96, 14, 14]           --
# │    │    └─Conv2d: 3-79                 [1, 576, 14, 14]          55,296
# │    │    └─BatchNorm2d: 3-80            [1, 576, 14, 14]          1,152
# │    │    └─Swish: 3-81                  [1, 576, 14, 14]          --
# │    │    └─Conv2d: 3-82                 [1, 576, 14, 14]          5,184
# │    │    └─BatchNorm2d: 3-83            [1, 576, 14, 14]          1,152
# │    │    └─Swish: 3-84                  [1, 576, 14, 14]          --
# │    │    └─SEBlock: 3-85                [1, 576, 14, 14]          166,608
# │    │    └─Conv2d: 3-86                 [1, 96, 14, 14]           55,296
# │    │    └─BatchNorm2d: 3-87            [1, 96, 14, 14]           192
# │    └─MBConvBlock: 2-14                 [1, 96, 14, 14]           --
# │    │    └─Conv2d: 3-88                 [1, 576, 14, 14]          55,296
# │    │    └─BatchNorm2d: 3-89            [1, 576, 14, 14]          1,152
# │    │    └─Swish: 3-90                  [1, 576, 14, 14]          --
# │    │    └─Conv2d: 3-91                 [1, 576, 14, 14]          5,184
# │    │    └─BatchNorm2d: 3-92            [1, 576, 14, 14]          1,152
# │    │    └─Swish: 3-93                  [1, 576, 14, 14]          --
# │    │    └─SEBlock: 3-94                [1, 576, 14, 14]          166,608
# │    │    └─Conv2d: 3-95                 [1, 96, 14, 14]           55,296
# │    │    └─BatchNorm2d: 3-96            [1, 96, 14, 14]           192
# │    └─MBConvBlock: 2-15                 [1, 96, 14, 14]           --
# │    │    └─Conv2d: 3-97                 [1, 576, 14, 14]          55,296
# │    │    └─BatchNorm2d: 3-98            [1, 576, 14, 14]          1,152
# │    │    └─Swish: 3-99                  [1, 576, 14, 14]          --
# │    │    └─Conv2d: 3-100                [1, 576, 14, 14]          5,184
# │    │    └─BatchNorm2d: 3-101           [1, 576, 14, 14]          1,152
# │    │    └─Swish: 3-102                 [1, 576, 14, 14]          --
# │    │    └─SEBlock: 3-103               [1, 576, 14, 14]          166,608
# │    │    └─Conv2d: 3-104                [1, 96, 14, 14]           55,296
# │    │    └─BatchNorm2d: 3-105           [1, 96, 14, 14]           192
# │    └─MBConvBlock: 2-16                 [1, 136, 14, 14]          --
# │    │    └─Conv2d: 3-106                [1, 576, 14, 14]          55,296
# │    │    └─BatchNorm2d: 3-107           [1, 576, 14, 14]          1,152
# │    │    └─Swish: 3-108                 [1, 576, 14, 14]          --
# │    │    └─Conv2d: 3-109                [1, 576, 14, 14]          14,400
# │    │    └─BatchNorm2d: 3-110           [1, 576, 14, 14]          1,152
# │    │    └─Swish: 3-111                 [1, 576, 14, 14]          --
# │    │    └─SEBlock: 3-112               [1, 576, 14, 14]          166,608
# │    │    └─Conv2d: 3-113                [1, 136, 14, 14]          78,336
# │    │    └─BatchNorm2d: 3-114           [1, 136, 14, 14]          272
# │    └─MBConvBlock: 2-17                 [1, 136, 14, 14]          --
# │    │    └─Conv2d: 3-115                [1, 816, 14, 14]          110,976
# │    │    └─BatchNorm2d: 3-116           [1, 816, 14, 14]          1,632
# │    │    └─Swish: 3-117                 [1, 816, 14, 14]          --
# │    │    └─Conv2d: 3-118                [1, 816, 14, 14]          20,400
# │    │    └─BatchNorm2d: 3-119           [1, 816, 14, 14]          1,632
# │    │    └─Swish: 3-120                 [1, 816, 14, 14]          --
# │    │    └─SEBlock: 3-121               [1, 816, 14, 14]          333,948
# │    │    └─Conv2d: 3-122                [1, 136, 14, 14]          110,976
# │    │    └─BatchNorm2d: 3-123           [1, 136, 14, 14]          272
# │    └─MBConvBlock: 2-18                 [1, 136, 14, 14]          --
# │    │    └─Conv2d: 3-124                [1, 816, 14, 14]          110,976
# │    │    └─BatchNorm2d: 3-125           [1, 816, 14, 14]          1,632
# │    │    └─Swish: 3-126                 [1, 816, 14, 14]          --
# │    │    └─Conv2d: 3-127                [1, 816, 14, 14]          20,400
# │    │    └─BatchNorm2d: 3-128           [1, 816, 14, 14]          1,632
# │    │    └─Swish: 3-129                 [1, 816, 14, 14]          --
# │    │    └─SEBlock: 3-130               [1, 816, 14, 14]          333,948
# │    │    └─Conv2d: 3-131                [1, 136, 14, 14]          110,976
# │    │    └─BatchNorm2d: 3-132           [1, 136, 14, 14]          272
# │    └─MBConvBlock: 2-19                 [1, 136, 14, 14]          --
# │    │    └─Conv2d: 3-133                [1, 816, 14, 14]          110,976
# │    │    └─BatchNorm2d: 3-134           [1, 816, 14, 14]          1,632
# │    │    └─Swish: 3-135                 [1, 816, 14, 14]          --
# │    │    └─Conv2d: 3-136                [1, 816, 14, 14]          20,400
# │    │    └─BatchNorm2d: 3-137           [1, 816, 14, 14]          1,632
# │    │    └─Swish: 3-138                 [1, 816, 14, 14]          --
# │    │    └─SEBlock: 3-139               [1, 816, 14, 14]          333,948
# │    │    └─Conv2d: 3-140                [1, 136, 14, 14]          110,976
# │    │    └─BatchNorm2d: 3-141           [1, 136, 14, 14]          272
# │    └─MBConvBlock: 2-20                 [1, 136, 14, 14]          --
# │    │    └─Conv2d: 3-142                [1, 816, 14, 14]          110,976
# │    │    └─BatchNorm2d: 3-143           [1, 816, 14, 14]          1,632
# │    │    └─Swish: 3-144                 [1, 816, 14, 14]          --
# │    │    └─Conv2d: 3-145                [1, 816, 14, 14]          20,400
# │    │    └─BatchNorm2d: 3-146           [1, 816, 14, 14]          1,632
# │    │    └─Swish: 3-147                 [1, 816, 14, 14]          --
# │    │    └─SEBlock: 3-148               [1, 816, 14, 14]          333,948
# │    │    └─Conv2d: 3-149                [1, 136, 14, 14]          110,976
# │    │    └─BatchNorm2d: 3-150           [1, 136, 14, 14]          272
# │    └─MBConvBlock: 2-21                 [1, 232, 7, 7]            --
# │    │    └─Conv2d: 3-151                [1, 816, 14, 14]          110,976
# │    │    └─BatchNorm2d: 3-152           [1, 816, 14, 14]          1,632
# │    │    └─Swish: 3-153                 [1, 816, 14, 14]          --
# │    │    └─Conv2d: 3-154                [1, 816, 7, 7]            20,400
# │    │    └─BatchNorm2d: 3-155           [1, 816, 7, 7]            1,632
# │    │    └─Swish: 3-156                 [1, 816, 7, 7]            --
# │    │    └─SEBlock: 3-157               [1, 816, 7, 7]            333,948
# │    │    └─Conv2d: 3-158                [1, 232, 7, 7]            189,312
# │    │    └─BatchNorm2d: 3-159           [1, 232, 7, 7]            464
# │    └─MBConvBlock: 2-22                 [1, 232, 7, 7]            --
# │    │    └─Conv2d: 3-160                [1, 1392, 7, 7]           322,944
# │    │    └─BatchNorm2d: 3-161           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-162                 [1, 1392, 7, 7]           --
# │    │    └─Conv2d: 3-163                [1, 1392, 7, 7]           34,800
# │    │    └─BatchNorm2d: 3-164           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-165                 [1, 1392, 7, 7]           --
# │    │    └─SEBlock: 3-166               [1, 1392, 7, 7]           970,572
# │    │    └─Conv2d: 3-167                [1, 232, 7, 7]            322,944
# │    │    └─BatchNorm2d: 3-168           [1, 232, 7, 7]            464
# │    └─MBConvBlock: 2-23                 [1, 232, 7, 7]            --
# │    │    └─Conv2d: 3-169                [1, 1392, 7, 7]           322,944
# │    │    └─BatchNorm2d: 3-170           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-171                 [1, 1392, 7, 7]           --
# │    │    └─Conv2d: 3-172                [1, 1392, 7, 7]           34,800
# │    │    └─BatchNorm2d: 3-173           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-174                 [1, 1392, 7, 7]           --
# │    │    └─SEBlock: 3-175               [1, 1392, 7, 7]           970,572
# │    │    └─Conv2d: 3-176                [1, 232, 7, 7]            322,944
# │    │    └─BatchNorm2d: 3-177           [1, 232, 7, 7]            464
# │    └─MBConvBlock: 2-24                 [1, 232, 7, 7]            --
# │    │    └─Conv2d: 3-178                [1, 1392, 7, 7]           322,944
# │    │    └─BatchNorm2d: 3-179           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-180                 [1, 1392, 7, 7]           --
# │    │    └─Conv2d: 3-181                [1, 1392, 7, 7]           34,800
# │    │    └─BatchNorm2d: 3-182           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-183                 [1, 1392, 7, 7]           --
# │    │    └─SEBlock: 3-184               [1, 1392, 7, 7]           970,572
# │    │    └─Conv2d: 3-185                [1, 232, 7, 7]            322,944
# │    │    └─BatchNorm2d: 3-186           [1, 232, 7, 7]            464
# │    └─MBConvBlock: 2-25                 [1, 232, 7, 7]            --
# │    │    └─Conv2d: 3-187                [1, 1392, 7, 7]           322,944
# │    │    └─BatchNorm2d: 3-188           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-189                 [1, 1392, 7, 7]           --
# │    │    └─Conv2d: 3-190                [1, 1392, 7, 7]           34,800
# │    │    └─BatchNorm2d: 3-191           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-192                 [1, 1392, 7, 7]           --
# │    │    └─SEBlock: 3-193               [1, 1392, 7, 7]           970,572
# │    │    └─Conv2d: 3-194                [1, 232, 7, 7]            322,944
# │    │    └─BatchNorm2d: 3-195           [1, 232, 7, 7]            464
# │    └─MBConvBlock: 2-26                 [1, 232, 7, 7]            --
# │    │    └─Conv2d: 3-196                [1, 1392, 7, 7]           322,944
# │    │    └─BatchNorm2d: 3-197           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-198                 [1, 1392, 7, 7]           --
# │    │    └─Conv2d: 3-199                [1, 1392, 7, 7]           34,800
# │    │    └─BatchNorm2d: 3-200           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-201                 [1, 1392, 7, 7]           --
# │    │    └─SEBlock: 3-202               [1, 1392, 7, 7]           970,572
# │    │    └─Conv2d: 3-203                [1, 232, 7, 7]            322,944
# │    │    └─BatchNorm2d: 3-204           [1, 232, 7, 7]            464
# │    └─MBConvBlock: 2-27                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-205                [1, 1392, 7, 7]           322,944
# │    │    └─BatchNorm2d: 3-206           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-207                 [1, 1392, 7, 7]           --
# │    │    └─Conv2d: 3-208                [1, 1392, 7, 7]           12,528
# │    │    └─BatchNorm2d: 3-209           [1, 1392, 7, 7]           2,784
# │    │    └─Swish: 3-210                 [1, 1392, 7, 7]           --
# │    │    └─SEBlock: 3-211               [1, 1392, 7, 7]           970,572
# │    │    └─Conv2d: 3-212                [1, 384, 7, 7]            534,528
# │    │    └─BatchNorm2d: 3-213           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-28                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-214                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-215           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-216                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-217                [1, 2304, 7, 7]           20,736
# │    │    └─BatchNorm2d: 3-218           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-219                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-220               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-221                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-222           [1, 384, 7, 7]            768
# ├─Sequential: 1-3                        [1, 1000]                 --
# │    └─Conv2d: 2-29                      [1, 1536, 7, 7]           589,824
# │    └─BatchNorm2d: 2-30                 [1, 1536, 7, 7]           3,072
# │    └─Swish: 2-31                       [1, 1536, 7, 7]           --
# │    └─AdaptiveAvgPool2d: 2-32           [1, 1536, 1, 1]           --
# │    └─Flatten: 2-33                     [1, 1536]                 --
# │    └─Dropout: 2-34                     [1, 1536]                 --
# │    └─Linear: 2-35                      [1, 1000]                 1,537,000
# ==========================================================================================
# Total params: 21,528,826
# Trainable params: 21,528,826
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 962.18
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 198.35
# Params size (MB): 86.12
# Estimated Total Size (MB): 285.06
# ==========================================================================================

# %% [markdown]
# ### EfficientNet-B4

# %%
efficientnet_b4_1 = CustomEfficientNet(width_coefficient=1.4, depth_coefficient=1.8, dropout_rate=0.4, num_classes=1000)
efficientnet_b4_1
# Out:
# CustomEfficientNet(
#   (stem): Sequential(
#     (0): Conv2d(3, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): ModuleList(
#     (0): MBConvBlock(
#       (depthwise): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#       (bn1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2-4): 3 x MBConvBlock(
#       (expand): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#       (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): MBConvBlock(
#       (expand): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(192, 192, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=192, bias=False)
#       (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(192, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6-8): 3 x MBConvBlock(
#       (expand): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336, bias=False)
#       (bn1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(336, 84, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(84, 336, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (9): MBConvBlock(
#       (expand): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(336, 336, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=336, bias=False)
#       (bn1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(336, 84, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(84, 336, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(336, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (10-14): 5 x MBConvBlock(
#       (expand): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#       (bn1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (15): MBConvBlock(
#       (expand): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#       (bn1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(672, 168, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(168, 672, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (16-20): 5 x MBConvBlock(
#       (expand): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#       (bn1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (21): MBConvBlock(
#       (expand): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(960, 960, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=960, bias=False)
#       (bn1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(960, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (22-28): 7 x MBConvBlock(
#       (expand): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#       (bn1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1632, 408, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(408, 1632, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (29): MBConvBlock(
#       (expand): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1632, 1632, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1632, bias=False)
#       (bn1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1632, 408, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(408, 1632, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1632, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (30): MBConvBlock(
#       (expand): Conv2d(448, 2688, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(2688, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(2688, 2688, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2688, bias=False)
#       (bn1): BatchNorm2d(2688, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(2688, 672, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(672, 2688, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(2688, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(448, 1792, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Linear(in_features=1792, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b4_1, (1, 3, 224, 224), device='cpu')
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomEfficientNet                       [1, 1000]                 --
# ├─Sequential: 1-1                        [1, 48, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 48, 112, 112]         1,296
# │    └─BatchNorm2d: 2-2                  [1, 48, 112, 112]         96
# │    └─Swish: 2-3                        [1, 48, 112, 112]         --
# ├─ModuleList: 1-2                        --                        --
# │    └─MBConvBlock: 2-4                  [1, 24, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 48, 112, 112]         432
# │    │    └─BatchNorm2d: 3-2             [1, 48, 112, 112]         96
# │    │    └─Swish: 3-3                   [1, 48, 112, 112]         --
# │    │    └─SEBlock: 3-4                 [1, 48, 112, 112]         1,212
# │    │    └─Conv2d: 3-5                  [1, 24, 112, 112]         1,152
# │    │    └─BatchNorm2d: 3-6             [1, 24, 112, 112]         48
# │    └─MBConvBlock: 2-5                  [1, 32, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 144, 112, 112]        3,456
# │    │    └─BatchNorm2d: 3-8             [1, 144, 112, 112]        288
# │    │    └─Swish: 3-9                   [1, 144, 112, 112]        --
# │    │    └─Conv2d: 3-10                 [1, 144, 56, 56]          1,296
# │    │    └─BatchNorm2d: 3-11            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-12                  [1, 144, 56, 56]          --
# │    │    └─SEBlock: 3-13                [1, 144, 56, 56]          10,548
# │    │    └─Conv2d: 3-14                 [1, 32, 56, 56]           4,608
# │    │    └─BatchNorm2d: 3-15            [1, 32, 56, 56]           64
# │    └─MBConvBlock: 2-6                  [1, 32, 56, 56]           --
# │    │    └─Conv2d: 3-16                 [1, 192, 56, 56]          6,144
# │    │    └─BatchNorm2d: 3-17            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-18                  [1, 192, 56, 56]          --
# │    │    └─Conv2d: 3-19                 [1, 192, 56, 56]          1,728
# │    │    └─BatchNorm2d: 3-20            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-21                  [1, 192, 56, 56]          --
# │    │    └─SEBlock: 3-22                [1, 192, 56, 56]          18,672
# │    │    └─Conv2d: 3-23                 [1, 32, 56, 56]           6,144
# │    │    └─BatchNorm2d: 3-24            [1, 32, 56, 56]           64
# │    └─MBConvBlock: 2-7                  [1, 32, 56, 56]           --
# │    │    └─Conv2d: 3-25                 [1, 192, 56, 56]          6,144
# │    │    └─BatchNorm2d: 3-26            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-27                  [1, 192, 56, 56]          --
# │    │    └─Conv2d: 3-28                 [1, 192, 56, 56]          1,728
# │    │    └─BatchNorm2d: 3-29            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-30                  [1, 192, 56, 56]          --
# │    │    └─SEBlock: 3-31                [1, 192, 56, 56]          18,672
# │    │    └─Conv2d: 3-32                 [1, 32, 56, 56]           6,144
# │    │    └─BatchNorm2d: 3-33            [1, 32, 56, 56]           64
# │    └─MBConvBlock: 2-8                  [1, 32, 56, 56]           --
# │    │    └─Conv2d: 3-34                 [1, 192, 56, 56]          6,144
# │    │    └─BatchNorm2d: 3-35            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-36                  [1, 192, 56, 56]          --
# │    │    └─Conv2d: 3-37                 [1, 192, 56, 56]          1,728
# │    │    └─BatchNorm2d: 3-38            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-39                  [1, 192, 56, 56]          --
# │    │    └─SEBlock: 3-40                [1, 192, 56, 56]          18,672
# │    │    └─Conv2d: 3-41                 [1, 32, 56, 56]           6,144
# │    │    └─BatchNorm2d: 3-42            [1, 32, 56, 56]           64
# │    └─MBConvBlock: 2-9                  [1, 56, 28, 28]           --
# │    │    └─Conv2d: 3-43                 [1, 192, 56, 56]          6,144
# │    │    └─BatchNorm2d: 3-44            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-45                  [1, 192, 56, 56]          --
# │    │    └─Conv2d: 3-46                 [1, 192, 28, 28]          4,800
# │    │    └─BatchNorm2d: 3-47            [1, 192, 28, 28]          384
# │    │    └─Swish: 3-48                  [1, 192, 28, 28]          --
# │    │    └─SEBlock: 3-49                [1, 192, 28, 28]          18,672
# │    │    └─Conv2d: 3-50                 [1, 56, 28, 28]           10,752
# │    │    └─BatchNorm2d: 3-51            [1, 56, 28, 28]           112
# │    └─MBConvBlock: 2-10                 [1, 56, 28, 28]           --
# │    │    └─Conv2d: 3-52                 [1, 336, 28, 28]          18,816
# │    │    └─BatchNorm2d: 3-53            [1, 336, 28, 28]          672
# │    │    └─Swish: 3-54                  [1, 336, 28, 28]          --
# │    │    └─Conv2d: 3-55                 [1, 336, 28, 28]          8,400
# │    │    └─BatchNorm2d: 3-56            [1, 336, 28, 28]          672
# │    │    └─Swish: 3-57                  [1, 336, 28, 28]          --
# │    │    └─SEBlock: 3-58                [1, 336, 28, 28]          56,868
# │    │    └─Conv2d: 3-59                 [1, 56, 28, 28]           18,816
# │    │    └─BatchNorm2d: 3-60            [1, 56, 28, 28]           112
# │    └─MBConvBlock: 2-11                 [1, 56, 28, 28]           --
# │    │    └─Conv2d: 3-61                 [1, 336, 28, 28]          18,816
# │    │    └─BatchNorm2d: 3-62            [1, 336, 28, 28]          672
# │    │    └─Swish: 3-63                  [1, 336, 28, 28]          --
# │    │    └─Conv2d: 3-64                 [1, 336, 28, 28]          8,400
# │    │    └─BatchNorm2d: 3-65            [1, 336, 28, 28]          672
# │    │    └─Swish: 3-66                  [1, 336, 28, 28]          --
# │    │    └─SEBlock: 3-67                [1, 336, 28, 28]          56,868
# │    │    └─Conv2d: 3-68                 [1, 56, 28, 28]           18,816
# │    │    └─BatchNorm2d: 3-69            [1, 56, 28, 28]           112
# │    └─MBConvBlock: 2-12                 [1, 56, 28, 28]           --
# │    │    └─Conv2d: 3-70                 [1, 336, 28, 28]          18,816
# │    │    └─BatchNorm2d: 3-71            [1, 336, 28, 28]          672
# │    │    └─Swish: 3-72                  [1, 336, 28, 28]          --
# │    │    └─Conv2d: 3-73                 [1, 336, 28, 28]          8,400
# │    │    └─BatchNorm2d: 3-74            [1, 336, 28, 28]          672
# │    │    └─Swish: 3-75                  [1, 336, 28, 28]          --
# │    │    └─SEBlock: 3-76                [1, 336, 28, 28]          56,868
# │    │    └─Conv2d: 3-77                 [1, 56, 28, 28]           18,816
# │    │    └─BatchNorm2d: 3-78            [1, 56, 28, 28]           112
# │    └─MBConvBlock: 2-13                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-79                 [1, 336, 28, 28]          18,816
# │    │    └─BatchNorm2d: 3-80            [1, 336, 28, 28]          672
# │    │    └─Swish: 3-81                  [1, 336, 28, 28]          --
# │    │    └─Conv2d: 3-82                 [1, 336, 14, 14]          3,024
# │    │    └─BatchNorm2d: 3-83            [1, 336, 14, 14]          672
# │    │    └─Swish: 3-84                  [1, 336, 14, 14]          --
# │    │    └─SEBlock: 3-85                [1, 336, 14, 14]          56,868
# │    │    └─Conv2d: 3-86                 [1, 112, 14, 14]          37,632
# │    │    └─BatchNorm2d: 3-87            [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-14                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-88                 [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-89            [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-90                  [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-91                 [1, 672, 14, 14]          6,048
# │    │    └─BatchNorm2d: 3-92            [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-93                  [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-94                [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-95                 [1, 112, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-96            [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-15                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-97                 [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-98            [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-99                  [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-100                [1, 672, 14, 14]          6,048
# │    │    └─BatchNorm2d: 3-101           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-102                 [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-103               [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-104                [1, 112, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-105           [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-16                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-106                [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-107           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-108                 [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-109                [1, 672, 14, 14]          6,048
# │    │    └─BatchNorm2d: 3-110           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-111                 [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-112               [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-113                [1, 112, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-114           [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-17                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-115                [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-116           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-117                 [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-118                [1, 672, 14, 14]          6,048
# │    │    └─BatchNorm2d: 3-119           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-120                 [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-121               [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-122                [1, 112, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-123           [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-18                 [1, 112, 14, 14]          --
# │    │    └─Conv2d: 3-124                [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-125           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-126                 [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-127                [1, 672, 14, 14]          6,048
# │    │    └─BatchNorm2d: 3-128           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-129                 [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-130               [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-131                [1, 112, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-132           [1, 112, 14, 14]          224
# │    └─MBConvBlock: 2-19                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-133                [1, 672, 14, 14]          75,264
# │    │    └─BatchNorm2d: 3-134           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-135                 [1, 672, 14, 14]          --
# │    │    └─Conv2d: 3-136                [1, 672, 14, 14]          16,800
# │    │    └─BatchNorm2d: 3-137           [1, 672, 14, 14]          1,344
# │    │    └─Swish: 3-138                 [1, 672, 14, 14]          --
# │    │    └─SEBlock: 3-139               [1, 672, 14, 14]          226,632
# │    │    └─Conv2d: 3-140                [1, 160, 14, 14]          107,520
# │    │    └─BatchNorm2d: 3-141           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-20                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-142                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-143           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-144                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-145                [1, 960, 14, 14]          24,000
# │    │    └─BatchNorm2d: 3-146           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-147                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-148               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-149                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-150           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-21                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-151                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-152           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-153                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-154                [1, 960, 14, 14]          24,000
# │    │    └─BatchNorm2d: 3-155           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-156                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-157               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-158                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-159           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-22                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-160                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-161           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-162                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-163                [1, 960, 14, 14]          24,000
# │    │    └─BatchNorm2d: 3-164           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-165                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-166               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-167                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-168           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-23                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-169                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-170           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-171                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-172                [1, 960, 14, 14]          24,000
# │    │    └─BatchNorm2d: 3-173           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-174                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-175               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-176                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-177           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-24                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-178                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-179           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-180                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-181                [1, 960, 14, 14]          24,000
# │    │    └─BatchNorm2d: 3-182           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-183                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-184               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-185                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-186           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-25                 [1, 272, 7, 7]            --
# │    │    └─Conv2d: 3-187                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-188           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-189                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-190                [1, 960, 7, 7]            24,000
# │    │    └─BatchNorm2d: 3-191           [1, 960, 7, 7]            1,920
# │    │    └─Swish: 3-192                 [1, 960, 7, 7]            --
# │    │    └─SEBlock: 3-193               [1, 960, 7, 7]            462,000
# │    │    └─Conv2d: 3-194                [1, 272, 7, 7]            261,120
# │    │    └─BatchNorm2d: 3-195           [1, 272, 7, 7]            544
# │    └─MBConvBlock: 2-26                 [1, 272, 7, 7]            --
# │    │    └─Conv2d: 3-196                [1, 1632, 7, 7]           443,904
# │    │    └─BatchNorm2d: 3-197           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-198                 [1, 1632, 7, 7]           --
# │    │    └─Conv2d: 3-199                [1, 1632, 7, 7]           40,800
# │    │    └─BatchNorm2d: 3-200           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-201                 [1, 1632, 7, 7]           --
# │    │    └─SEBlock: 3-202               [1, 1632, 7, 7]           1,333,752
# │    │    └─Conv2d: 3-203                [1, 272, 7, 7]            443,904
# │    │    └─BatchNorm2d: 3-204           [1, 272, 7, 7]            544
# │    └─MBConvBlock: 2-27                 [1, 272, 7, 7]            --
# │    │    └─Conv2d: 3-205                [1, 1632, 7, 7]           443,904
# │    │    └─BatchNorm2d: 3-206           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-207                 [1, 1632, 7, 7]           --
# │    │    └─Conv2d: 3-208                [1, 1632, 7, 7]           40,800
# │    │    └─BatchNorm2d: 3-209           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-210                 [1, 1632, 7, 7]           --
# │    │    └─SEBlock: 3-211               [1, 1632, 7, 7]           1,333,752
# │    │    └─Conv2d: 3-212                [1, 272, 7, 7]            443,904
# │    │    └─BatchNorm2d: 3-213           [1, 272, 7, 7]            544
# │    └─MBConvBlock: 2-28                 [1, 272, 7, 7]            --
# │    │    └─Conv2d: 3-214                [1, 1632, 7, 7]           443,904
# │    │    └─BatchNorm2d: 3-215           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-216                 [1, 1632, 7, 7]           --
# │    │    └─Conv2d: 3-217                [1, 1632, 7, 7]           40,800
# │    │    └─BatchNorm2d: 3-218           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-219                 [1, 1632, 7, 7]           --
# │    │    └─SEBlock: 3-220               [1, 1632, 7, 7]           1,333,752
# │    │    └─Conv2d: 3-221                [1, 272, 7, 7]            443,904
# │    │    └─BatchNorm2d: 3-222           [1, 272, 7, 7]            544
# │    └─MBConvBlock: 2-29                 [1, 272, 7, 7]            --
# │    │    └─Conv2d: 3-223                [1, 1632, 7, 7]           443,904
# │    │    └─BatchNorm2d: 3-224           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-225                 [1, 1632, 7, 7]           --
# │    │    └─Conv2d: 3-226                [1, 1632, 7, 7]           40,800
# │    │    └─BatchNorm2d: 3-227           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-228                 [1, 1632, 7, 7]           --
# │    │    └─SEBlock: 3-229               [1, 1632, 7, 7]           1,333,752
# │    │    └─Conv2d: 3-230                [1, 272, 7, 7]            443,904
# │    │    └─BatchNorm2d: 3-231           [1, 272, 7, 7]            544
# │    └─MBConvBlock: 2-30                 [1, 272, 7, 7]            --
# │    │    └─Conv2d: 3-232                [1, 1632, 7, 7]           443,904
# │    │    └─BatchNorm2d: 3-233           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-234                 [1, 1632, 7, 7]           --
# │    │    └─Conv2d: 3-235                [1, 1632, 7, 7]           40,800
# │    │    └─BatchNorm2d: 3-236           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-237                 [1, 1632, 7, 7]           --
# │    │    └─SEBlock: 3-238               [1, 1632, 7, 7]           1,333,752
# │    │    └─Conv2d: 3-239                [1, 272, 7, 7]            443,904
# │    │    └─BatchNorm2d: 3-240           [1, 272, 7, 7]            544
# │    └─MBConvBlock: 2-31                 [1, 272, 7, 7]            --
# │    │    └─Conv2d: 3-241                [1, 1632, 7, 7]           443,904
# │    │    └─BatchNorm2d: 3-242           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-243                 [1, 1632, 7, 7]           --
# │    │    └─Conv2d: 3-244                [1, 1632, 7, 7]           40,800
# │    │    └─BatchNorm2d: 3-245           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-246                 [1, 1632, 7, 7]           --
# │    │    └─SEBlock: 3-247               [1, 1632, 7, 7]           1,333,752
# │    │    └─Conv2d: 3-248                [1, 272, 7, 7]            443,904
# │    │    └─BatchNorm2d: 3-249           [1, 272, 7, 7]            544
# │    └─MBConvBlock: 2-32                 [1, 272, 7, 7]            --
# │    │    └─Conv2d: 3-250                [1, 1632, 7, 7]           443,904
# │    │    └─BatchNorm2d: 3-251           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-252                 [1, 1632, 7, 7]           --
# │    │    └─Conv2d: 3-253                [1, 1632, 7, 7]           40,800
# │    │    └─BatchNorm2d: 3-254           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-255                 [1, 1632, 7, 7]           --
# │    │    └─SEBlock: 3-256               [1, 1632, 7, 7]           1,333,752
# │    │    └─Conv2d: 3-257                [1, 272, 7, 7]            443,904
# │    │    └─BatchNorm2d: 3-258           [1, 272, 7, 7]            544
# │    └─MBConvBlock: 2-33                 [1, 448, 7, 7]            --
# │    │    └─Conv2d: 3-259                [1, 1632, 7, 7]           443,904
# │    │    └─BatchNorm2d: 3-260           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-261                 [1, 1632, 7, 7]           --
# │    │    └─Conv2d: 3-262                [1, 1632, 7, 7]           14,688
# │    │    └─BatchNorm2d: 3-263           [1, 1632, 7, 7]           3,264
# │    │    └─Swish: 3-264                 [1, 1632, 7, 7]           --
# │    │    └─SEBlock: 3-265               [1, 1632, 7, 7]           1,333,752
# │    │    └─Conv2d: 3-266                [1, 448, 7, 7]            731,136
# │    │    └─BatchNorm2d: 3-267           [1, 448, 7, 7]            896
# │    └─MBConvBlock: 2-34                 [1, 448, 7, 7]            --
# │    │    └─Conv2d: 3-268                [1, 2688, 7, 7]           1,204,224
# │    │    └─BatchNorm2d: 3-269           [1, 2688, 7, 7]           5,376
# │    │    └─Swish: 3-270                 [1, 2688, 7, 7]           --
# │    │    └─Conv2d: 3-271                [1, 2688, 7, 7]           24,192
# │    │    └─BatchNorm2d: 3-272           [1, 2688, 7, 7]           5,376
# │    │    └─Swish: 3-273                 [1, 2688, 7, 7]           --
# │    │    └─SEBlock: 3-274               [1, 2688, 7, 7]           3,616,032
# │    │    └─Conv2d: 3-275                [1, 448, 7, 7]            1,204,224
# │    │    └─BatchNorm2d: 3-276           [1, 448, 7, 7]            896
# ├─Sequential: 1-3                        [1, 1000]                 --
# │    └─Conv2d: 2-35                      [1, 1792, 7, 7]           802,816
# │    └─BatchNorm2d: 2-36                 [1, 1792, 7, 7]           3,584
# │    └─Swish: 2-37                       [1, 1792, 7, 7]           --
# │    └─AdaptiveAvgPool2d: 2-38           [1, 1792, 1, 1]           --
# │    └─Flatten: 2-39                     [1, 1792]                 --
# │    └─Dropout: 2-40                     [1, 1792]                 --
# │    └─Linear: 2-41                      [1, 1000]                 1,793,000
# ==========================================================================================
# Total params: 34,926,040
# Trainable params: 34,926,040
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.51
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 262.91
# Params size (MB): 139.70
# Estimated Total Size (MB): 403.21
# ==========================================================================================

# %% [markdown]
# ### EfficientNet-B5

# %%
efficientnet_b5_1 = CustomEfficientNet(width_coefficient=1.6, depth_coefficient=2.2, dropout_rate=0.4, num_classes=1000)
efficientnet_b5_1
# Out:
# CustomEfficientNet(
#   (stem): Sequential(
#     (0): Conv2d(3, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): ModuleList(
#     (0): MBConvBlock(
#       (depthwise): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#       (bn1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (expand): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(144, 36, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(36, 144, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2-5): 4 x MBConvBlock(
#       (expand): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): MBConvBlock(
#       (expand): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=240, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7-10): 4 x MBConvBlock(
#       (expand): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(384, 384, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=384, bias=False)
#       (bn1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (11): MBConvBlock(
#       (expand): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#       (bn1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (12-17): 6 x MBConvBlock(
#       (expand): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#       (bn1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (18): MBConvBlock(
#       (expand): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#       (bn1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(192, 768, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(768, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (19-24): 6 x MBConvBlock(
#       (expand): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1056, 1056, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1056, bias=False)
#       (bn1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1056, 264, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(264, 1056, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(176, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (25): MBConvBlock(
#       (expand): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1056, 1056, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=1056, bias=False)
#       (bn1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1056, 264, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(264, 1056, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1056, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (26-33): 8 x MBConvBlock(
#       (expand): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1824, 1824, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1824, bias=False)
#       (bn1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1824, 456, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(456, 1824, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (34): MBConvBlock(
#       (expand): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#       (bn1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1824, 456, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(456, 1824, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1824, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (35-36): 2 x MBConvBlock(
#       (expand): Conv2d(512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(3072, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#       (bn1): BatchNorm2d(3072, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(3072, 768, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(768, 3072, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Linear(in_features=2048, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b5_1, (1, 3, 224, 224), device='cpu')
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomEfficientNet                       [1, 1000]                 --
# ├─Sequential: 1-1                        [1, 48, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 48, 112, 112]         1,296
# │    └─BatchNorm2d: 2-2                  [1, 48, 112, 112]         96
# │    └─Swish: 2-3                        [1, 48, 112, 112]         --
# ├─ModuleList: 1-2                        --                        --
# │    └─MBConvBlock: 2-4                  [1, 24, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 48, 112, 112]         432
# │    │    └─BatchNorm2d: 3-2             [1, 48, 112, 112]         96
# │    │    └─Swish: 3-3                   [1, 48, 112, 112]         --
# │    │    └─SEBlock: 3-4                 [1, 48, 112, 112]         1,212
# │    │    └─Conv2d: 3-5                  [1, 24, 112, 112]         1,152
# │    │    └─BatchNorm2d: 3-6             [1, 24, 112, 112]         48
# │    └─MBConvBlock: 2-5                  [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 144, 112, 112]        3,456
# │    │    └─BatchNorm2d: 3-8             [1, 144, 112, 112]        288
# │    │    └─Swish: 3-9                   [1, 144, 112, 112]        --
# │    │    └─Conv2d: 3-10                 [1, 144, 56, 56]          1,296
# │    │    └─BatchNorm2d: 3-11            [1, 144, 56, 56]          288
# │    │    └─Swish: 3-12                  [1, 144, 56, 56]          --
# │    │    └─SEBlock: 3-13                [1, 144, 56, 56]          10,548
# │    │    └─Conv2d: 3-14                 [1, 40, 56, 56]           5,760
# │    │    └─BatchNorm2d: 3-15            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-6                  [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-16                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-17            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-18                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-19                 [1, 240, 56, 56]          2,160
# │    │    └─BatchNorm2d: 3-20            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-21                  [1, 240, 56, 56]          --
# │    │    └─SEBlock: 3-22                [1, 240, 56, 56]          29,100
# │    │    └─Conv2d: 3-23                 [1, 40, 56, 56]           9,600
# │    │    └─BatchNorm2d: 3-24            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-7                  [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-25                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-26            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-27                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-28                 [1, 240, 56, 56]          2,160
# │    │    └─BatchNorm2d: 3-29            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-30                  [1, 240, 56, 56]          --
# │    │    └─SEBlock: 3-31                [1, 240, 56, 56]          29,100
# │    │    └─Conv2d: 3-32                 [1, 40, 56, 56]           9,600
# │    │    └─BatchNorm2d: 3-33            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-8                  [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-34                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-35            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-36                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-37                 [1, 240, 56, 56]          2,160
# │    │    └─BatchNorm2d: 3-38            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-39                  [1, 240, 56, 56]          --
# │    │    └─SEBlock: 3-40                [1, 240, 56, 56]          29,100
# │    │    └─Conv2d: 3-41                 [1, 40, 56, 56]           9,600
# │    │    └─BatchNorm2d: 3-42            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-9                  [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-43                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-44            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-45                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-46                 [1, 240, 56, 56]          2,160
# │    │    └─BatchNorm2d: 3-47            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-48                  [1, 240, 56, 56]          --
# │    │    └─SEBlock: 3-49                [1, 240, 56, 56]          29,100
# │    │    └─Conv2d: 3-50                 [1, 40, 56, 56]           9,600
# │    │    └─BatchNorm2d: 3-51            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-10                 [1, 64, 28, 28]           --
# │    │    └─Conv2d: 3-52                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-53            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-54                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-55                 [1, 240, 28, 28]          6,000
# │    │    └─BatchNorm2d: 3-56            [1, 240, 28, 28]          480
# │    │    └─Swish: 3-57                  [1, 240, 28, 28]          --
# │    │    └─SEBlock: 3-58                [1, 240, 28, 28]          29,100
# │    │    └─Conv2d: 3-59                 [1, 64, 28, 28]           15,360
# │    │    └─BatchNorm2d: 3-60            [1, 64, 28, 28]           128
# │    └─MBConvBlock: 2-11                 [1, 64, 28, 28]           --
# │    │    └─Conv2d: 3-61                 [1, 384, 28, 28]          24,576
# │    │    └─BatchNorm2d: 3-62            [1, 384, 28, 28]          768
# │    │    └─Swish: 3-63                  [1, 384, 28, 28]          --
# │    │    └─Conv2d: 3-64                 [1, 384, 28, 28]          9,600
# │    │    └─BatchNorm2d: 3-65            [1, 384, 28, 28]          768
# │    │    └─Swish: 3-66                  [1, 384, 28, 28]          --
# │    │    └─SEBlock: 3-67                [1, 384, 28, 28]          74,208
# │    │    └─Conv2d: 3-68                 [1, 64, 28, 28]           24,576
# │    │    └─BatchNorm2d: 3-69            [1, 64, 28, 28]           128
# │    └─MBConvBlock: 2-12                 [1, 64, 28, 28]           --
# │    │    └─Conv2d: 3-70                 [1, 384, 28, 28]          24,576
# │    │    └─BatchNorm2d: 3-71            [1, 384, 28, 28]          768
# │    │    └─Swish: 3-72                  [1, 384, 28, 28]          --
# │    │    └─Conv2d: 3-73                 [1, 384, 28, 28]          9,600
# │    │    └─BatchNorm2d: 3-74            [1, 384, 28, 28]          768
# │    │    └─Swish: 3-75                  [1, 384, 28, 28]          --
# │    │    └─SEBlock: 3-76                [1, 384, 28, 28]          74,208
# │    │    └─Conv2d: 3-77                 [1, 64, 28, 28]           24,576
# │    │    └─BatchNorm2d: 3-78            [1, 64, 28, 28]           128
# │    └─MBConvBlock: 2-13                 [1, 64, 28, 28]           --
# │    │    └─Conv2d: 3-79                 [1, 384, 28, 28]          24,576
# │    │    └─BatchNorm2d: 3-80            [1, 384, 28, 28]          768
# │    │    └─Swish: 3-81                  [1, 384, 28, 28]          --
# │    │    └─Conv2d: 3-82                 [1, 384, 28, 28]          9,600
# │    │    └─BatchNorm2d: 3-83            [1, 384, 28, 28]          768
# │    │    └─Swish: 3-84                  [1, 384, 28, 28]          --
# │    │    └─SEBlock: 3-85                [1, 384, 28, 28]          74,208
# │    │    └─Conv2d: 3-86                 [1, 64, 28, 28]           24,576
# │    │    └─BatchNorm2d: 3-87            [1, 64, 28, 28]           128
# │    └─MBConvBlock: 2-14                 [1, 64, 28, 28]           --
# │    │    └─Conv2d: 3-88                 [1, 384, 28, 28]          24,576
# │    │    └─BatchNorm2d: 3-89            [1, 384, 28, 28]          768
# │    │    └─Swish: 3-90                  [1, 384, 28, 28]          --
# │    │    └─Conv2d: 3-91                 [1, 384, 28, 28]          9,600
# │    │    └─BatchNorm2d: 3-92            [1, 384, 28, 28]          768
# │    │    └─Swish: 3-93                  [1, 384, 28, 28]          --
# │    │    └─SEBlock: 3-94                [1, 384, 28, 28]          74,208
# │    │    └─Conv2d: 3-95                 [1, 64, 28, 28]           24,576
# │    │    └─BatchNorm2d: 3-96            [1, 64, 28, 28]           128
# │    └─MBConvBlock: 2-15                 [1, 128, 14, 14]          --
# │    │    └─Conv2d: 3-97                 [1, 384, 28, 28]          24,576
# │    │    └─BatchNorm2d: 3-98            [1, 384, 28, 28]          768
# │    │    └─Swish: 3-99                  [1, 384, 28, 28]          --
# │    │    └─Conv2d: 3-100                [1, 384, 14, 14]          3,456
# │    │    └─BatchNorm2d: 3-101           [1, 384, 14, 14]          768
# │    │    └─Swish: 3-102                 [1, 384, 14, 14]          --
# │    │    └─SEBlock: 3-103               [1, 384, 14, 14]          74,208
# │    │    └─Conv2d: 3-104                [1, 128, 14, 14]          49,152
# │    │    └─BatchNorm2d: 3-105           [1, 128, 14, 14]          256
# │    └─MBConvBlock: 2-16                 [1, 128, 14, 14]          --
# │    │    └─Conv2d: 3-106                [1, 768, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-107           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-108                 [1, 768, 14, 14]          --
# │    │    └─Conv2d: 3-109                [1, 768, 14, 14]          6,912
# │    │    └─BatchNorm2d: 3-110           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-111                 [1, 768, 14, 14]          --
# │    │    └─SEBlock: 3-112               [1, 768, 14, 14]          295,872
# │    │    └─Conv2d: 3-113                [1, 128, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-114           [1, 128, 14, 14]          256
# │    └─MBConvBlock: 2-17                 [1, 128, 14, 14]          --
# │    │    └─Conv2d: 3-115                [1, 768, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-116           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-117                 [1, 768, 14, 14]          --
# │    │    └─Conv2d: 3-118                [1, 768, 14, 14]          6,912
# │    │    └─BatchNorm2d: 3-119           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-120                 [1, 768, 14, 14]          --
# │    │    └─SEBlock: 3-121               [1, 768, 14, 14]          295,872
# │    │    └─Conv2d: 3-122                [1, 128, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-123           [1, 128, 14, 14]          256
# │    └─MBConvBlock: 2-18                 [1, 128, 14, 14]          --
# │    │    └─Conv2d: 3-124                [1, 768, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-125           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-126                 [1, 768, 14, 14]          --
# │    │    └─Conv2d: 3-127                [1, 768, 14, 14]          6,912
# │    │    └─BatchNorm2d: 3-128           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-129                 [1, 768, 14, 14]          --
# │    │    └─SEBlock: 3-130               [1, 768, 14, 14]          295,872
# │    │    └─Conv2d: 3-131                [1, 128, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-132           [1, 128, 14, 14]          256
# │    └─MBConvBlock: 2-19                 [1, 128, 14, 14]          --
# │    │    └─Conv2d: 3-133                [1, 768, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-134           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-135                 [1, 768, 14, 14]          --
# │    │    └─Conv2d: 3-136                [1, 768, 14, 14]          6,912
# │    │    └─BatchNorm2d: 3-137           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-138                 [1, 768, 14, 14]          --
# │    │    └─SEBlock: 3-139               [1, 768, 14, 14]          295,872
# │    │    └─Conv2d: 3-140                [1, 128, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-141           [1, 128, 14, 14]          256
# │    └─MBConvBlock: 2-20                 [1, 128, 14, 14]          --
# │    │    └─Conv2d: 3-142                [1, 768, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-143           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-144                 [1, 768, 14, 14]          --
# │    │    └─Conv2d: 3-145                [1, 768, 14, 14]          6,912
# │    │    └─BatchNorm2d: 3-146           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-147                 [1, 768, 14, 14]          --
# │    │    └─SEBlock: 3-148               [1, 768, 14, 14]          295,872
# │    │    └─Conv2d: 3-149                [1, 128, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-150           [1, 128, 14, 14]          256
# │    └─MBConvBlock: 2-21                 [1, 128, 14, 14]          --
# │    │    └─Conv2d: 3-151                [1, 768, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-152           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-153                 [1, 768, 14, 14]          --
# │    │    └─Conv2d: 3-154                [1, 768, 14, 14]          6,912
# │    │    └─BatchNorm2d: 3-155           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-156                 [1, 768, 14, 14]          --
# │    │    └─SEBlock: 3-157               [1, 768, 14, 14]          295,872
# │    │    └─Conv2d: 3-158                [1, 128, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-159           [1, 128, 14, 14]          256
# │    └─MBConvBlock: 2-22                 [1, 176, 14, 14]          --
# │    │    └─Conv2d: 3-160                [1, 768, 14, 14]          98,304
# │    │    └─BatchNorm2d: 3-161           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-162                 [1, 768, 14, 14]          --
# │    │    └─Conv2d: 3-163                [1, 768, 14, 14]          19,200
# │    │    └─BatchNorm2d: 3-164           [1, 768, 14, 14]          1,536
# │    │    └─Swish: 3-165                 [1, 768, 14, 14]          --
# │    │    └─SEBlock: 3-166               [1, 768, 14, 14]          295,872
# │    │    └─Conv2d: 3-167                [1, 176, 14, 14]          135,168
# │    │    └─BatchNorm2d: 3-168           [1, 176, 14, 14]          352
# │    └─MBConvBlock: 2-23                 [1, 176, 14, 14]          --
# │    │    └─Conv2d: 3-169                [1, 1056, 14, 14]         185,856
# │    │    └─BatchNorm2d: 3-170           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-171                 [1, 1056, 14, 14]         --
# │    │    └─Conv2d: 3-172                [1, 1056, 14, 14]         26,400
# │    │    └─BatchNorm2d: 3-173           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-174                 [1, 1056, 14, 14]         --
# │    │    └─SEBlock: 3-175               [1, 1056, 14, 14]         558,888
# │    │    └─Conv2d: 3-176                [1, 176, 14, 14]          185,856
# │    │    └─BatchNorm2d: 3-177           [1, 176, 14, 14]          352
# │    └─MBConvBlock: 2-24                 [1, 176, 14, 14]          --
# │    │    └─Conv2d: 3-178                [1, 1056, 14, 14]         185,856
# │    │    └─BatchNorm2d: 3-179           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-180                 [1, 1056, 14, 14]         --
# │    │    └─Conv2d: 3-181                [1, 1056, 14, 14]         26,400
# │    │    └─BatchNorm2d: 3-182           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-183                 [1, 1056, 14, 14]         --
# │    │    └─SEBlock: 3-184               [1, 1056, 14, 14]         558,888
# │    │    └─Conv2d: 3-185                [1, 176, 14, 14]          185,856
# │    │    └─BatchNorm2d: 3-186           [1, 176, 14, 14]          352
# │    └─MBConvBlock: 2-25                 [1, 176, 14, 14]          --
# │    │    └─Conv2d: 3-187                [1, 1056, 14, 14]         185,856
# │    │    └─BatchNorm2d: 3-188           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-189                 [1, 1056, 14, 14]         --
# │    │    └─Conv2d: 3-190                [1, 1056, 14, 14]         26,400
# │    │    └─BatchNorm2d: 3-191           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-192                 [1, 1056, 14, 14]         --
# │    │    └─SEBlock: 3-193               [1, 1056, 14, 14]         558,888
# │    │    └─Conv2d: 3-194                [1, 176, 14, 14]          185,856
# │    │    └─BatchNorm2d: 3-195           [1, 176, 14, 14]          352
# │    └─MBConvBlock: 2-26                 [1, 176, 14, 14]          --
# │    │    └─Conv2d: 3-196                [1, 1056, 14, 14]         185,856
# │    │    └─BatchNorm2d: 3-197           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-198                 [1, 1056, 14, 14]         --
# │    │    └─Conv2d: 3-199                [1, 1056, 14, 14]         26,400
# │    │    └─BatchNorm2d: 3-200           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-201                 [1, 1056, 14, 14]         --
# │    │    └─SEBlock: 3-202               [1, 1056, 14, 14]         558,888
# │    │    └─Conv2d: 3-203                [1, 176, 14, 14]          185,856
# │    │    └─BatchNorm2d: 3-204           [1, 176, 14, 14]          352
# │    └─MBConvBlock: 2-27                 [1, 176, 14, 14]          --
# │    │    └─Conv2d: 3-205                [1, 1056, 14, 14]         185,856
# │    │    └─BatchNorm2d: 3-206           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-207                 [1, 1056, 14, 14]         --
# │    │    └─Conv2d: 3-208                [1, 1056, 14, 14]         26,400
# │    │    └─BatchNorm2d: 3-209           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-210                 [1, 1056, 14, 14]         --
# │    │    └─SEBlock: 3-211               [1, 1056, 14, 14]         558,888
# │    │    └─Conv2d: 3-212                [1, 176, 14, 14]          185,856
# │    │    └─BatchNorm2d: 3-213           [1, 176, 14, 14]          352
# │    └─MBConvBlock: 2-28                 [1, 176, 14, 14]          --
# │    │    └─Conv2d: 3-214                [1, 1056, 14, 14]         185,856
# │    │    └─BatchNorm2d: 3-215           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-216                 [1, 1056, 14, 14]         --
# │    │    └─Conv2d: 3-217                [1, 1056, 14, 14]         26,400
# │    │    └─BatchNorm2d: 3-218           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-219                 [1, 1056, 14, 14]         --
# │    │    └─SEBlock: 3-220               [1, 1056, 14, 14]         558,888
# │    │    └─Conv2d: 3-221                [1, 176, 14, 14]          185,856
# │    │    └─BatchNorm2d: 3-222           [1, 176, 14, 14]          352
# │    └─MBConvBlock: 2-29                 [1, 304, 7, 7]            --
# │    │    └─Conv2d: 3-223                [1, 1056, 14, 14]         185,856
# │    │    └─BatchNorm2d: 3-224           [1, 1056, 14, 14]         2,112
# │    │    └─Swish: 3-225                 [1, 1056, 14, 14]         --
# │    │    └─Conv2d: 3-226                [1, 1056, 7, 7]           26,400
# │    │    └─BatchNorm2d: 3-227           [1, 1056, 7, 7]           2,112
# │    │    └─Swish: 3-228                 [1, 1056, 7, 7]           --
# │    │    └─SEBlock: 3-229               [1, 1056, 7, 7]           558,888
# │    │    └─Conv2d: 3-230                [1, 304, 7, 7]            321,024
# │    │    └─BatchNorm2d: 3-231           [1, 304, 7, 7]            608
# │    └─MBConvBlock: 2-30                 [1, 304, 7, 7]            --
# │    │    └─Conv2d: 3-232                [1, 1824, 7, 7]           554,496
# │    │    └─BatchNorm2d: 3-233           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-234                 [1, 1824, 7, 7]           --
# │    │    └─Conv2d: 3-235                [1, 1824, 7, 7]           45,600
# │    │    └─BatchNorm2d: 3-236           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-237                 [1, 1824, 7, 7]           --
# │    │    └─SEBlock: 3-238               [1, 1824, 7, 7]           1,665,768
# │    │    └─Conv2d: 3-239                [1, 304, 7, 7]            554,496
# │    │    └─BatchNorm2d: 3-240           [1, 304, 7, 7]            608
# │    └─MBConvBlock: 2-31                 [1, 304, 7, 7]            --
# │    │    └─Conv2d: 3-241                [1, 1824, 7, 7]           554,496
# │    │    └─BatchNorm2d: 3-242           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-243                 [1, 1824, 7, 7]           --
# │    │    └─Conv2d: 3-244                [1, 1824, 7, 7]           45,600
# │    │    └─BatchNorm2d: 3-245           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-246                 [1, 1824, 7, 7]           --
# │    │    └─SEBlock: 3-247               [1, 1824, 7, 7]           1,665,768
# │    │    └─Conv2d: 3-248                [1, 304, 7, 7]            554,496
# │    │    └─BatchNorm2d: 3-249           [1, 304, 7, 7]            608
# │    └─MBConvBlock: 2-32                 [1, 304, 7, 7]            --
# │    │    └─Conv2d: 3-250                [1, 1824, 7, 7]           554,496
# │    │    └─BatchNorm2d: 3-251           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-252                 [1, 1824, 7, 7]           --
# │    │    └─Conv2d: 3-253                [1, 1824, 7, 7]           45,600
# │    │    └─BatchNorm2d: 3-254           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-255                 [1, 1824, 7, 7]           --
# │    │    └─SEBlock: 3-256               [1, 1824, 7, 7]           1,665,768
# │    │    └─Conv2d: 3-257                [1, 304, 7, 7]            554,496
# │    │    └─BatchNorm2d: 3-258           [1, 304, 7, 7]            608
# │    └─MBConvBlock: 2-33                 [1, 304, 7, 7]            --
# │    │    └─Conv2d: 3-259                [1, 1824, 7, 7]           554,496
# │    │    └─BatchNorm2d: 3-260           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-261                 [1, 1824, 7, 7]           --
# │    │    └─Conv2d: 3-262                [1, 1824, 7, 7]           45,600
# │    │    └─BatchNorm2d: 3-263           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-264                 [1, 1824, 7, 7]           --
# │    │    └─SEBlock: 3-265               [1, 1824, 7, 7]           1,665,768
# │    │    └─Conv2d: 3-266                [1, 304, 7, 7]            554,496
# │    │    └─BatchNorm2d: 3-267           [1, 304, 7, 7]            608
# │    └─MBConvBlock: 2-34                 [1, 304, 7, 7]            --
# │    │    └─Conv2d: 3-268                [1, 1824, 7, 7]           554,496
# │    │    └─BatchNorm2d: 3-269           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-270                 [1, 1824, 7, 7]           --
# │    │    └─Conv2d: 3-271                [1, 1824, 7, 7]           45,600
# │    │    └─BatchNorm2d: 3-272           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-273                 [1, 1824, 7, 7]           --
# │    │    └─SEBlock: 3-274               [1, 1824, 7, 7]           1,665,768
# │    │    └─Conv2d: 3-275                [1, 304, 7, 7]            554,496
# │    │    └─BatchNorm2d: 3-276           [1, 304, 7, 7]            608
# │    └─MBConvBlock: 2-35                 [1, 304, 7, 7]            --
# │    │    └─Conv2d: 3-277                [1, 1824, 7, 7]           554,496
# │    │    └─BatchNorm2d: 3-278           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-279                 [1, 1824, 7, 7]           --
# │    │    └─Conv2d: 3-280                [1, 1824, 7, 7]           45,600
# │    │    └─BatchNorm2d: 3-281           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-282                 [1, 1824, 7, 7]           --
# │    │    └─SEBlock: 3-283               [1, 1824, 7, 7]           1,665,768
# │    │    └─Conv2d: 3-284                [1, 304, 7, 7]            554,496
# │    │    └─BatchNorm2d: 3-285           [1, 304, 7, 7]            608
# │    └─MBConvBlock: 2-36                 [1, 304, 7, 7]            --
# │    │    └─Conv2d: 3-286                [1, 1824, 7, 7]           554,496
# │    │    └─BatchNorm2d: 3-287           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-288                 [1, 1824, 7, 7]           --
# │    │    └─Conv2d: 3-289                [1, 1824, 7, 7]           45,600
# │    │    └─BatchNorm2d: 3-290           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-291                 [1, 1824, 7, 7]           --
# │    │    └─SEBlock: 3-292               [1, 1824, 7, 7]           1,665,768
# │    │    └─Conv2d: 3-293                [1, 304, 7, 7]            554,496
# │    │    └─BatchNorm2d: 3-294           [1, 304, 7, 7]            608
# │    └─MBConvBlock: 2-37                 [1, 304, 7, 7]            --
# │    │    └─Conv2d: 3-295                [1, 1824, 7, 7]           554,496
# │    │    └─BatchNorm2d: 3-296           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-297                 [1, 1824, 7, 7]           --
# │    │    └─Conv2d: 3-298                [1, 1824, 7, 7]           45,600
# │    │    └─BatchNorm2d: 3-299           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-300                 [1, 1824, 7, 7]           --
# │    │    └─SEBlock: 3-301               [1, 1824, 7, 7]           1,665,768
# │    │    └─Conv2d: 3-302                [1, 304, 7, 7]            554,496
# │    │    └─BatchNorm2d: 3-303           [1, 304, 7, 7]            608
# │    └─MBConvBlock: 2-38                 [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-304                [1, 1824, 7, 7]           554,496
# │    │    └─BatchNorm2d: 3-305           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-306                 [1, 1824, 7, 7]           --
# │    │    └─Conv2d: 3-307                [1, 1824, 7, 7]           16,416
# │    │    └─BatchNorm2d: 3-308           [1, 1824, 7, 7]           3,648
# │    │    └─Swish: 3-309                 [1, 1824, 7, 7]           --
# │    │    └─SEBlock: 3-310               [1, 1824, 7, 7]           1,665,768
# │    │    └─Conv2d: 3-311                [1, 512, 7, 7]            933,888
# │    │    └─BatchNorm2d: 3-312           [1, 512, 7, 7]            1,024
# │    └─MBConvBlock: 2-39                 [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-313                [1, 3072, 7, 7]           1,572,864
# │    │    └─BatchNorm2d: 3-314           [1, 3072, 7, 7]           6,144
# │    │    └─Swish: 3-315                 [1, 3072, 7, 7]           --
# │    │    └─Conv2d: 3-316                [1, 3072, 7, 7]           27,648
# │    │    └─BatchNorm2d: 3-317           [1, 3072, 7, 7]           6,144
# │    │    └─Swish: 3-318                 [1, 3072, 7, 7]           --
# │    │    └─SEBlock: 3-319               [1, 3072, 7, 7]           4,722,432
# │    │    └─Conv2d: 3-320                [1, 512, 7, 7]            1,572,864
# │    │    └─BatchNorm2d: 3-321           [1, 512, 7, 7]            1,024
# │    └─MBConvBlock: 2-40                 [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-322                [1, 3072, 7, 7]           1,572,864
# │    │    └─BatchNorm2d: 3-323           [1, 3072, 7, 7]           6,144
# │    │    └─Swish: 3-324                 [1, 3072, 7, 7]           --
# │    │    └─Conv2d: 3-325                [1, 3072, 7, 7]           27,648
# │    │    └─BatchNorm2d: 3-326           [1, 3072, 7, 7]           6,144
# │    │    └─Swish: 3-327                 [1, 3072, 7, 7]           --
# │    │    └─SEBlock: 3-328               [1, 3072, 7, 7]           4,722,432
# │    │    └─Conv2d: 3-329                [1, 512, 7, 7]            1,572,864
# │    │    └─BatchNorm2d: 3-330           [1, 512, 7, 7]            1,024
# ├─Sequential: 1-3                        [1, 1000]                 --
# │    └─Conv2d: 2-41                      [1, 2048, 7, 7]           1,048,576
# │    └─BatchNorm2d: 2-42                 [1, 2048, 7, 7]           4,096
# │    └─Swish: 2-43                       [1, 2048, 7, 7]           --
# │    └─AdaptiveAvgPool2d: 2-44           [1, 2048, 1, 1]           --
# │    └─Flatten: 2-45                     [1, 2048]                 --
# │    └─Dropout: 2-46                     [1, 2048]                 --
# │    └─Linear: 2-47                      [1, 1000]                 2,049,000
# ==========================================================================================
# Total params: 56,144,532
# Trainable params: 56,144,532
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.36
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 355.20
# Params size (MB): 224.58
# Estimated Total Size (MB): 580.38
# ==========================================================================================

# %% [markdown]
# ### EfficientNet-B6

# %%
efficientnet_b6_1 = CustomEfficientNet(width_coefficient=1.8, depth_coefficient=2.6, dropout_rate=0.5, num_classes=1000)
efficientnet_b6_1
# Out:
# CustomEfficientNet(
#   (stem): Sequential(
#     (0): Conv2d(3, 56, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): ModuleList(
#     (0): MBConvBlock(
#       (depthwise): Conv2d(56, 56, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=56, bias=False)
#       (bn1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(56, 14, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(14, 56, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(56, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (expand): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#       (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(192, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2-6): 5 x MBConvBlock(
#       (expand): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): MBConvBlock(
#       (expand): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=240, bias=False)
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(240, 60, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(60, 240, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(240, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8-12): 5 x MBConvBlock(
#       (expand): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#       (bn1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(432, 108, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(108, 432, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (13): MBConvBlock(
#       (expand): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(432, 432, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=432, bias=False)
#       (bn1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(432, 108, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(108, 432, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (14-20): 7 x MBConvBlock(
#       (expand): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#       (bn1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(864, 216, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(216, 864, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (21): MBConvBlock(
#       (expand): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#       (bn1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(864, 216, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(216, 864, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(864, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (22-28): 7 x MBConvBlock(
#       (expand): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#       (bn1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1200, 300, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(300, 1200, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (29): MBConvBlock(
#       (expand): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=1200, bias=False)
#       (bn1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1200, 300, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(300, 1200, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1200, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (30-39): 10 x MBConvBlock(
#       (expand): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#       (bn1): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(2064, 516, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(516, 2064, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (40): MBConvBlock(
#       (expand): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(2064, 2064, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2064, bias=False)
#       (bn1): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(2064, 516, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(516, 2064, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(2064, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (41-42): 2 x MBConvBlock(
#       (expand): Conv2d(576, 3456, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(3456, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(3456, 3456, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3456, bias=False)
#       (bn1): BatchNorm2d(3456, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(3456, 864, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(864, 3456, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(3456, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(576, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=2304, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b6_1, (1, 3, 224, 224), device='cpu')
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomEfficientNet                       [1, 1000]                 --
# ├─Sequential: 1-1                        [1, 56, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 56, 112, 112]         1,512
# │    └─BatchNorm2d: 2-2                  [1, 56, 112, 112]         112
# │    └─Swish: 2-3                        [1, 56, 112, 112]         --
# ├─ModuleList: 1-2                        --                        --
# │    └─MBConvBlock: 2-4                  [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 56, 112, 112]         504
# │    │    └─BatchNorm2d: 3-2             [1, 56, 112, 112]         112
# │    │    └─Swish: 3-3                   [1, 56, 112, 112]         --
# │    │    └─SEBlock: 3-4                 [1, 56, 112, 112]         1,638
# │    │    └─Conv2d: 3-5                  [1, 32, 112, 112]         1,792
# │    │    └─BatchNorm2d: 3-6             [1, 32, 112, 112]         64
# │    └─MBConvBlock: 2-5                  [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 192, 112, 112]        6,144
# │    │    └─BatchNorm2d: 3-8             [1, 192, 112, 112]        384
# │    │    └─Swish: 3-9                   [1, 192, 112, 112]        --
# │    │    └─Conv2d: 3-10                 [1, 192, 56, 56]          1,728
# │    │    └─BatchNorm2d: 3-11            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-12                  [1, 192, 56, 56]          --
# │    │    └─SEBlock: 3-13                [1, 192, 56, 56]          18,672
# │    │    └─Conv2d: 3-14                 [1, 40, 56, 56]           7,680
# │    │    └─BatchNorm2d: 3-15            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-6                  [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-16                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-17            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-18                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-19                 [1, 240, 56, 56]          2,160
# │    │    └─BatchNorm2d: 3-20            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-21                  [1, 240, 56, 56]          --
# │    │    └─SEBlock: 3-22                [1, 240, 56, 56]          29,100
# │    │    └─Conv2d: 3-23                 [1, 40, 56, 56]           9,600
# │    │    └─BatchNorm2d: 3-24            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-7                  [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-25                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-26            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-27                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-28                 [1, 240, 56, 56]          2,160
# │    │    └─BatchNorm2d: 3-29            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-30                  [1, 240, 56, 56]          --
# │    │    └─SEBlock: 3-31                [1, 240, 56, 56]          29,100
# │    │    └─Conv2d: 3-32                 [1, 40, 56, 56]           9,600
# │    │    └─BatchNorm2d: 3-33            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-8                  [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-34                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-35            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-36                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-37                 [1, 240, 56, 56]          2,160
# │    │    └─BatchNorm2d: 3-38            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-39                  [1, 240, 56, 56]          --
# │    │    └─SEBlock: 3-40                [1, 240, 56, 56]          29,100
# │    │    └─Conv2d: 3-41                 [1, 40, 56, 56]           9,600
# │    │    └─BatchNorm2d: 3-42            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-9                  [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-43                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-44            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-45                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-46                 [1, 240, 56, 56]          2,160
# │    │    └─BatchNorm2d: 3-47            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-48                  [1, 240, 56, 56]          --
# │    │    └─SEBlock: 3-49                [1, 240, 56, 56]          29,100
# │    │    └─Conv2d: 3-50                 [1, 40, 56, 56]           9,600
# │    │    └─BatchNorm2d: 3-51            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-10                 [1, 40, 56, 56]           --
# │    │    └─Conv2d: 3-52                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-53            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-54                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-55                 [1, 240, 56, 56]          2,160
# │    │    └─BatchNorm2d: 3-56            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-57                  [1, 240, 56, 56]          --
# │    │    └─SEBlock: 3-58                [1, 240, 56, 56]          29,100
# │    │    └─Conv2d: 3-59                 [1, 40, 56, 56]           9,600
# │    │    └─BatchNorm2d: 3-60            [1, 40, 56, 56]           80
# │    └─MBConvBlock: 2-11                 [1, 72, 28, 28]           --
# │    │    └─Conv2d: 3-61                 [1, 240, 56, 56]          9,600
# │    │    └─BatchNorm2d: 3-62            [1, 240, 56, 56]          480
# │    │    └─Swish: 3-63                  [1, 240, 56, 56]          --
# │    │    └─Conv2d: 3-64                 [1, 240, 28, 28]          6,000
# │    │    └─BatchNorm2d: 3-65            [1, 240, 28, 28]          480
# │    │    └─Swish: 3-66                  [1, 240, 28, 28]          --
# │    │    └─SEBlock: 3-67                [1, 240, 28, 28]          29,100
# │    │    └─Conv2d: 3-68                 [1, 72, 28, 28]           17,280
# │    │    └─BatchNorm2d: 3-69            [1, 72, 28, 28]           144
# │    └─MBConvBlock: 2-12                 [1, 72, 28, 28]           --
# │    │    └─Conv2d: 3-70                 [1, 432, 28, 28]          31,104
# │    │    └─BatchNorm2d: 3-71            [1, 432, 28, 28]          864
# │    │    └─Swish: 3-72                  [1, 432, 28, 28]          --
# │    │    └─Conv2d: 3-73                 [1, 432, 28, 28]          10,800
# │    │    └─BatchNorm2d: 3-74            [1, 432, 28, 28]          864
# │    │    └─Swish: 3-75                  [1, 432, 28, 28]          --
# │    │    └─SEBlock: 3-76                [1, 432, 28, 28]          93,852
# │    │    └─Conv2d: 3-77                 [1, 72, 28, 28]           31,104
# │    │    └─BatchNorm2d: 3-78            [1, 72, 28, 28]           144
# │    └─MBConvBlock: 2-13                 [1, 72, 28, 28]           --
# │    │    └─Conv2d: 3-79                 [1, 432, 28, 28]          31,104
# │    │    └─BatchNorm2d: 3-80            [1, 432, 28, 28]          864
# │    │    └─Swish: 3-81                  [1, 432, 28, 28]          --
# │    │    └─Conv2d: 3-82                 [1, 432, 28, 28]          10,800
# │    │    └─BatchNorm2d: 3-83            [1, 432, 28, 28]          864
# │    │    └─Swish: 3-84                  [1, 432, 28, 28]          --
# │    │    └─SEBlock: 3-85                [1, 432, 28, 28]          93,852
# │    │    └─Conv2d: 3-86                 [1, 72, 28, 28]           31,104
# │    │    └─BatchNorm2d: 3-87            [1, 72, 28, 28]           144
# │    └─MBConvBlock: 2-14                 [1, 72, 28, 28]           --
# │    │    └─Conv2d: 3-88                 [1, 432, 28, 28]          31,104
# │    │    └─BatchNorm2d: 3-89            [1, 432, 28, 28]          864
# │    │    └─Swish: 3-90                  [1, 432, 28, 28]          --
# │    │    └─Conv2d: 3-91                 [1, 432, 28, 28]          10,800
# │    │    └─BatchNorm2d: 3-92            [1, 432, 28, 28]          864
# │    │    └─Swish: 3-93                  [1, 432, 28, 28]          --
# │    │    └─SEBlock: 3-94                [1, 432, 28, 28]          93,852
# │    │    └─Conv2d: 3-95                 [1, 72, 28, 28]           31,104
# │    │    └─BatchNorm2d: 3-96            [1, 72, 28, 28]           144
# │    └─MBConvBlock: 2-15                 [1, 72, 28, 28]           --
# │    │    └─Conv2d: 3-97                 [1, 432, 28, 28]          31,104
# │    │    └─BatchNorm2d: 3-98            [1, 432, 28, 28]          864
# │    │    └─Swish: 3-99                  [1, 432, 28, 28]          --
# │    │    └─Conv2d: 3-100                [1, 432, 28, 28]          10,800
# │    │    └─BatchNorm2d: 3-101           [1, 432, 28, 28]          864
# │    │    └─Swish: 3-102                 [1, 432, 28, 28]          --
# │    │    └─SEBlock: 3-103               [1, 432, 28, 28]          93,852
# │    │    └─Conv2d: 3-104                [1, 72, 28, 28]           31,104
# │    │    └─BatchNorm2d: 3-105           [1, 72, 28, 28]           144
# │    └─MBConvBlock: 2-16                 [1, 72, 28, 28]           --
# │    │    └─Conv2d: 3-106                [1, 432, 28, 28]          31,104
# │    │    └─BatchNorm2d: 3-107           [1, 432, 28, 28]          864
# │    │    └─Swish: 3-108                 [1, 432, 28, 28]          --
# │    │    └─Conv2d: 3-109                [1, 432, 28, 28]          10,800
# │    │    └─BatchNorm2d: 3-110           [1, 432, 28, 28]          864
# │    │    └─Swish: 3-111                 [1, 432, 28, 28]          --
# │    │    └─SEBlock: 3-112               [1, 432, 28, 28]          93,852
# │    │    └─Conv2d: 3-113                [1, 72, 28, 28]           31,104
# │    │    └─BatchNorm2d: 3-114           [1, 72, 28, 28]           144
# │    └─MBConvBlock: 2-17                 [1, 144, 14, 14]          --
# │    │    └─Conv2d: 3-115                [1, 432, 28, 28]          31,104
# │    │    └─BatchNorm2d: 3-116           [1, 432, 28, 28]          864
# │    │    └─Swish: 3-117                 [1, 432, 28, 28]          --
# │    │    └─Conv2d: 3-118                [1, 432, 14, 14]          3,888
# │    │    └─BatchNorm2d: 3-119           [1, 432, 14, 14]          864
# │    │    └─Swish: 3-120                 [1, 432, 14, 14]          --
# │    │    └─SEBlock: 3-121               [1, 432, 14, 14]          93,852
# │    │    └─Conv2d: 3-122                [1, 144, 14, 14]          62,208
# │    │    └─BatchNorm2d: 3-123           [1, 144, 14, 14]          288
# │    └─MBConvBlock: 2-18                 [1, 144, 14, 14]          --
# │    │    └─Conv2d: 3-124                [1, 864, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-125           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-126                 [1, 864, 14, 14]          --
# │    │    └─Conv2d: 3-127                [1, 864, 14, 14]          7,776
# │    │    └─BatchNorm2d: 3-128           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-129                 [1, 864, 14, 14]          --
# │    │    └─SEBlock: 3-130               [1, 864, 14, 14]          374,328
# │    │    └─Conv2d: 3-131                [1, 144, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-132           [1, 144, 14, 14]          288
# │    └─MBConvBlock: 2-19                 [1, 144, 14, 14]          --
# │    │    └─Conv2d: 3-133                [1, 864, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-134           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-135                 [1, 864, 14, 14]          --
# │    │    └─Conv2d: 3-136                [1, 864, 14, 14]          7,776
# │    │    └─BatchNorm2d: 3-137           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-138                 [1, 864, 14, 14]          --
# │    │    └─SEBlock: 3-139               [1, 864, 14, 14]          374,328
# │    │    └─Conv2d: 3-140                [1, 144, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-141           [1, 144, 14, 14]          288
# │    └─MBConvBlock: 2-20                 [1, 144, 14, 14]          --
# │    │    └─Conv2d: 3-142                [1, 864, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-143           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-144                 [1, 864, 14, 14]          --
# │    │    └─Conv2d: 3-145                [1, 864, 14, 14]          7,776
# │    │    └─BatchNorm2d: 3-146           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-147                 [1, 864, 14, 14]          --
# │    │    └─SEBlock: 3-148               [1, 864, 14, 14]          374,328
# │    │    └─Conv2d: 3-149                [1, 144, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-150           [1, 144, 14, 14]          288
# │    └─MBConvBlock: 2-21                 [1, 144, 14, 14]          --
# │    │    └─Conv2d: 3-151                [1, 864, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-152           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-153                 [1, 864, 14, 14]          --
# │    │    └─Conv2d: 3-154                [1, 864, 14, 14]          7,776
# │    │    └─BatchNorm2d: 3-155           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-156                 [1, 864, 14, 14]          --
# │    │    └─SEBlock: 3-157               [1, 864, 14, 14]          374,328
# │    │    └─Conv2d: 3-158                [1, 144, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-159           [1, 144, 14, 14]          288
# │    └─MBConvBlock: 2-22                 [1, 144, 14, 14]          --
# │    │    └─Conv2d: 3-160                [1, 864, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-161           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-162                 [1, 864, 14, 14]          --
# │    │    └─Conv2d: 3-163                [1, 864, 14, 14]          7,776
# │    │    └─BatchNorm2d: 3-164           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-165                 [1, 864, 14, 14]          --
# │    │    └─SEBlock: 3-166               [1, 864, 14, 14]          374,328
# │    │    └─Conv2d: 3-167                [1, 144, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-168           [1, 144, 14, 14]          288
# │    └─MBConvBlock: 2-23                 [1, 144, 14, 14]          --
# │    │    └─Conv2d: 3-169                [1, 864, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-170           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-171                 [1, 864, 14, 14]          --
# │    │    └─Conv2d: 3-172                [1, 864, 14, 14]          7,776
# │    │    └─BatchNorm2d: 3-173           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-174                 [1, 864, 14, 14]          --
# │    │    └─SEBlock: 3-175               [1, 864, 14, 14]          374,328
# │    │    └─Conv2d: 3-176                [1, 144, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-177           [1, 144, 14, 14]          288
# │    └─MBConvBlock: 2-24                 [1, 144, 14, 14]          --
# │    │    └─Conv2d: 3-178                [1, 864, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-179           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-180                 [1, 864, 14, 14]          --
# │    │    └─Conv2d: 3-181                [1, 864, 14, 14]          7,776
# │    │    └─BatchNorm2d: 3-182           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-183                 [1, 864, 14, 14]          --
# │    │    └─SEBlock: 3-184               [1, 864, 14, 14]          374,328
# │    │    └─Conv2d: 3-185                [1, 144, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-186           [1, 144, 14, 14]          288
# │    └─MBConvBlock: 2-25                 [1, 200, 14, 14]          --
# │    │    └─Conv2d: 3-187                [1, 864, 14, 14]          124,416
# │    │    └─BatchNorm2d: 3-188           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-189                 [1, 864, 14, 14]          --
# │    │    └─Conv2d: 3-190                [1, 864, 14, 14]          21,600
# │    │    └─BatchNorm2d: 3-191           [1, 864, 14, 14]          1,728
# │    │    └─Swish: 3-192                 [1, 864, 14, 14]          --
# │    │    └─SEBlock: 3-193               [1, 864, 14, 14]          374,328
# │    │    └─Conv2d: 3-194                [1, 200, 14, 14]          172,800
# │    │    └─BatchNorm2d: 3-195           [1, 200, 14, 14]          400
# │    └─MBConvBlock: 2-26                 [1, 200, 14, 14]          --
# │    │    └─Conv2d: 3-196                [1, 1200, 14, 14]         240,000
# │    │    └─BatchNorm2d: 3-197           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-198                 [1, 1200, 14, 14]         --
# │    │    └─Conv2d: 3-199                [1, 1200, 14, 14]         30,000
# │    │    └─BatchNorm2d: 3-200           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-201                 [1, 1200, 14, 14]         --
# │    │    └─SEBlock: 3-202               [1, 1200, 14, 14]         721,500
# │    │    └─Conv2d: 3-203                [1, 200, 14, 14]          240,000
# │    │    └─BatchNorm2d: 3-204           [1, 200, 14, 14]          400
# │    └─MBConvBlock: 2-27                 [1, 200, 14, 14]          --
# │    │    └─Conv2d: 3-205                [1, 1200, 14, 14]         240,000
# │    │    └─BatchNorm2d: 3-206           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-207                 [1, 1200, 14, 14]         --
# │    │    └─Conv2d: 3-208                [1, 1200, 14, 14]         30,000
# │    │    └─BatchNorm2d: 3-209           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-210                 [1, 1200, 14, 14]         --
# │    │    └─SEBlock: 3-211               [1, 1200, 14, 14]         721,500
# │    │    └─Conv2d: 3-212                [1, 200, 14, 14]          240,000
# │    │    └─BatchNorm2d: 3-213           [1, 200, 14, 14]          400
# │    └─MBConvBlock: 2-28                 [1, 200, 14, 14]          --
# │    │    └─Conv2d: 3-214                [1, 1200, 14, 14]         240,000
# │    │    └─BatchNorm2d: 3-215           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-216                 [1, 1200, 14, 14]         --
# │    │    └─Conv2d: 3-217                [1, 1200, 14, 14]         30,000
# │    │    └─BatchNorm2d: 3-218           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-219                 [1, 1200, 14, 14]         --
# │    │    └─SEBlock: 3-220               [1, 1200, 14, 14]         721,500
# │    │    └─Conv2d: 3-221                [1, 200, 14, 14]          240,000
# │    │    └─BatchNorm2d: 3-222           [1, 200, 14, 14]          400
# │    └─MBConvBlock: 2-29                 [1, 200, 14, 14]          --
# │    │    └─Conv2d: 3-223                [1, 1200, 14, 14]         240,000
# │    │    └─BatchNorm2d: 3-224           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-225                 [1, 1200, 14, 14]         --
# │    │    └─Conv2d: 3-226                [1, 1200, 14, 14]         30,000
# │    │    └─BatchNorm2d: 3-227           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-228                 [1, 1200, 14, 14]         --
# │    │    └─SEBlock: 3-229               [1, 1200, 14, 14]         721,500
# │    │    └─Conv2d: 3-230                [1, 200, 14, 14]          240,000
# │    │    └─BatchNorm2d: 3-231           [1, 200, 14, 14]          400
# │    └─MBConvBlock: 2-30                 [1, 200, 14, 14]          --
# │    │    └─Conv2d: 3-232                [1, 1200, 14, 14]         240,000
# │    │    └─BatchNorm2d: 3-233           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-234                 [1, 1200, 14, 14]         --
# │    │    └─Conv2d: 3-235                [1, 1200, 14, 14]         30,000
# │    │    └─BatchNorm2d: 3-236           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-237                 [1, 1200, 14, 14]         --
# │    │    └─SEBlock: 3-238               [1, 1200, 14, 14]         721,500
# │    │    └─Conv2d: 3-239                [1, 200, 14, 14]          240,000
# │    │    └─BatchNorm2d: 3-240           [1, 200, 14, 14]          400
# │    └─MBConvBlock: 2-31                 [1, 200, 14, 14]          --
# │    │    └─Conv2d: 3-241                [1, 1200, 14, 14]         240,000
# │    │    └─BatchNorm2d: 3-242           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-243                 [1, 1200, 14, 14]         --
# │    │    └─Conv2d: 3-244                [1, 1200, 14, 14]         30,000
# │    │    └─BatchNorm2d: 3-245           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-246                 [1, 1200, 14, 14]         --
# │    │    └─SEBlock: 3-247               [1, 1200, 14, 14]         721,500
# │    │    └─Conv2d: 3-248                [1, 200, 14, 14]          240,000
# │    │    └─BatchNorm2d: 3-249           [1, 200, 14, 14]          400
# │    └─MBConvBlock: 2-32                 [1, 200, 14, 14]          --
# │    │    └─Conv2d: 3-250                [1, 1200, 14, 14]         240,000
# │    │    └─BatchNorm2d: 3-251           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-252                 [1, 1200, 14, 14]         --
# │    │    └─Conv2d: 3-253                [1, 1200, 14, 14]         30,000
# │    │    └─BatchNorm2d: 3-254           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-255                 [1, 1200, 14, 14]         --
# │    │    └─SEBlock: 3-256               [1, 1200, 14, 14]         721,500
# │    │    └─Conv2d: 3-257                [1, 200, 14, 14]          240,000
# │    │    └─BatchNorm2d: 3-258           [1, 200, 14, 14]          400
# │    └─MBConvBlock: 2-33                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-259                [1, 1200, 14, 14]         240,000
# │    │    └─BatchNorm2d: 3-260           [1, 1200, 14, 14]         2,400
# │    │    └─Swish: 3-261                 [1, 1200, 14, 14]         --
# │    │    └─Conv2d: 3-262                [1, 1200, 7, 7]           30,000
# │    │    └─BatchNorm2d: 3-263           [1, 1200, 7, 7]           2,400
# │    │    └─Swish: 3-264                 [1, 1200, 7, 7]           --
# │    │    └─SEBlock: 3-265               [1, 1200, 7, 7]           721,500
# │    │    └─Conv2d: 3-266                [1, 344, 7, 7]            412,800
# │    │    └─BatchNorm2d: 3-267           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-34                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-268                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-269           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-270                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-271                [1, 2064, 7, 7]           51,600
# │    │    └─BatchNorm2d: 3-272           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-273                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-274               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-275                [1, 344, 7, 7]            710,016
# │    │    └─BatchNorm2d: 3-276           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-35                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-277                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-278           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-279                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-280                [1, 2064, 7, 7]           51,600
# │    │    └─BatchNorm2d: 3-281           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-282                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-283               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-284                [1, 344, 7, 7]            710,016
# │    │    └─BatchNorm2d: 3-285           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-36                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-286                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-287           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-288                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-289                [1, 2064, 7, 7]           51,600
# │    │    └─BatchNorm2d: 3-290           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-291                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-292               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-293                [1, 344, 7, 7]            710,016
# │    │    └─BatchNorm2d: 3-294           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-37                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-295                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-296           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-297                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-298                [1, 2064, 7, 7]           51,600
# │    │    └─BatchNorm2d: 3-299           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-300                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-301               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-302                [1, 344, 7, 7]            710,016
# │    │    └─BatchNorm2d: 3-303           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-38                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-304                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-305           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-306                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-307                [1, 2064, 7, 7]           51,600
# │    │    └─BatchNorm2d: 3-308           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-309                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-310               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-311                [1, 344, 7, 7]            710,016
# │    │    └─BatchNorm2d: 3-312           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-39                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-313                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-314           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-315                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-316                [1, 2064, 7, 7]           51,600
# │    │    └─BatchNorm2d: 3-317           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-318                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-319               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-320                [1, 344, 7, 7]            710,016
# │    │    └─BatchNorm2d: 3-321           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-40                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-322                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-323           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-324                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-325                [1, 2064, 7, 7]           51,600
# │    │    └─BatchNorm2d: 3-326           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-327                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-328               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-329                [1, 344, 7, 7]            710,016
# │    │    └─BatchNorm2d: 3-330           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-41                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-331                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-332           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-333                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-334                [1, 2064, 7, 7]           51,600
# │    │    └─BatchNorm2d: 3-335           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-336                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-337               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-338                [1, 344, 7, 7]            710,016
# │    │    └─BatchNorm2d: 3-339           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-42                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-340                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-341           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-342                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-343                [1, 2064, 7, 7]           51,600
# │    │    └─BatchNorm2d: 3-344           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-345                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-346               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-347                [1, 344, 7, 7]            710,016
# │    │    └─BatchNorm2d: 3-348           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-43                 [1, 344, 7, 7]            --
# │    │    └─Conv2d: 3-349                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-350           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-351                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-352                [1, 2064, 7, 7]           51,600
# │    │    └─BatchNorm2d: 3-353           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-354                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-355               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-356                [1, 344, 7, 7]            710,016
# │    │    └─BatchNorm2d: 3-357           [1, 344, 7, 7]            688
# │    └─MBConvBlock: 2-44                 [1, 576, 7, 7]            --
# │    │    └─Conv2d: 3-358                [1, 2064, 7, 7]           710,016
# │    │    └─BatchNorm2d: 3-359           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-360                 [1, 2064, 7, 7]           --
# │    │    └─Conv2d: 3-361                [1, 2064, 7, 7]           18,576
# │    │    └─BatchNorm2d: 3-362           [1, 2064, 7, 7]           4,128
# │    │    └─Swish: 3-363                 [1, 2064, 7, 7]           --
# │    │    └─SEBlock: 3-364               [1, 2064, 7, 7]           2,132,628
# │    │    └─Conv2d: 3-365                [1, 576, 7, 7]            1,188,864
# │    │    └─BatchNorm2d: 3-366           [1, 576, 7, 7]            1,152
# │    └─MBConvBlock: 2-45                 [1, 576, 7, 7]            --
# │    │    └─Conv2d: 3-367                [1, 3456, 7, 7]           1,990,656
# │    │    └─BatchNorm2d: 3-368           [1, 3456, 7, 7]           6,912
# │    │    └─Swish: 3-369                 [1, 3456, 7, 7]           --
# │    │    └─Conv2d: 3-370                [1, 3456, 7, 7]           31,104
# │    │    └─BatchNorm2d: 3-371           [1, 3456, 7, 7]           6,912
# │    │    └─Swish: 3-372                 [1, 3456, 7, 7]           --
# │    │    └─SEBlock: 3-373               [1, 3456, 7, 7]           5,976,288
# │    │    └─Conv2d: 3-374                [1, 576, 7, 7]            1,990,656
# │    │    └─BatchNorm2d: 3-375           [1, 576, 7, 7]            1,152
# │    └─MBConvBlock: 2-46                 [1, 576, 7, 7]            --
# │    │    └─Conv2d: 3-376                [1, 3456, 7, 7]           1,990,656
# │    │    └─BatchNorm2d: 3-377           [1, 3456, 7, 7]           6,912
# │    │    └─Swish: 3-378                 [1, 3456, 7, 7]           --
# │    │    └─Conv2d: 3-379                [1, 3456, 7, 7]           31,104
# │    │    └─BatchNorm2d: 3-380           [1, 3456, 7, 7]           6,912
# │    │    └─Swish: 3-381                 [1, 3456, 7, 7]           --
# │    │    └─SEBlock: 3-382               [1, 3456, 7, 7]           5,976,288
# │    │    └─Conv2d: 3-383                [1, 576, 7, 7]            1,990,656
# │    │    └─BatchNorm2d: 3-384           [1, 576, 7, 7]            1,152
# ├─Sequential: 1-3                        [1, 1000]                 --
# │    └─Conv2d: 2-47                      [1, 2304, 7, 7]           1,327,104
# │    └─BatchNorm2d: 2-48                 [1, 2304, 7, 7]           4,608
# │    └─Swish: 2-49                       [1, 2304, 7, 7]           --
# │    └─AdaptiveAvgPool2d: 2-50           [1, 2304, 1, 1]           --
# │    └─Flatten: 2-51                     [1, 2304]                 --
# │    └─Dropout: 2-52                     [1, 2304]                 --
# │    └─Linear: 2-53                      [1, 1000]                 2,305,000
# ==========================================================================================
# Total params: 80,440,170
# Trainable params: 80,440,170
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 3.36
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 453.42
# Params size (MB): 321.76
# Estimated Total Size (MB): 775.78
# ==========================================================================================

# %% [markdown]
# ### EfficientNet-B7

# %%
efficientnet_b7_1 = CustomEfficientNet(width_coefficient=2.0, depth_coefficient=3.1, dropout_rate=0.5, num_classes=1000)
efficientnet_b7_1
# Out:
# CustomEfficientNet(
#   (stem): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): ModuleList(
#     (0): MBConvBlock(
#       (depthwise): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (expand): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#       (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2-7): 6 x MBConvBlock(
#       (expand): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#       (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8): MBConvBlock(
#       (expand): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#       (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(288, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (9-14): 6 x MBConvBlock(
#       (expand): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#       (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (15): MBConvBlock(
#       (expand): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(480, 480, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=480, bias=False)
#       (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(480, 120, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(120, 480, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(480, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (16-24): 9 x MBConvBlock(
#       (expand): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#       (bn1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (25): MBConvBlock(
#       (expand): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#       (bn1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(960, 240, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(240, 960, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(960, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (26-34): 9 x MBConvBlock(
#       (expand): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#       (bn1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1344, 336, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(336, 1344, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (35): MBConvBlock(
#       (expand): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=1344, bias=False)
#       (bn1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(1344, 336, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(336, 1344, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(1344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (36-47): 12 x MBConvBlock(
#       (expand): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#       (bn1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(2304, 576, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(576, 2304, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (48): MBConvBlock(
#       (expand): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#       (bn1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(2304, 576, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(576, 2304, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(2304, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (49-51): 3 x MBConvBlock(
#       (expand): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn0): BatchNorm2d(3840, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act0): Swish()
#       (depthwise): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#       (bn1): BatchNorm2d(3840, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): Swish()
#       (se): SEBlock(
#         (fc1): Conv2d(3840, 960, kernel_size=(1, 1), stride=(1, 1))
#         (fc2): Conv2d(960, 3840, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (project): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(640, 2560, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(2560, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#     (4): Flatten(start_dim=1, end_dim=-1)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=2560, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b7_1, (1, 3, 224, 224), device='cpu')
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CustomEfficientNet                       [1, 1000]                 --
# ├─Sequential: 1-1                        [1, 64, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 64, 112, 112]         1,728
# │    └─BatchNorm2d: 2-2                  [1, 64, 112, 112]         128
# │    └─Swish: 2-3                        [1, 64, 112, 112]         --
# ├─ModuleList: 1-2                        --                        --
# │    └─MBConvBlock: 2-4                  [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-1                  [1, 64, 112, 112]         576
# │    │    └─BatchNorm2d: 3-2             [1, 64, 112, 112]         128
# │    │    └─Swish: 3-3                   [1, 64, 112, 112]         --
# │    │    └─SEBlock: 3-4                 [1, 64, 112, 112]         2,128
# │    │    └─Conv2d: 3-5                  [1, 32, 112, 112]         2,048
# │    │    └─BatchNorm2d: 3-6             [1, 32, 112, 112]         64
# │    └─MBConvBlock: 2-5                  [1, 48, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 192, 112, 112]        6,144
# │    │    └─BatchNorm2d: 3-8             [1, 192, 112, 112]        384
# │    │    └─Swish: 3-9                   [1, 192, 112, 112]        --
# │    │    └─Conv2d: 3-10                 [1, 192, 56, 56]          1,728
# │    │    └─BatchNorm2d: 3-11            [1, 192, 56, 56]          384
# │    │    └─Swish: 3-12                  [1, 192, 56, 56]          --
# │    │    └─SEBlock: 3-13                [1, 192, 56, 56]          18,672
# │    │    └─Conv2d: 3-14                 [1, 48, 56, 56]           9,216
# │    │    └─BatchNorm2d: 3-15            [1, 48, 56, 56]           96
# │    └─MBConvBlock: 2-6                  [1, 48, 56, 56]           --
# │    │    └─Conv2d: 3-16                 [1, 288, 56, 56]          13,824
# │    │    └─BatchNorm2d: 3-17            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-18                  [1, 288, 56, 56]          --
# │    │    └─Conv2d: 3-19                 [1, 288, 56, 56]          2,592
# │    │    └─BatchNorm2d: 3-20            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-21                  [1, 288, 56, 56]          --
# │    │    └─SEBlock: 3-22                [1, 288, 56, 56]          41,832
# │    │    └─Conv2d: 3-23                 [1, 48, 56, 56]           13,824
# │    │    └─BatchNorm2d: 3-24            [1, 48, 56, 56]           96
# │    └─MBConvBlock: 2-7                  [1, 48, 56, 56]           --
# │    │    └─Conv2d: 3-25                 [1, 288, 56, 56]          13,824
# │    │    └─BatchNorm2d: 3-26            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-27                  [1, 288, 56, 56]          --
# │    │    └─Conv2d: 3-28                 [1, 288, 56, 56]          2,592
# │    │    └─BatchNorm2d: 3-29            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-30                  [1, 288, 56, 56]          --
# │    │    └─SEBlock: 3-31                [1, 288, 56, 56]          41,832
# │    │    └─Conv2d: 3-32                 [1, 48, 56, 56]           13,824
# │    │    └─BatchNorm2d: 3-33            [1, 48, 56, 56]           96
# │    └─MBConvBlock: 2-8                  [1, 48, 56, 56]           --
# │    │    └─Conv2d: 3-34                 [1, 288, 56, 56]          13,824
# │    │    └─BatchNorm2d: 3-35            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-36                  [1, 288, 56, 56]          --
# │    │    └─Conv2d: 3-37                 [1, 288, 56, 56]          2,592
# │    │    └─BatchNorm2d: 3-38            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-39                  [1, 288, 56, 56]          --
# │    │    └─SEBlock: 3-40                [1, 288, 56, 56]          41,832
# │    │    └─Conv2d: 3-41                 [1, 48, 56, 56]           13,824
# │    │    └─BatchNorm2d: 3-42            [1, 48, 56, 56]           96
# │    └─MBConvBlock: 2-9                  [1, 48, 56, 56]           --
# │    │    └─Conv2d: 3-43                 [1, 288, 56, 56]          13,824
# │    │    └─BatchNorm2d: 3-44            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-45                  [1, 288, 56, 56]          --
# │    │    └─Conv2d: 3-46                 [1, 288, 56, 56]          2,592
# │    │    └─BatchNorm2d: 3-47            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-48                  [1, 288, 56, 56]          --
# │    │    └─SEBlock: 3-49                [1, 288, 56, 56]          41,832
# │    │    └─Conv2d: 3-50                 [1, 48, 56, 56]           13,824
# │    │    └─BatchNorm2d: 3-51            [1, 48, 56, 56]           96
# │    └─MBConvBlock: 2-10                 [1, 48, 56, 56]           --
# │    │    └─Conv2d: 3-52                 [1, 288, 56, 56]          13,824
# │    │    └─BatchNorm2d: 3-53            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-54                  [1, 288, 56, 56]          --
# │    │    └─Conv2d: 3-55                 [1, 288, 56, 56]          2,592
# │    │    └─BatchNorm2d: 3-56            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-57                  [1, 288, 56, 56]          --
# │    │    └─SEBlock: 3-58                [1, 288, 56, 56]          41,832
# │    │    └─Conv2d: 3-59                 [1, 48, 56, 56]           13,824
# │    │    └─BatchNorm2d: 3-60            [1, 48, 56, 56]           96
# │    └─MBConvBlock: 2-11                 [1, 48, 56, 56]           --
# │    │    └─Conv2d: 3-61                 [1, 288, 56, 56]          13,824
# │    │    └─BatchNorm2d: 3-62            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-63                  [1, 288, 56, 56]          --
# │    │    └─Conv2d: 3-64                 [1, 288, 56, 56]          2,592
# │    │    └─BatchNorm2d: 3-65            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-66                  [1, 288, 56, 56]          --
# │    │    └─SEBlock: 3-67                [1, 288, 56, 56]          41,832
# │    │    └─Conv2d: 3-68                 [1, 48, 56, 56]           13,824
# │    │    └─BatchNorm2d: 3-69            [1, 48, 56, 56]           96
# │    └─MBConvBlock: 2-12                 [1, 80, 28, 28]           --
# │    │    └─Conv2d: 3-70                 [1, 288, 56, 56]          13,824
# │    │    └─BatchNorm2d: 3-71            [1, 288, 56, 56]          576
# │    │    └─Swish: 3-72                  [1, 288, 56, 56]          --
# │    │    └─Conv2d: 3-73                 [1, 288, 28, 28]          7,200
# │    │    └─BatchNorm2d: 3-74            [1, 288, 28, 28]          576
# │    │    └─Swish: 3-75                  [1, 288, 28, 28]          --
# │    │    └─SEBlock: 3-76                [1, 288, 28, 28]          41,832
# │    │    └─Conv2d: 3-77                 [1, 80, 28, 28]           23,040
# │    │    └─BatchNorm2d: 3-78            [1, 80, 28, 28]           160
# │    └─MBConvBlock: 2-13                 [1, 80, 28, 28]           --
# │    │    └─Conv2d: 3-79                 [1, 480, 28, 28]          38,400
# │    │    └─BatchNorm2d: 3-80            [1, 480, 28, 28]          960
# │    │    └─Swish: 3-81                  [1, 480, 28, 28]          --
# │    │    └─Conv2d: 3-82                 [1, 480, 28, 28]          12,000
# │    │    └─BatchNorm2d: 3-83            [1, 480, 28, 28]          960
# │    │    └─Swish: 3-84                  [1, 480, 28, 28]          --
# │    │    └─SEBlock: 3-85                [1, 480, 28, 28]          115,800
# │    │    └─Conv2d: 3-86                 [1, 80, 28, 28]           38,400
# │    │    └─BatchNorm2d: 3-87            [1, 80, 28, 28]           160
# │    └─MBConvBlock: 2-14                 [1, 80, 28, 28]           --
# │    │    └─Conv2d: 3-88                 [1, 480, 28, 28]          38,400
# │    │    └─BatchNorm2d: 3-89            [1, 480, 28, 28]          960
# │    │    └─Swish: 3-90                  [1, 480, 28, 28]          --
# │    │    └─Conv2d: 3-91                 [1, 480, 28, 28]          12,000
# │    │    └─BatchNorm2d: 3-92            [1, 480, 28, 28]          960
# │    │    └─Swish: 3-93                  [1, 480, 28, 28]          --
# │    │    └─SEBlock: 3-94                [1, 480, 28, 28]          115,800
# │    │    └─Conv2d: 3-95                 [1, 80, 28, 28]           38,400
# │    │    └─BatchNorm2d: 3-96            [1, 80, 28, 28]           160
# │    └─MBConvBlock: 2-15                 [1, 80, 28, 28]           --
# │    │    └─Conv2d: 3-97                 [1, 480, 28, 28]          38,400
# │    │    └─BatchNorm2d: 3-98            [1, 480, 28, 28]          960
# │    │    └─Swish: 3-99                  [1, 480, 28, 28]          --
# │    │    └─Conv2d: 3-100                [1, 480, 28, 28]          12,000
# │    │    └─BatchNorm2d: 3-101           [1, 480, 28, 28]          960
# │    │    └─Swish: 3-102                 [1, 480, 28, 28]          --
# │    │    └─SEBlock: 3-103               [1, 480, 28, 28]          115,800
# │    │    └─Conv2d: 3-104                [1, 80, 28, 28]           38,400
# │    │    └─BatchNorm2d: 3-105           [1, 80, 28, 28]           160
# │    └─MBConvBlock: 2-16                 [1, 80, 28, 28]           --
# │    │    └─Conv2d: 3-106                [1, 480, 28, 28]          38,400
# │    │    └─BatchNorm2d: 3-107           [1, 480, 28, 28]          960
# │    │    └─Swish: 3-108                 [1, 480, 28, 28]          --
# │    │    └─Conv2d: 3-109                [1, 480, 28, 28]          12,000
# │    │    └─BatchNorm2d: 3-110           [1, 480, 28, 28]          960
# │    │    └─Swish: 3-111                 [1, 480, 28, 28]          --
# │    │    └─SEBlock: 3-112               [1, 480, 28, 28]          115,800
# │    │    └─Conv2d: 3-113                [1, 80, 28, 28]           38,400
# │    │    └─BatchNorm2d: 3-114           [1, 80, 28, 28]           160
# │    └─MBConvBlock: 2-17                 [1, 80, 28, 28]           --
# │    │    └─Conv2d: 3-115                [1, 480, 28, 28]          38,400
# │    │    └─BatchNorm2d: 3-116           [1, 480, 28, 28]          960
# │    │    └─Swish: 3-117                 [1, 480, 28, 28]          --
# │    │    └─Conv2d: 3-118                [1, 480, 28, 28]          12,000
# │    │    └─BatchNorm2d: 3-119           [1, 480, 28, 28]          960
# │    │    └─Swish: 3-120                 [1, 480, 28, 28]          --
# │    │    └─SEBlock: 3-121               [1, 480, 28, 28]          115,800
# │    │    └─Conv2d: 3-122                [1, 80, 28, 28]           38,400
# │    │    └─BatchNorm2d: 3-123           [1, 80, 28, 28]           160
# │    └─MBConvBlock: 2-18                 [1, 80, 28, 28]           --
# │    │    └─Conv2d: 3-124                [1, 480, 28, 28]          38,400
# │    │    └─BatchNorm2d: 3-125           [1, 480, 28, 28]          960
# │    │    └─Swish: 3-126                 [1, 480, 28, 28]          --
# │    │    └─Conv2d: 3-127                [1, 480, 28, 28]          12,000
# │    │    └─BatchNorm2d: 3-128           [1, 480, 28, 28]          960
# │    │    └─Swish: 3-129                 [1, 480, 28, 28]          --
# │    │    └─SEBlock: 3-130               [1, 480, 28, 28]          115,800
# │    │    └─Conv2d: 3-131                [1, 80, 28, 28]           38,400
# │    │    └─BatchNorm2d: 3-132           [1, 80, 28, 28]           160
# │    └─MBConvBlock: 2-19                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-133                [1, 480, 28, 28]          38,400
# │    │    └─BatchNorm2d: 3-134           [1, 480, 28, 28]          960
# │    │    └─Swish: 3-135                 [1, 480, 28, 28]          --
# │    │    └─Conv2d: 3-136                [1, 480, 14, 14]          4,320
# │    │    └─BatchNorm2d: 3-137           [1, 480, 14, 14]          960
# │    │    └─Swish: 3-138                 [1, 480, 14, 14]          --
# │    │    └─SEBlock: 3-139               [1, 480, 14, 14]          115,800
# │    │    └─Conv2d: 3-140                [1, 160, 14, 14]          76,800
# │    │    └─BatchNorm2d: 3-141           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-20                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-142                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-143           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-144                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-145                [1, 960, 14, 14]          8,640
# │    │    └─BatchNorm2d: 3-146           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-147                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-148               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-149                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-150           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-21                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-151                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-152           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-153                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-154                [1, 960, 14, 14]          8,640
# │    │    └─BatchNorm2d: 3-155           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-156                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-157               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-158                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-159           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-22                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-160                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-161           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-162                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-163                [1, 960, 14, 14]          8,640
# │    │    └─BatchNorm2d: 3-164           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-165                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-166               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-167                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-168           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-23                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-169                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-170           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-171                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-172                [1, 960, 14, 14]          8,640
# │    │    └─BatchNorm2d: 3-173           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-174                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-175               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-176                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-177           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-24                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-178                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-179           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-180                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-181                [1, 960, 14, 14]          8,640
# │    │    └─BatchNorm2d: 3-182           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-183                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-184               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-185                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-186           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-25                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-187                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-188           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-189                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-190                [1, 960, 14, 14]          8,640
# │    │    └─BatchNorm2d: 3-191           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-192                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-193               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-194                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-195           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-26                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-196                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-197           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-198                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-199                [1, 960, 14, 14]          8,640
# │    │    └─BatchNorm2d: 3-200           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-201                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-202               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-203                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-204           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-27                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-205                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-206           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-207                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-208                [1, 960, 14, 14]          8,640
# │    │    └─BatchNorm2d: 3-209           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-210                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-211               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-212                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-213           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-28                 [1, 160, 14, 14]          --
# │    │    └─Conv2d: 3-214                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-215           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-216                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-217                [1, 960, 14, 14]          8,640
# │    │    └─BatchNorm2d: 3-218           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-219                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-220               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-221                [1, 160, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-222           [1, 160, 14, 14]          320
# │    └─MBConvBlock: 2-29                 [1, 224, 14, 14]          --
# │    │    └─Conv2d: 3-223                [1, 960, 14, 14]          153,600
# │    │    └─BatchNorm2d: 3-224           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-225                 [1, 960, 14, 14]          --
# │    │    └─Conv2d: 3-226                [1, 960, 14, 14]          24,000
# │    │    └─BatchNorm2d: 3-227           [1, 960, 14, 14]          1,920
# │    │    └─Swish: 3-228                 [1, 960, 14, 14]          --
# │    │    └─SEBlock: 3-229               [1, 960, 14, 14]          462,000
# │    │    └─Conv2d: 3-230                [1, 224, 14, 14]          215,040
# │    │    └─BatchNorm2d: 3-231           [1, 224, 14, 14]          448
# │    └─MBConvBlock: 2-30                 [1, 224, 14, 14]          --
# │    │    └─Conv2d: 3-232                [1, 1344, 14, 14]         301,056
# │    │    └─BatchNorm2d: 3-233           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-234                 [1, 1344, 14, 14]         --
# │    │    └─Conv2d: 3-235                [1, 1344, 14, 14]         33,600
# │    │    └─BatchNorm2d: 3-236           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-237                 [1, 1344, 14, 14]         --
# │    │    └─SEBlock: 3-238               [1, 1344, 14, 14]         904,848
# │    │    └─Conv2d: 3-239                [1, 224, 14, 14]          301,056
# │    │    └─BatchNorm2d: 3-240           [1, 224, 14, 14]          448
# │    └─MBConvBlock: 2-31                 [1, 224, 14, 14]          --
# │    │    └─Conv2d: 3-241                [1, 1344, 14, 14]         301,056
# │    │    └─BatchNorm2d: 3-242           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-243                 [1, 1344, 14, 14]         --
# │    │    └─Conv2d: 3-244                [1, 1344, 14, 14]         33,600
# │    │    └─BatchNorm2d: 3-245           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-246                 [1, 1344, 14, 14]         --
# │    │    └─SEBlock: 3-247               [1, 1344, 14, 14]         904,848
# │    │    └─Conv2d: 3-248                [1, 224, 14, 14]          301,056
# │    │    └─BatchNorm2d: 3-249           [1, 224, 14, 14]          448
# │    └─MBConvBlock: 2-32                 [1, 224, 14, 14]          --
# │    │    └─Conv2d: 3-250                [1, 1344, 14, 14]         301,056
# │    │    └─BatchNorm2d: 3-251           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-252                 [1, 1344, 14, 14]         --
# │    │    └─Conv2d: 3-253                [1, 1344, 14, 14]         33,600
# │    │    └─BatchNorm2d: 3-254           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-255                 [1, 1344, 14, 14]         --
# │    │    └─SEBlock: 3-256               [1, 1344, 14, 14]         904,848
# │    │    └─Conv2d: 3-257                [1, 224, 14, 14]          301,056
# │    │    └─BatchNorm2d: 3-258           [1, 224, 14, 14]          448
# │    └─MBConvBlock: 2-33                 [1, 224, 14, 14]          --
# │    │    └─Conv2d: 3-259                [1, 1344, 14, 14]         301,056
# │    │    └─BatchNorm2d: 3-260           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-261                 [1, 1344, 14, 14]         --
# │    │    └─Conv2d: 3-262                [1, 1344, 14, 14]         33,600
# │    │    └─BatchNorm2d: 3-263           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-264                 [1, 1344, 14, 14]         --
# │    │    └─SEBlock: 3-265               [1, 1344, 14, 14]         904,848
# │    │    └─Conv2d: 3-266                [1, 224, 14, 14]          301,056
# │    │    └─BatchNorm2d: 3-267           [1, 224, 14, 14]          448
# │    └─MBConvBlock: 2-34                 [1, 224, 14, 14]          --
# │    │    └─Conv2d: 3-268                [1, 1344, 14, 14]         301,056
# │    │    └─BatchNorm2d: 3-269           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-270                 [1, 1344, 14, 14]         --
# │    │    └─Conv2d: 3-271                [1, 1344, 14, 14]         33,600
# │    │    └─BatchNorm2d: 3-272           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-273                 [1, 1344, 14, 14]         --
# │    │    └─SEBlock: 3-274               [1, 1344, 14, 14]         904,848
# │    │    └─Conv2d: 3-275                [1, 224, 14, 14]          301,056
# │    │    └─BatchNorm2d: 3-276           [1, 224, 14, 14]          448
# │    └─MBConvBlock: 2-35                 [1, 224, 14, 14]          --
# │    │    └─Conv2d: 3-277                [1, 1344, 14, 14]         301,056
# │    │    └─BatchNorm2d: 3-278           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-279                 [1, 1344, 14, 14]         --
# │    │    └─Conv2d: 3-280                [1, 1344, 14, 14]         33,600
# │    │    └─BatchNorm2d: 3-281           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-282                 [1, 1344, 14, 14]         --
# │    │    └─SEBlock: 3-283               [1, 1344, 14, 14]         904,848
# │    │    └─Conv2d: 3-284                [1, 224, 14, 14]          301,056
# │    │    └─BatchNorm2d: 3-285           [1, 224, 14, 14]          448
# │    └─MBConvBlock: 2-36                 [1, 224, 14, 14]          --
# │    │    └─Conv2d: 3-286                [1, 1344, 14, 14]         301,056
# │    │    └─BatchNorm2d: 3-287           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-288                 [1, 1344, 14, 14]         --
# │    │    └─Conv2d: 3-289                [1, 1344, 14, 14]         33,600
# │    │    └─BatchNorm2d: 3-290           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-291                 [1, 1344, 14, 14]         --
# │    │    └─SEBlock: 3-292               [1, 1344, 14, 14]         904,848
# │    │    └─Conv2d: 3-293                [1, 224, 14, 14]          301,056
# │    │    └─BatchNorm2d: 3-294           [1, 224, 14, 14]          448
# │    └─MBConvBlock: 2-37                 [1, 224, 14, 14]          --
# │    │    └─Conv2d: 3-295                [1, 1344, 14, 14]         301,056
# │    │    └─BatchNorm2d: 3-296           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-297                 [1, 1344, 14, 14]         --
# │    │    └─Conv2d: 3-298                [1, 1344, 14, 14]         33,600
# │    │    └─BatchNorm2d: 3-299           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-300                 [1, 1344, 14, 14]         --
# │    │    └─SEBlock: 3-301               [1, 1344, 14, 14]         904,848
# │    │    └─Conv2d: 3-302                [1, 224, 14, 14]          301,056
# │    │    └─BatchNorm2d: 3-303           [1, 224, 14, 14]          448
# │    └─MBConvBlock: 2-38                 [1, 224, 14, 14]          --
# │    │    └─Conv2d: 3-304                [1, 1344, 14, 14]         301,056
# │    │    └─BatchNorm2d: 3-305           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-306                 [1, 1344, 14, 14]         --
# │    │    └─Conv2d: 3-307                [1, 1344, 14, 14]         33,600
# │    │    └─BatchNorm2d: 3-308           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-309                 [1, 1344, 14, 14]         --
# │    │    └─SEBlock: 3-310               [1, 1344, 14, 14]         904,848
# │    │    └─Conv2d: 3-311                [1, 224, 14, 14]          301,056
# │    │    └─BatchNorm2d: 3-312           [1, 224, 14, 14]          448
# │    └─MBConvBlock: 2-39                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-313                [1, 1344, 14, 14]         301,056
# │    │    └─BatchNorm2d: 3-314           [1, 1344, 14, 14]         2,688
# │    │    └─Swish: 3-315                 [1, 1344, 14, 14]         --
# │    │    └─Conv2d: 3-316                [1, 1344, 7, 7]           33,600
# │    │    └─BatchNorm2d: 3-317           [1, 1344, 7, 7]           2,688
# │    │    └─Swish: 3-318                 [1, 1344, 7, 7]           --
# │    │    └─SEBlock: 3-319               [1, 1344, 7, 7]           904,848
# │    │    └─Conv2d: 3-320                [1, 384, 7, 7]            516,096
# │    │    └─BatchNorm2d: 3-321           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-40                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-322                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-323           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-324                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-325                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-326           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-327                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-328               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-329                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-330           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-41                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-331                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-332           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-333                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-334                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-335           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-336                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-337               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-338                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-339           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-42                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-340                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-341           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-342                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-343                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-344           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-345                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-346               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-347                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-348           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-43                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-349                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-350           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-351                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-352                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-353           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-354                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-355               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-356                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-357           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-44                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-358                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-359           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-360                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-361                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-362           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-363                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-364               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-365                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-366           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-45                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-367                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-368           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-369                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-370                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-371           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-372                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-373               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-374                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-375           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-46                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-376                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-377           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-378                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-379                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-380           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-381                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-382               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-383                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-384           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-47                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-385                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-386           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-387                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-388                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-389           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-390                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-391               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-392                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-393           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-48                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-394                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-395           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-396                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-397                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-398           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-399                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-400               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-401                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-402           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-49                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-403                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-404           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-405                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-406                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-407           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-408                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-409               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-410                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-411           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-50                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-412                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-413           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-414                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-415                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-416           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-417                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-418               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-419                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-420           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-51                 [1, 384, 7, 7]            --
# │    │    └─Conv2d: 3-421                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-422           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-423                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-424                [1, 2304, 7, 7]           57,600
# │    │    └─BatchNorm2d: 3-425           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-426                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-427               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-428                [1, 384, 7, 7]            884,736
# │    │    └─BatchNorm2d: 3-429           [1, 384, 7, 7]            768
# │    └─MBConvBlock: 2-52                 [1, 640, 7, 7]            --
# │    │    └─Conv2d: 3-430                [1, 2304, 7, 7]           884,736
# │    │    └─BatchNorm2d: 3-431           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-432                 [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-433                [1, 2304, 7, 7]           20,736
# │    │    └─BatchNorm2d: 3-434           [1, 2304, 7, 7]           4,608
# │    │    └─Swish: 3-435                 [1, 2304, 7, 7]           --
# │    │    └─SEBlock: 3-436               [1, 2304, 7, 7]           2,657,088
# │    │    └─Conv2d: 3-437                [1, 640, 7, 7]            1,474,560
# │    │    └─BatchNorm2d: 3-438           [1, 640, 7, 7]            1,280
# │    └─MBConvBlock: 2-53                 [1, 640, 7, 7]            --
# │    │    └─Conv2d: 3-439                [1, 3840, 7, 7]           2,457,600
# │    │    └─BatchNorm2d: 3-440           [1, 3840, 7, 7]           7,680
# │    │    └─Swish: 3-441                 [1, 3840, 7, 7]           --
# │    │    └─Conv2d: 3-442                [1, 3840, 7, 7]           34,560
# │    │    └─BatchNorm2d: 3-443           [1, 3840, 7, 7]           7,680
# │    │    └─Swish: 3-444                 [1, 3840, 7, 7]           --
# │    │    └─SEBlock: 3-445               [1, 3840, 7, 7]           7,377,600
# │    │    └─Conv2d: 3-446                [1, 640, 7, 7]            2,457,600
# │    │    └─BatchNorm2d: 3-447           [1, 640, 7, 7]            1,280
# │    └─MBConvBlock: 2-54                 [1, 640, 7, 7]            --
# │    │    └─Conv2d: 3-448                [1, 3840, 7, 7]           2,457,600
# │    │    └─BatchNorm2d: 3-449           [1, 3840, 7, 7]           7,680
# │    │    └─Swish: 3-450                 [1, 3840, 7, 7]           --
# │    │    └─Conv2d: 3-451                [1, 3840, 7, 7]           34,560
# │    │    └─BatchNorm2d: 3-452           [1, 3840, 7, 7]           7,680
# │    │    └─Swish: 3-453                 [1, 3840, 7, 7]           --
# │    │    └─SEBlock: 3-454               [1, 3840, 7, 7]           7,377,600
# │    │    └─Conv2d: 3-455                [1, 640, 7, 7]            2,457,600
# │    │    └─BatchNorm2d: 3-456           [1, 640, 7, 7]            1,280
# │    └─MBConvBlock: 2-55                 [1, 640, 7, 7]            --
# │    │    └─Conv2d: 3-457                [1, 3840, 7, 7]           2,457,600
# │    │    └─BatchNorm2d: 3-458           [1, 3840, 7, 7]           7,680
# │    │    └─Swish: 3-459                 [1, 3840, 7, 7]           --
# │    │    └─Conv2d: 3-460                [1, 3840, 7, 7]           34,560
# │    │    └─BatchNorm2d: 3-461           [1, 3840, 7, 7]           7,680
# │    │    └─Swish: 3-462                 [1, 3840, 7, 7]           --
# │    │    └─SEBlock: 3-463               [1, 3840, 7, 7]           7,377,600
# │    │    └─Conv2d: 3-464                [1, 640, 7, 7]            2,457,600
# │    │    └─BatchNorm2d: 3-465           [1, 640, 7, 7]            1,280
# ├─Sequential: 1-3                        [1, 1000]                 --
# │    └─Conv2d: 2-56                      [1, 2560, 7, 7]           1,638,400
# │    └─BatchNorm2d: 2-57                 [1, 2560, 7, 7]           5,120
# │    └─Swish: 2-58                       [1, 2560, 7, 7]           --
# │    └─AdaptiveAvgPool2d: 2-59           [1, 2560, 1, 1]           --
# │    └─Flatten: 2-60                     [1, 2560]                 --
# │    └─Dropout: 2-61                     [1, 2560]                 --
# │    └─Linear: 2-62                      [1, 1000]                 2,561,000
# ==========================================================================================
# Total params: 125,838,184
# Trainable params: 125,838,184
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 5.18
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 602.47
# Params size (MB): 503.35
# Estimated Total Size (MB): 1106.43
# ==========================================================================================

# %% [markdown]
# ## PyTorch EfficientNet
#    - EfficientNet is available in PyTorch: [pytorch.org/vision/main/models/efficientnet.html](https://pytorch.org/vision/main/models/efficientnet.html)

# %% [markdown]
# ### EfficientNet-B0

# %%
efficientnet_b0_2 = efficientnet_b0()
efficientnet_b0_2
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b0_2, (1, 3, 224, 224), device='cpu')
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# EfficientNet                                            [1, 1000]                 --
# ├─Sequential: 1-1                                       [1, 1280, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                        [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-1                                 [1, 32, 112, 112]         864
# │    │    └─BatchNorm2d: 3-2                            [1, 32, 112, 112]         64
# │    │    └─SiLU: 3-3                                   [1, 32, 112, 112]         --
# │    └─Sequential: 2-2                                  [1, 16, 112, 112]         --
# │    │    └─MBConv: 3-4                                 [1, 16, 112, 112]         1,448
# │    └─Sequential: 2-3                                  [1, 24, 56, 56]           --
# │    │    └─MBConv: 3-5                                 [1, 24, 56, 56]           6,004
# │    │    └─MBConv: 3-6                                 [1, 24, 56, 56]           10,710
# │    └─Sequential: 2-4                                  [1, 40, 28, 28]           --
# │    │    └─MBConv: 3-7                                 [1, 40, 28, 28]           15,350
# │    │    └─MBConv: 3-8                                 [1, 40, 28, 28]           31,290
# │    └─Sequential: 2-5                                  [1, 80, 14, 14]           --
# │    │    └─MBConv: 3-9                                 [1, 80, 14, 14]           37,130
# │    │    └─MBConv: 3-10                                [1, 80, 14, 14]           102,900
# │    │    └─MBConv: 3-11                                [1, 80, 14, 14]           102,900
# │    └─Sequential: 2-6                                  [1, 112, 14, 14]          --
# │    │    └─MBConv: 3-12                                [1, 112, 14, 14]          126,004
# │    │    └─MBConv: 3-13                                [1, 112, 14, 14]          208,572
# │    │    └─MBConv: 3-14                                [1, 112, 14, 14]          208,572
# │    └─Sequential: 2-7                                  [1, 192, 7, 7]            --
# │    │    └─MBConv: 3-15                                [1, 192, 7, 7]            262,492
# │    │    └─MBConv: 3-16                                [1, 192, 7, 7]            587,952
# │    │    └─MBConv: 3-17                                [1, 192, 7, 7]            587,952
# │    │    └─MBConv: 3-18                                [1, 192, 7, 7]            587,952
# │    └─Sequential: 2-8                                  [1, 320, 7, 7]            --
# │    │    └─MBConv: 3-19                                [1, 320, 7, 7]            717,232
# │    └─Conv2dNormActivation: 2-9                        [1, 1280, 7, 7]           --
# │    │    └─Conv2d: 3-20                                [1, 1280, 7, 7]           409,600
# │    │    └─BatchNorm2d: 3-21                           [1, 1280, 7, 7]           2,560
# │    │    └─SiLU: 3-22                                  [1, 1280, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                                [1, 1280, 1, 1]           --
# ├─Sequential: 1-3                                       [1, 1000]                 --
# │    └─Dropout: 2-10                                    [1, 1280]                 --
# │    └─Linear: 2-11                                     [1, 1000]                 1,281,000
# =========================================================================================================
# Total params: 5,288,548
# Trainable params: 5,288,548
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 385.87
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 107.89
# Params size (MB): 21.15
# Estimated Total Size (MB): 129.64
# =========================================================================================================

# %% [markdown]
# ### EfficientNet-B1

# %%
efficientnet_b1_2 = efficientnet_b1()
efficientnet_b1_2
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 16, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.008695652173913044, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.017391304347826087, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.026086956521739136, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.034782608695652174, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.043478260869565216, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05217391304347827, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06086956521739131, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06956521739130435, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0782608695652174, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08695652173913043, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09565217391304348, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10434782608695654, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11304347826086956, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12173913043478261, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13043478260869565, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1391304347826087, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14782608695652175, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1565217391304348, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16521739130434784, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17391304347826086, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1826086956521739, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(320, 1920, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1920, 1920, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1920, bias=False)
#             (1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1920, 80, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(80, 1920, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1920, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19130434782608696, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b1_2, (1, 3, 224, 224), device='cpu')
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# EfficientNet                                            [1, 1000]                 --
# ├─Sequential: 1-1                                       [1, 1280, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                        [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-1                                 [1, 32, 112, 112]         864
# │    │    └─BatchNorm2d: 3-2                            [1, 32, 112, 112]         64
# │    │    └─SiLU: 3-3                                   [1, 32, 112, 112]         --
# │    └─Sequential: 2-2                                  [1, 16, 112, 112]         --
# │    │    └─MBConv: 3-4                                 [1, 16, 112, 112]         1,448
# │    │    └─MBConv: 3-5                                 [1, 16, 112, 112]         612
# │    └─Sequential: 2-3                                  [1, 24, 56, 56]           --
# │    │    └─MBConv: 3-6                                 [1, 24, 56, 56]           6,004
# │    │    └─MBConv: 3-7                                 [1, 24, 56, 56]           10,710
# │    │    └─MBConv: 3-8                                 [1, 24, 56, 56]           10,710
# │    └─Sequential: 2-4                                  [1, 40, 28, 28]           --
# │    │    └─MBConv: 3-9                                 [1, 40, 28, 28]           15,350
# │    │    └─MBConv: 3-10                                [1, 40, 28, 28]           31,290
# │    │    └─MBConv: 3-11                                [1, 40, 28, 28]           31,290
# │    └─Sequential: 2-5                                  [1, 80, 14, 14]           --
# │    │    └─MBConv: 3-12                                [1, 80, 14, 14]           37,130
# │    │    └─MBConv: 3-13                                [1, 80, 14, 14]           102,900
# │    │    └─MBConv: 3-14                                [1, 80, 14, 14]           102,900
# │    │    └─MBConv: 3-15                                [1, 80, 14, 14]           102,900
# │    └─Sequential: 2-6                                  [1, 112, 14, 14]          --
# │    │    └─MBConv: 3-16                                [1, 112, 14, 14]          126,004
# │    │    └─MBConv: 3-17                                [1, 112, 14, 14]          208,572
# │    │    └─MBConv: 3-18                                [1, 112, 14, 14]          208,572
# │    │    └─MBConv: 3-19                                [1, 112, 14, 14]          208,572
# │    └─Sequential: 2-7                                  [1, 192, 7, 7]            --
# │    │    └─MBConv: 3-20                                [1, 192, 7, 7]            262,492
# │    │    └─MBConv: 3-21                                [1, 192, 7, 7]            587,952
# │    │    └─MBConv: 3-22                                [1, 192, 7, 7]            587,952
# │    │    └─MBConv: 3-23                                [1, 192, 7, 7]            587,952
# │    │    └─MBConv: 3-24                                [1, 192, 7, 7]            587,952
# │    └─Sequential: 2-8                                  [1, 320, 7, 7]            --
# │    │    └─MBConv: 3-25                                [1, 320, 7, 7]            717,232
# │    │    └─MBConv: 3-26                                [1, 320, 7, 7]            1,563,600
# │    └─Conv2dNormActivation: 2-9                        [1, 1280, 7, 7]           --
# │    │    └─Conv2d: 3-27                                [1, 1280, 7, 7]           409,600
# │    │    └─BatchNorm2d: 3-28                           [1, 1280, 7, 7]           2,560
# │    │    └─SiLU: 3-29                                  [1, 1280, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                                [1, 1280, 1, 1]           --
# ├─Sequential: 1-3                                       [1, 1000]                 --
# │    └─Dropout: 2-10                                    [1, 1280]                 --
# │    └─Linear: 2-11                                     [1, 1000]                 1,281,000
# =========================================================================================================
# Total params: 7,794,184
# Trainable params: 7,794,184
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 569.73
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 149.57
# Params size (MB): 31.18
# Estimated Total Size (MB): 181.35
# =========================================================================================================

# %% [markdown]
# ### EfficientNet-B2

# %%
efficientnet_b2_2 = efficientnet_b2()
efficientnet_b2_2
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 16, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.008695652173913044, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.017391304347826087, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.026086956521739136, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.034782608695652174, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.043478260869565216, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05217391304347827, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06086956521739131, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06956521739130435, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0782608695652174, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08695652173913043, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09565217391304348, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(528, 528, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=528, bias=False)
#             (1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(528, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10434782608695654, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11304347826086956, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12173913043478261, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13043478260869565, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(720, 720, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=720, bias=False)
#             (1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(720, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1391304347826087, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14782608695652175, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1565217391304348, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16521739130434784, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17391304347826086, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1248, 1248, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1248, bias=False)
#             (1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1248, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1826086956521739, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(352, 2112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2112, 2112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2112, bias=False)
#             (1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2112, 88, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(88, 2112, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2112, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19130434782608696, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=True)
#     (1): Linear(in_features=1408, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b2_2, (1, 3, 224, 224), device='cpu')
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# EfficientNet                                            [1, 1000]                 --
# ├─Sequential: 1-1                                       [1, 1408, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                        [1, 32, 112, 112]         --
# │    │    └─Conv2d: 3-1                                 [1, 32, 112, 112]         864
# │    │    └─BatchNorm2d: 3-2                            [1, 32, 112, 112]         64
# │    │    └─SiLU: 3-3                                   [1, 32, 112, 112]         --
# │    └─Sequential: 2-2                                  [1, 16, 112, 112]         --
# │    │    └─MBConv: 3-4                                 [1, 16, 112, 112]         1,448
# │    │    └─MBConv: 3-5                                 [1, 16, 112, 112]         612
# │    └─Sequential: 2-3                                  [1, 24, 56, 56]           --
# │    │    └─MBConv: 3-6                                 [1, 24, 56, 56]           6,004
# │    │    └─MBConv: 3-7                                 [1, 24, 56, 56]           10,710
# │    │    └─MBConv: 3-8                                 [1, 24, 56, 56]           10,710
# │    └─Sequential: 2-4                                  [1, 48, 28, 28]           --
# │    │    └─MBConv: 3-9                                 [1, 48, 28, 28]           16,518
# │    │    └─MBConv: 3-10                                [1, 48, 28, 28]           43,308
# │    │    └─MBConv: 3-11                                [1, 48, 28, 28]           43,308
# │    └─Sequential: 2-5                                  [1, 88, 14, 14]           --
# │    │    └─MBConv: 3-12                                [1, 88, 14, 14]           50,300
# │    │    └─MBConv: 3-13                                [1, 88, 14, 14]           123,750
# │    │    └─MBConv: 3-14                                [1, 88, 14, 14]           123,750
# │    │    └─MBConv: 3-15                                [1, 88, 14, 14]           123,750
# │    └─Sequential: 2-6                                  [1, 120, 14, 14]          --
# │    │    └─MBConv: 3-16                                [1, 120, 14, 14]          149,158
# │    │    └─MBConv: 3-17                                [1, 120, 14, 14]          237,870
# │    │    └─MBConv: 3-18                                [1, 120, 14, 14]          237,870
# │    │    └─MBConv: 3-19                                [1, 120, 14, 14]          237,870
# │    └─Sequential: 2-7                                  [1, 208, 7, 7]            --
# │    │    └─MBConv: 3-20                                [1, 208, 7, 7]            301,406
# │    │    └─MBConv: 3-21                                [1, 208, 7, 7]            686,868
# │    │    └─MBConv: 3-22                                [1, 208, 7, 7]            686,868
# │    │    └─MBConv: 3-23                                [1, 208, 7, 7]            686,868
# │    │    └─MBConv: 3-24                                [1, 208, 7, 7]            686,868
# │    └─Sequential: 2-8                                  [1, 352, 7, 7]            --
# │    │    └─MBConv: 3-25                                [1, 352, 7, 7]            846,900
# │    │    └─MBConv: 3-26                                [1, 352, 7, 7]            1,888,920
# │    └─Conv2dNormActivation: 2-9                        [1, 1408, 7, 7]           --
# │    │    └─Conv2d: 3-27                                [1, 1408, 7, 7]           495,616
# │    │    └─BatchNorm2d: 3-28                           [1, 1408, 7, 7]           2,816
# │    │    └─SiLU: 3-29                                  [1, 1408, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                                [1, 1408, 1, 1]           --
# ├─Sequential: 1-3                                       [1, 1000]                 --
# │    └─Dropout: 2-10                                    [1, 1408]                 --
# │    └─Linear: 2-11                                     [1, 1000]                 1,409,000
# =========================================================================================================
# Total params: 9,109,994
# Trainable params: 9,109,994
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 659.05
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 156.81
# Params size (MB): 36.44
# Estimated Total Size (MB): 193.85
# =========================================================================================================

# %% [markdown]
# ### EfficientNet-B3

# %%
efficientnet_b3_2 = efficientnet_b3()
efficientnet_b3_2
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 40, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(40, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 40, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(40, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.007692307692307693, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.015384615384615385, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.02307692307692308, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03076923076923077, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.038461538461538464, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04615384615384616, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05384615384615385, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06153846153846154, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06923076923076923, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07692307692307693, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08461538461538462, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09230769230769233, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(576, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#             (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1076923076923077, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#             (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11538461538461539, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#             (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12307692307692308, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#             (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13076923076923078, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(816, 816, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=816, bias=False)
#             (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(816, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13846153846153847, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14615384615384616, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15384615384615385, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16153846153846155, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16923076923076924, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17692307692307693, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1392, 1392, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1392, bias=False)
#             (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1392, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18461538461538465, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19230769230769232, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=True)
#     (1): Linear(in_features=1536, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b3_2, (1, 3, 224, 224), device='cpu')
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# EfficientNet                                            [1, 1000]                 --
# ├─Sequential: 1-1                                       [1, 1536, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                        [1, 40, 112, 112]         --
# │    │    └─Conv2d: 3-1                                 [1, 40, 112, 112]         1,080
# │    │    └─BatchNorm2d: 3-2                            [1, 40, 112, 112]         80
# │    │    └─SiLU: 3-3                                   [1, 40, 112, 112]         --
# │    └─Sequential: 2-2                                  [1, 24, 112, 112]         --
# │    │    └─MBConv: 3-4                                 [1, 24, 112, 112]         2,298
# │    │    └─MBConv: 3-5                                 [1, 24, 112, 112]         1,206
# │    └─Sequential: 2-3                                  [1, 32, 56, 56]           --
# │    │    └─MBConv: 3-6                                 [1, 32, 56, 56]           11,878
# │    │    └─MBConv: 3-7                                 [1, 32, 56, 56]           18,120
# │    │    └─MBConv: 3-8                                 [1, 32, 56, 56]           18,120
# │    └─Sequential: 2-4                                  [1, 48, 28, 28]           --
# │    │    └─MBConv: 3-9                                 [1, 48, 28, 28]           24,296
# │    │    └─MBConv: 3-10                                [1, 48, 28, 28]           43,308
# │    │    └─MBConv: 3-11                                [1, 48, 28, 28]           43,308
# │    └─Sequential: 2-5                                  [1, 96, 14, 14]           --
# │    │    └─MBConv: 3-12                                [1, 96, 14, 14]           52,620
# │    │    └─MBConv: 3-13                                [1, 96, 14, 14]           146,520
# │    │    └─MBConv: 3-14                                [1, 96, 14, 14]           146,520
# │    │    └─MBConv: 3-15                                [1, 96, 14, 14]           146,520
# │    │    └─MBConv: 3-16                                [1, 96, 14, 14]           146,520
# │    └─Sequential: 2-6                                  [1, 136, 14, 14]          --
# │    │    └─MBConv: 3-17                                [1, 136, 14, 14]          178,856
# │    │    └─MBConv: 3-18                                [1, 136, 14, 14]          302,226
# │    │    └─MBConv: 3-19                                [1, 136, 14, 14]          302,226
# │    │    └─MBConv: 3-20                                [1, 136, 14, 14]          302,226
# │    │    └─MBConv: 3-21                                [1, 136, 14, 14]          302,226
# │    └─Sequential: 2-7                                  [1, 232, 7, 7]            --
# │    │    └─MBConv: 3-22                                [1, 232, 7, 7]            380,754
# │    │    └─MBConv: 3-23                                [1, 232, 7, 7]            849,642
# │    │    └─MBConv: 3-24                                [1, 232, 7, 7]            849,642
# │    │    └─MBConv: 3-25                                [1, 232, 7, 7]            849,642
# │    │    └─MBConv: 3-26                                [1, 232, 7, 7]            849,642
# │    │    └─MBConv: 3-27                                [1, 232, 7, 7]            849,642
# │    └─Sequential: 2-8                                  [1, 384, 7, 7]            --
# │    │    └─MBConv: 3-28                                [1, 384, 7, 7]            1,039,258
# │    │    └─MBConv: 3-29                                [1, 384, 7, 7]            2,244,960
# │    └─Conv2dNormActivation: 2-9                        [1, 1536, 7, 7]           --
# │    │    └─Conv2d: 3-30                                [1, 1536, 7, 7]           589,824
# │    │    └─BatchNorm2d: 3-31                           [1, 1536, 7, 7]           3,072
# │    │    └─SiLU: 3-32                                  [1, 1536, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                                [1, 1536, 1, 1]           --
# ├─Sequential: 1-3                                       [1, 1000]                 --
# │    └─Dropout: 2-10                                    [1, 1536]                 --
# │    └─Linear: 2-11                                     [1, 1000]                 1,537,000
# =========================================================================================================
# Total params: 12,233,232
# Trainable params: 12,233,232
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 962.82
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 207.95
# Params size (MB): 48.93
# Estimated Total Size (MB): 257.48
# =========================================================================================================

# %% [markdown]
# ### EfficientNet-B4

# %%
efficientnet_b4_2 = efficientnet_b4()
efficientnet_b4_2
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.00625, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.018750000000000003, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03125, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(192, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336, bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.043750000000000004, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336, bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336, bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05625, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=336, bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(336, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06875, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08125, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09375, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10625000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11875000000000001, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14375000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15625, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16875, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18125000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1632, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(448, 2688, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2688, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2688, 2688, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2688, bias=False)
#             (1): BatchNorm2d(2688, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2688, 112, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(112, 2688, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2688, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19375, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(448, 1792, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.4, inplace=True)
#     (1): Linear(in_features=1792, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b4_2, (1, 3, 224, 224), device='cpu')
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# EfficientNet                                            [1, 1000]                 --
# ├─Sequential: 1-1                                       [1, 1792, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                        [1, 48, 112, 112]         --
# │    │    └─Conv2d: 3-1                                 [1, 48, 112, 112]         1,296
# │    │    └─BatchNorm2d: 3-2                            [1, 48, 112, 112]         96
# │    │    └─SiLU: 3-3                                   [1, 48, 112, 112]         --
# │    └─Sequential: 2-2                                  [1, 24, 112, 112]         --
# │    │    └─MBConv: 3-4                                 [1, 24, 112, 112]         2,940
# │    │    └─MBConv: 3-5                                 [1, 24, 112, 112]         1,206
# │    └─Sequential: 2-3                                  [1, 32, 56, 56]           --
# │    │    └─MBConv: 3-6                                 [1, 32, 56, 56]           11,878
# │    │    └─MBConv: 3-7                                 [1, 32, 56, 56]           18,120
# │    │    └─MBConv: 3-8                                 [1, 32, 56, 56]           18,120
# │    │    └─MBConv: 3-9                                 [1, 32, 56, 56]           18,120
# │    └─Sequential: 2-4                                  [1, 56, 28, 28]           --
# │    │    └─MBConv: 3-10                                [1, 56, 28, 28]           25,848
# │    │    └─MBConv: 3-11                                [1, 56, 28, 28]           57,246
# │    │    └─MBConv: 3-12                                [1, 56, 28, 28]           57,246
# │    │    └─MBConv: 3-13                                [1, 56, 28, 28]           57,246
# │    └─Sequential: 2-5                                  [1, 112, 14, 14]          --
# │    │    └─MBConv: 3-14                                [1, 112, 14, 14]          70,798
# │    │    └─MBConv: 3-15                                [1, 112, 14, 14]          197,820
# │    │    └─MBConv: 3-16                                [1, 112, 14, 14]          197,820
# │    │    └─MBConv: 3-17                                [1, 112, 14, 14]          197,820
# │    │    └─MBConv: 3-18                                [1, 112, 14, 14]          197,820
# │    │    └─MBConv: 3-19                                [1, 112, 14, 14]          197,820
# │    └─Sequential: 2-6                                  [1, 160, 14, 14]          --
# │    │    └─MBConv: 3-20                                [1, 160, 14, 14]          240,924
# │    │    └─MBConv: 3-21                                [1, 160, 14, 14]          413,160
# │    │    └─MBConv: 3-22                                [1, 160, 14, 14]          413,160
# │    │    └─MBConv: 3-23                                [1, 160, 14, 14]          413,160
# │    │    └─MBConv: 3-24                                [1, 160, 14, 14]          413,160
# │    │    └─MBConv: 3-25                                [1, 160, 14, 14]          413,160
# │    └─Sequential: 2-7                                  [1, 272, 7, 7]            --
# │    │    └─MBConv: 3-26                                [1, 272, 7, 7]            520,904
# │    │    └─MBConv: 3-27                                [1, 272, 7, 7]            1,159,332
# │    │    └─MBConv: 3-28                                [1, 272, 7, 7]            1,159,332
# │    │    └─MBConv: 3-29                                [1, 272, 7, 7]            1,159,332
# │    │    └─MBConv: 3-30                                [1, 272, 7, 7]            1,159,332
# │    │    └─MBConv: 3-31                                [1, 272, 7, 7]            1,159,332
# │    │    └─MBConv: 3-32                                [1, 272, 7, 7]            1,159,332
# │    │    └─MBConv: 3-33                                [1, 272, 7, 7]            1,159,332
# │    └─Sequential: 2-8                                  [1, 448, 7, 7]            --
# │    │    └─MBConv: 3-34                                [1, 448, 7, 7]            1,420,804
# │    │    └─MBConv: 3-35                                [1, 448, 7, 7]            3,049,200
# │    └─Conv2dNormActivation: 2-9                        [1, 1792, 7, 7]           --
# │    │    └─Conv2d: 3-36                                [1, 1792, 7, 7]           802,816
# │    │    └─BatchNorm2d: 3-37                           [1, 1792, 7, 7]           3,584
# │    │    └─SiLU: 3-38                                  [1, 1792, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                                [1, 1792, 1, 1]           --
# ├─Sequential: 1-3                                       [1, 1000]                 --
# │    └─Dropout: 2-10                                    [1, 1792]                 --
# │    └─Linear: 2-11                                     [1, 1000]                 1,793,000
# =========================================================================================================
# Total params: 19,341,616
# Trainable params: 19,341,616
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.50
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 272.50
# Params size (MB): 77.37
# Estimated Total Size (MB): 350.46
# =========================================================================================================

# %% [markdown]
# ### EfficientNet-B5

# %%
efficientnet_b5_2 = efficientnet_b5()
efficientnet_b5_2
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.005128205128205128, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.010256410256410256, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.015384615384615387, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.020512820512820513, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.02564102564102564, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.030769230769230774, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0358974358974359, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.041025641025641026, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(384, 16, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16, 384, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.046153846153846156, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(384, 16, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16, 384, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05128205128205128, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(384, 16, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16, 384, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05641025641025642, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(384, 16, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16, 384, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06153846153846155, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(384, 16, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16, 384, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06666666666666667, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0717948717948718, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07692307692307693, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08205128205128205, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08717948717948719, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09230769230769231, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09743589743589744, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#             (1): BatchNorm2d(768, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(768, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(176, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10256410256410256, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1056, 1056, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1056, bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(176, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1076923076923077, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1056, 1056, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1056, bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(176, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11282051282051284, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1056, 1056, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1056, bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(176, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11794871794871796, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1056, 1056, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1056, bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(176, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1230769230769231, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1056, 1056, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1056, bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(176, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1282051282051282, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1056, 1056, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1056, bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(176, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13333333333333333, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1056, 1056, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=1056, bias=False)
#             (1): BatchNorm2d(1056, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1056, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13846153846153847, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1824, 1824, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1824, bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1435897435897436, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1824, 1824, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1824, bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14871794871794874, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1824, 1824, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1824, bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15384615384615385, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1824, 1824, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1824, bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.158974358974359, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1824, 1824, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1824, bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1641025641025641, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1824, 1824, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1824, bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16923076923076924, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1824, 1824, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1824, bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17435897435897438, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1824, 1824, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1824, bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1794871794871795, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#             (1): BatchNorm2d(1824, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1824, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18461538461538463, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3072, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#             (1): BatchNorm2d(3072, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3072, 128, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(128, 3072, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18974358974358976, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3072, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#             (1): BatchNorm2d(3072, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3072, 128, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(128, 3072, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19487179487179487, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2048, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.4, inplace=True)
#     (1): Linear(in_features=2048, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b5_2, (1, 3, 224, 224), device='cpu')
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# EfficientNet                                            [1, 1000]                 --
# ├─Sequential: 1-1                                       [1, 2048, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                        [1, 48, 112, 112]         --
# │    │    └─Conv2d: 3-1                                 [1, 48, 112, 112]         1,296
# │    │    └─BatchNorm2d: 3-2                            [1, 48, 112, 112]         96
# │    │    └─SiLU: 3-3                                   [1, 48, 112, 112]         --
# │    └─Sequential: 2-2                                  [1, 24, 112, 112]         --
# │    │    └─MBConv: 3-4                                 [1, 24, 112, 112]         2,940
# │    │    └─MBConv: 3-5                                 [1, 24, 112, 112]         1,206
# │    │    └─MBConv: 3-6                                 [1, 24, 112, 112]         1,206
# │    └─Sequential: 2-3                                  [1, 40, 56, 56]           --
# │    │    └─MBConv: 3-7                                 [1, 40, 56, 56]           13,046
# │    │    └─MBConv: 3-8                                 [1, 40, 56, 56]           27,450
# │    │    └─MBConv: 3-9                                 [1, 40, 56, 56]           27,450
# │    │    └─MBConv: 3-10                                [1, 40, 56, 56]           27,450
# │    │    └─MBConv: 3-11                                [1, 40, 56, 56]           27,450
# │    └─Sequential: 2-4                                  [1, 64, 28, 28]           --
# │    │    └─MBConv: 3-12                                [1, 64, 28, 28]           37,098
# │    │    └─MBConv: 3-13                                [1, 64, 28, 28]           73,104
# │    │    └─MBConv: 3-14                                [1, 64, 28, 28]           73,104
# │    │    └─MBConv: 3-15                                [1, 64, 28, 28]           73,104
# │    │    └─MBConv: 3-16                                [1, 64, 28, 28]           73,104
# │    └─Sequential: 2-5                                  [1, 128, 14, 14]          --
# │    │    └─MBConv: 3-17                                [1, 128, 14, 14]          91,664
# │    │    └─MBConv: 3-18                                [1, 128, 14, 14]          256,800
# │    │    └─MBConv: 3-19                                [1, 128, 14, 14]          256,800
# │    │    └─MBConv: 3-20                                [1, 128, 14, 14]          256,800
# │    │    └─MBConv: 3-21                                [1, 128, 14, 14]          256,800
# │    │    └─MBConv: 3-22                                [1, 128, 14, 14]          256,800
# │    │    └─MBConv: 3-23                                [1, 128, 14, 14]          256,800
# │    └─Sequential: 2-6                                  [1, 176, 14, 14]          --
# │    │    └─MBConv: 3-24                                [1, 176, 14, 14]          306,048
# │    │    └─MBConv: 3-25                                [1, 176, 14, 14]          496,716
# │    │    └─MBConv: 3-26                                [1, 176, 14, 14]          496,716
# │    │    └─MBConv: 3-27                                [1, 176, 14, 14]          496,716
# │    │    └─MBConv: 3-28                                [1, 176, 14, 14]          496,716
# │    │    └─MBConv: 3-29                                [1, 176, 14, 14]          496,716
# │    │    └─MBConv: 3-30                                [1, 176, 14, 14]          496,716
# │    └─Sequential: 2-7                                  [1, 304, 7, 7]            --
# │    │    └─MBConv: 3-31                                [1, 304, 7, 7]            632,140
# │    │    └─MBConv: 3-32                                [1, 304, 7, 7]            1,441,644
# │    │    └─MBConv: 3-33                                [1, 304, 7, 7]            1,441,644
# │    │    └─MBConv: 3-34                                [1, 304, 7, 7]            1,441,644
# │    │    └─MBConv: 3-35                                [1, 304, 7, 7]            1,441,644
# │    │    └─MBConv: 3-36                                [1, 304, 7, 7]            1,441,644
# │    │    └─MBConv: 3-37                                [1, 304, 7, 7]            1,441,644
# │    │    └─MBConv: 3-38                                [1, 304, 7, 7]            1,441,644
# │    │    └─MBConv: 3-39                                [1, 304, 7, 7]            1,441,644
# │    └─Sequential: 2-8                                  [1, 512, 7, 7]            --
# │    │    └─MBConv: 3-40                                [1, 512, 7, 7]            1,792,268
# │    │    └─MBConv: 3-41                                [1, 512, 7, 7]            3,976,320
# │    │    └─MBConv: 3-42                                [1, 512, 7, 7]            3,976,320
# │    └─Conv2dNormActivation: 2-9                        [1, 2048, 7, 7]           --
# │    │    └─Conv2d: 3-43                                [1, 2048, 7, 7]           1,048,576
# │    │    └─BatchNorm2d: 3-44                           [1, 2048, 7, 7]           4,096
# │    │    └─SiLU: 3-45                                  [1, 2048, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                                [1, 2048, 1, 1]           --
# ├─Sequential: 1-3                                       [1, 1000]                 --
# │    └─Dropout: 2-10                                    [1, 2048]                 --
# │    └─Linear: 2-11                                     [1, 1000]                 2,049,000
# =========================================================================================================
# Total params: 30,389,784
# Trainable params: 30,389,784
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.36
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 374.41
# Params size (MB): 121.56
# Estimated Total Size (MB): 496.57
# =========================================================================================================

# %% [markdown]
# ### EfficientNet-B6

# %%
efficientnet_b6_2 = efficientnet_b6()
efficientnet_b6_2
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 56, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(56, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(56, 56, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=56, bias=False)
#             (1): BatchNorm2d(56, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(56, 14, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(14, 56, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(56, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0044444444444444444, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.008888888888888889, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(192, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.013333333333333336, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.017777777777777778, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.022222222222222223, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.026666666666666672, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.031111111111111114, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.035555555555555556, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.044444444444444446, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04888888888888889, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.053333333333333344, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05777777777777778, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06222222222222223, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06666666666666667, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07111111111111111, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07555555555555557, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08444444444444445, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08888888888888889, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09333333333333334, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09777777777777778, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(864, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10222222222222223, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10666666666666669, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1111111111111111, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11555555555555556, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12000000000000001, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12444444444444445, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12888888888888891, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13333333333333333, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1200, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13777777777777778, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14222222222222222, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14666666666666667, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15111111111111114, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15555555555555556, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16444444444444445, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1688888888888889, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17333333333333334, mode=row)
#       )
#       (9): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17777777777777778, mode=row)
#       )
#       (10): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18222222222222226, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2064, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18666666666666668, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(576, 3456, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3456, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3456, 3456, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3456, bias=False)
#             (1): BatchNorm2d(3456, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3456, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 3456, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3456, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1911111111111111, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(576, 3456, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3456, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3456, 3456, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3456, bias=False)
#             (1): BatchNorm2d(3456, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3456, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 3456, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3456, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19555555555555557, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(576, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=True)
#     (1): Linear(in_features=2304, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b6_2, (1, 3, 224, 224), device='cpu')
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# EfficientNet                                            [1, 1000]                 --
# ├─Sequential: 1-1                                       [1, 2304, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                        [1, 56, 112, 112]         --
# │    │    └─Conv2d: 3-1                                 [1, 56, 112, 112]         1,512
# │    │    └─BatchNorm2d: 3-2                            [1, 56, 112, 112]         112
# │    │    └─SiLU: 3-3                                   [1, 56, 112, 112]         --
# │    └─Sequential: 2-2                                  [1, 32, 112, 112]         --
# │    │    └─MBConv: 3-4                                 [1, 32, 112, 112]         4,110
# │    │    └─MBConv: 3-5                                 [1, 32, 112, 112]         1,992
# │    │    └─MBConv: 3-6                                 [1, 32, 112, 112]         1,992
# │    └─Sequential: 2-3                                  [1, 40, 56, 56]           --
# │    │    └─MBConv: 3-7                                 [1, 40, 56, 56]           19,672
# │    │    └─MBConv: 3-8                                 [1, 40, 56, 56]           27,450
# │    │    └─MBConv: 3-9                                 [1, 40, 56, 56]           27,450
# │    │    └─MBConv: 3-10                                [1, 40, 56, 56]           27,450
# │    │    └─MBConv: 3-11                                [1, 40, 56, 56]           27,450
# │    │    └─MBConv: 3-12                                [1, 40, 56, 56]           27,450
# │    └─Sequential: 2-4                                  [1, 72, 28, 28]           --
# │    │    └─MBConv: 3-13                                [1, 72, 28, 28]           39,034
# │    │    └─MBConv: 3-14                                [1, 72, 28, 28]           90,882
# │    │    └─MBConv: 3-15                                [1, 72, 28, 28]           90,882
# │    │    └─MBConv: 3-16                                [1, 72, 28, 28]           90,882
# │    │    └─MBConv: 3-17                                [1, 72, 28, 28]           90,882
# │    │    └─MBConv: 3-18                                [1, 72, 28, 28]           90,882
# │    └─Sequential: 2-5                                  [1, 144, 14, 14]          --
# │    │    └─MBConv: 3-19                                [1, 144, 14, 14]          115,218
# │    │    └─MBConv: 3-20                                [1, 144, 14, 14]          323,460
# │    │    └─MBConv: 3-21                                [1, 144, 14, 14]          323,460
# │    │    └─MBConv: 3-22                                [1, 144, 14, 14]          323,460
# │    │    └─MBConv: 3-23                                [1, 144, 14, 14]          323,460
# │    │    └─MBConv: 3-24                                [1, 144, 14, 14]          323,460
# │    │    └─MBConv: 3-25                                [1, 144, 14, 14]          323,460
# │    │    └─MBConv: 3-26                                [1, 144, 14, 14]          323,460
# │    └─Sequential: 2-6                                  [1, 200, 14, 14]          --
# │    │    └─MBConv: 3-27                                [1, 200, 14, 14]          385,780
# │    │    └─MBConv: 3-28                                [1, 200, 14, 14]          636,450
# │    │    └─MBConv: 3-29                                [1, 200, 14, 14]          636,450
# │    │    └─MBConv: 3-30                                [1, 200, 14, 14]          636,450
# │    │    └─MBConv: 3-31                                [1, 200, 14, 14]          636,450
# │    │    └─MBConv: 3-32                                [1, 200, 14, 14]          636,450
# │    │    └─MBConv: 3-33                                [1, 200, 14, 14]          636,450
# │    │    └─MBConv: 3-34                                [1, 200, 14, 14]          636,450
# │    └─Sequential: 2-7                                  [1, 344, 7, 7]            --
# │    │    └─MBConv: 3-35                                [1, 344, 7, 7]            809,538
# │    │    └─MBConv: 3-36                                [1, 344, 7, 7]            1,837,734
# │    │    └─MBConv: 3-37                                [1, 344, 7, 7]            1,837,734
# │    │    └─MBConv: 3-38                                [1, 344, 7, 7]            1,837,734
# │    │    └─MBConv: 3-39                                [1, 344, 7, 7]            1,837,734
# │    │    └─MBConv: 3-40                                [1, 344, 7, 7]            1,837,734
# │    │    └─MBConv: 3-41                                [1, 344, 7, 7]            1,837,734
# │    │    └─MBConv: 3-42                                [1, 344, 7, 7]            1,837,734
# │    │    └─MBConv: 3-43                                [1, 344, 7, 7]            1,837,734
# │    │    └─MBConv: 3-44                                [1, 344, 7, 7]            1,837,734
# │    │    └─MBConv: 3-45                                [1, 344, 7, 7]            1,837,734
# │    └─Sequential: 2-8                                  [1, 576, 7, 7]            --
# │    │    └─MBConv: 3-46                                [1, 576, 7, 7]            2,284,022
# │    │    └─MBConv: 3-47                                [1, 576, 7, 7]            5,026,320
# │    │    └─MBConv: 3-48                                [1, 576, 7, 7]            5,026,320
# │    └─Conv2dNormActivation: 2-9                        [1, 2304, 7, 7]           --
# │    │    └─Conv2d: 3-49                                [1, 2304, 7, 7]           1,327,104
# │    │    └─BatchNorm2d: 3-50                           [1, 2304, 7, 7]           4,608
# │    │    └─SiLU: 3-51                                  [1, 2304, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                                [1, 2304, 1, 1]           --
# ├─Sequential: 1-3                                       [1, 1000]                 --
# │    └─Dropout: 2-10                                    [1, 2304]                 --
# │    └─Linear: 2-11                                     [1, 1000]                 2,305,000
# =========================================================================================================
# Total params: 43,040,704
# Trainable params: 43,040,704
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 3.36
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 479.03
# Params size (MB): 172.16
# Estimated Total Size (MB): 651.79
# =========================================================================================================

# %% [markdown]
# ### EfficientNet-B7

# %%
efficientnet_b7_2 = efficientnet_b7()
efficientnet_b7_2
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0036363636363636364, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.007272727272727273, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.01090909090909091, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.014545454545454545, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.01818181818181818, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.02181818181818182, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025454545454545455, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.02909090909090909, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03272727272727273, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03636363636363636, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#             (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(288, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04363636363636364, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04727272727272727, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05090909090909091, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05454545454545454, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05818181818181818, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06181818181818183, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06545454545454546, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06909090909090909, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07272727272727272, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07636363636363637, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08363636363636365, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08727272727272728, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09090909090909091, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09454545454545454, mode=row)
#       )
#       (9): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09818181818181819, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(960, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10181818181818182, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10545454545454547, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10909090909090909, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11272727272727273, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11636363636363636, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12000000000000001, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12363636363636366, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12727272727272726, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13090909090909092, mode=row)
#       )
#       (9): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56, 1344, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13454545454545455, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1344, 1344, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=1344, bias=False)
#             (1): BatchNorm2d(1344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1344, 56, kernel_size=(1, 1), stride=(1, 1))
# ...
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15272727272727274, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15636363636363634, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16363636363636364, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1672727272727273, mode=row)
#       )
#       (9): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17090909090909093, mode=row)
#       )
#       (10): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17454545454545456, mode=row)
#       )
#       (11): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1781818181818182, mode=row)
#       )
#       (12): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18181818181818182, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#             (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(2304, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18545454545454548, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1890909090909091, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19272727272727275, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(640, 3840, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(3840, 3840, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3840, bias=False)
#             (1): BatchNorm2d(3840, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3840, 160, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(160, 3840, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(3840, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19636363636363638, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(640, 2560, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2560, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=True)
#     (1): Linear(in_features=2560, out_features=1000, bias=True)
#   )
# )

# %%
summary(efficientnet_b7_2, (1, 3, 224, 224), device='cpu')
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# EfficientNet                                            [1, 1000]                 --
# ├─Sequential: 1-1                                       [1, 2560, 7, 7]           --
# │    └─Conv2dNormActivation: 2-1                        [1, 64, 112, 112]         --
# │    │    └─Conv2d: 3-1                                 [1, 64, 112, 112]         1,728
# │    │    └─BatchNorm2d: 3-2                            [1, 64, 112, 112]         128
# │    │    └─SiLU: 3-3                                   [1, 64, 112, 112]         --
# │    └─Sequential: 2-2                                  [1, 32, 112, 112]         --
# │    │    └─MBConv: 3-4                                 [1, 32, 112, 112]         4,944
# │    │    └─MBConv: 3-5                                 [1, 32, 112, 112]         1,992
# │    │    └─MBConv: 3-6                                 [1, 32, 112, 112]         1,992
# │    │    └─MBConv: 3-7                                 [1, 32, 112, 112]         1,992
# │    └─Sequential: 2-3                                  [1, 48, 56, 56]           --
# │    │    └─MBConv: 3-8                                 [1, 48, 56, 56]           21,224
# │    │    └─MBConv: 3-9                                 [1, 48, 56, 56]           38,700
# │    │    └─MBConv: 3-10                                [1, 48, 56, 56]           38,700
# │    │    └─MBConv: 3-11                                [1, 48, 56, 56]           38,700
# │    │    └─MBConv: 3-12                                [1, 48, 56, 56]           38,700
# │    │    └─MBConv: 3-13                                [1, 48, 56, 56]           38,700
# │    │    └─MBConv: 3-14                                [1, 48, 56, 56]           38,700
# │    └─Sequential: 2-4                                  [1, 80, 28, 28]           --
# │    │    └─MBConv: 3-15                                [1, 80, 28, 28]           52,588
# │    │    └─MBConv: 3-16                                [1, 80, 28, 28]           110,580
# │    │    └─MBConv: 3-17                                [1, 80, 28, 28]           110,580
# │    │    └─MBConv: 3-18                                [1, 80, 28, 28]           110,580
# │    │    └─MBConv: 3-19                                [1, 80, 28, 28]           110,580
# │    │    └─MBConv: 3-20                                [1, 80, 28, 28]           110,580
# │    │    └─MBConv: 3-21                                [1, 80, 28, 28]           110,580
# │    └─Sequential: 2-5                                  [1, 160, 14, 14]          --
# │    │    └─MBConv: 3-22                                [1, 160, 14, 14]          141,460
# │    │    └─MBConv: 3-23                                [1, 160, 14, 14]          397,800
# │    │    └─MBConv: 3-24                                [1, 160, 14, 14]          397,800
# │    │    └─MBConv: 3-25                                [1, 160, 14, 14]          397,800
# │    │    └─MBConv: 3-26                                [1, 160, 14, 14]          397,800
# │    │    └─MBConv: 3-27                                [1, 160, 14, 14]          397,800
# │    │    └─MBConv: 3-28                                [1, 160, 14, 14]          397,800
# │    │    └─MBConv: 3-29                                [1, 160, 14, 14]          397,800
# │    │    └─MBConv: 3-30                                [1, 160, 14, 14]          397,800
# │    │    └─MBConv: 3-31                                [1, 160, 14, 14]          397,800
# │    └─Sequential: 2-6                                  [1, 224, 14, 14]          --
# │    │    └─MBConv: 3-32                                [1, 224, 14, 14]          474,728
# │    │    └─MBConv: 3-33                                [1, 224, 14, 14]          793,464
# │    │    └─MBConv: 3-34                                [1, 224, 14, 14]          793,464
# │    │    └─MBConv: 3-35                                [1, 224, 14, 14]          793,464
# │    │    └─MBConv: 3-36                                [1, 224, 14, 14]          793,464
# │    │    └─MBConv: 3-37                                [1, 224, 14, 14]          793,464
# │    │    └─MBConv: 3-38                                [1, 224, 14, 14]          793,464
# │    │    └─MBConv: 3-39                                [1, 224, 14, 14]          793,464
# │    │    └─MBConv: 3-40                                [1, 224, 14, 14]          793,464
# │    │    └─MBConv: 3-41                                [1, 224, 14, 14]          793,464
# │    └─Sequential: 2-7                                  [1, 384, 7, 7]            --
# │    │    └─MBConv: 3-42                                [1, 384, 7, 7]            1,008,824
# │    │    └─MBConv: 3-43                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-44                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-45                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-46                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-47                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-48                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-49                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-50                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-51                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-52                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-53                                [1, 384, 7, 7]            2,281,824
# │    │    └─MBConv: 3-54                                [1, 384, 7, 7]            2,281,824
# │    └─Sequential: 2-8                                  [1, 640, 7, 7]            --
# │    │    └─MBConv: 3-55                                [1, 640, 7, 7]            2,835,296
# │    │    └─MBConv: 3-56                                [1, 640, 7, 7]            6,199,200
# │    │    └─MBConv: 3-57                                [1, 640, 7, 7]            6,199,200
# │    │    └─MBConv: 3-58                                [1, 640, 7, 7]            6,199,200
# │    └─Conv2dNormActivation: 2-9                        [1, 2560, 7, 7]           --
# │    │    └─Conv2d: 3-59                                [1, 2560, 7, 7]           1,638,400
# │    │    └─BatchNorm2d: 3-60                           [1, 2560, 7, 7]           5,120
# │    │    └─SiLU: 3-61                                  [1, 2560, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-2                                [1, 2560, 1, 1]           --
# ├─Sequential: 1-3                                       [1, 1000]                 --
# │    └─Dropout: 2-10                                    [1, 2560]                 --
# │    └─Linear: 2-11                                     [1, 1000]                 2,561,000
# =========================================================================================================
# Total params: 66,347,960
# Trainable params: 66,347,960
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 5.17
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 640.89
# Params size (MB): 265.39
# Estimated Total Size (MB): 906.88
# =========================================================================================================
